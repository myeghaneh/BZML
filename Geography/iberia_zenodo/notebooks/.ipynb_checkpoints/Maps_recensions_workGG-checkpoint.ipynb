# %%
from citableclass import Credentials, Citable, Json2DF
# %load_ext autoreload
# %autoreload 2

# %%
#title = Credentials(authors='olivier.defaux,gerd.grasshoff,malte.vogl', project='geography',title='Maps of the Iberian Peninsula')
#title.titlepage()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#from utility import plot_maps,comp_plot_map_01,comp_plot_map_02
from tools import Geography
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.io import output_notebook, output_file, save
output_notebook()
from bokeh.models import HoverTool,BoxZoomTool,ResetTool, WheelZoomTool
from bokeh.layouts import row, gridplot, layout
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('max_colwidth', 260)

# %%
options = {"compact": True, "bg": "#09a3d5",
           "color": "white", "font": "Source Sans Pro","collapse_phrases":False}

# %% [markdown]
# On the basis of both recensions of the Geography, the localities of the Iberian peninsula are plotted and compared.

# %% [markdown]
# ### Load resources

# %%
OmegaJ = pd.read_json('../data/OmegaStructure.json')
XiJ = pd.read_json('../data/XiStructure.json')

# %%
# %run geographytools.py

# %%
df=OmegaJ["chapters"][0]
om=json_normalize(df,"section")
om.head(2)
# Out:
#     sec_ID  \
# 0  2.04.00
# 1  2.04.01
#
#                                                                                                                                                                                                                                 sec_part  \
# 0                                                                                                                                                                                                                                    NaN
# 1  [{'ID': '2.04.01.01', 'type': 'text string', 'text': 'τῆς Ἰσπανίας κατὰ δὲ Ἕλληνας Ἰβηρίας τρεῖς εἰσιν ἐπαρχίαι·'}, {'ID': '2.04.01.02', 'type': 'text string', 'text': 'Βαιτικὴ καὶ Λουσιτανία καὶ Ταρρακωνησία'}]
#
#                       text           type_sec
# 0  Ἰσπανίας Βαιτικῆς θέσις              title
# 1                      NaN  area presentation

# %%
def findTS(s):
    out=""
    for i,r in om.iterrows():
        sci=r["sec_ID"]
        if sci in s:
            out=r["type_sec"]
            exit
    return(out)
findTS("2.04.01.01")
# Out:
# 'area presentation'

# %%
def Js2Geodf(df): 
# df=OmegaJ["chapters"][0]
    om=json_normalize(df,"section")
    om=om.dropna(subset=["sec_part"])
    l=[]
    for i,x in om.iterrows():
        k={"type_sec":x["type_sec"]}
        l.append([x["sec_part"]])
#
    listItems=list(flatten_list(l))
    dfout=pd.DataFrame(listItems)
    dfout["type_sec"]=dfout.apply(lambda x: findTS(x["ID"]),axis=1)
    return(dfout)

# %%
dfOmega=Js2Geodf(OmegaJ["chapters"][0])
dfXi=Js2Geodf(XiJ["chapters"][0])

# %%
dfOmega.head(2)
# Out:
#            ID category coord people  \
# 0  2.04.01.01      NaN   NaN    NaN
# 1  2.04.01.02      NaN   NaN    NaN
#
#                                                                       text  \
# 0  τῆς Ἰσπανίας κατὰ δὲ Ἕλληνας Ἰβηρίας τρεῖς εἰσιν ἐπαρχίαι·
# 1                             Βαιτικὴ καὶ Λουσιτανία καὶ Ταρρακωνησία
#
#   toponym         type           type_sec
# 0     NaN  text string  area presentation
# 1     NaN  text string  area presentation

# %% [markdown]
# ### Translate greek to decimal coordinates

# %%
def reformatCoord(row,longLat, xy='coord_x'):
    if type(row[xy]) == dict:
        return (row[xy][longLat]['integer'].strip(),row[xy][longLat]['fraction'].strip())
    else:
        return False

# %%
gfrac={"":0,"Lς":2/3,"ςL":2/3,"ιβ":1/12,"ς":1/6,"δ":1/4,"γ":1/3,"γιβ":5/12,"L":1/2,"Lιβ":7/12,"γο":2/3,"Lδ":3/4,"Lγ":5/6,"Lγιβ":11/12,"η":1/8}
gint={"":0,"α":1,"β":2,"γ":3,"δ":4,"ε":5,"ς":6,"ζ":7,"η":8,"θ":9,"ι":10,"κ":20,"λ":30,"μ":40}

# %%
def translate(row):
    if type(row)==tuple:
        try:
            temp_frac = gfrac[row[1]]
        except:
            temp_frac = gint[row[1]]
        try:
            if len(row[0]) == 1:
                temp_int = gint[row[0]]
            elif len(row[0]) == 2:
                temp_int = gint[row[0][0]] + gint[row[0][1]]
            elif row[0] == '':
                temp_int = 0
        except:
            temp_int = None
        return temp_int + temp_frac

# %% [markdown]
# Omega recension

# %%
dfTemp = dfOmega.copy()
dfTemp['longitude'] = dfOmega.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
dfTemp['latitude'] = dfOmega.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)

# %%
dfTemp.head(20)
# Out:
#             ID                 category  \
# 0   2.04.01.01                      NaN
# 1   2.04.01.02                      NaN
# 2   2.04.02.01                      NaN
# 3   2.04.02.02                      NaN
# 4   2.04.03.01  [river mouth, boundary]
# 5   2.04.03.02              river mouth
# 6   2.04.03.03               river path
# 7   2.04.03.04   [river path, boundary]
# 8   2.04.03.07                 boundary
# 9   2.04.03.08             river source
# 10  2.04.04.01                      NaN
# 11  2.04.04.02                      NaN
# 12  2.04.04.03                      NaN
# 13  2.04.05.00                      NaN
# 14  2.04.05.01                      NaN
# 15  2.04.05.04                     city
# 16  2.04.05.05              river mouth
# 17  2.04.05.06              river mouth
# 18  2.04.05.07             river source
# 19  2.04.05.08                     city
#
#                                                                                        coord  \
# 0                                                                                        NaN
# 1                                                                                        NaN
# 2                                                                                        NaN
# 3                                                                                        NaN
# 4   {'long': {'integer': 'δ', 'fraction': 'ιβ'}, 'lat': {'integer': 'λζ', 'fraction': 'γο'}}
# 5     {'long': {'integer': 'δ', 'fraction': 'γ'}, 'lat': {'integer': 'λζ', 'fraction': 'L'}}
# 6      {'long': {'integer': 'ς', 'fraction': 'γ'}, 'lat': {'integer': 'λθ', 'fraction': ''}}
# 7       {'long': {'integer': 'θ', 'fraction': ''}, 'lat': {'integer': 'λθ', 'fraction': ''}}
# 8     {'long': {'integer': 'ιβ', 'fraction': ''}, 'lat': {'integer': 'λζ', 'fraction': 'δ'}}
# 9       {'long': {'integer': 'ιδ', 'fraction': ''}, 'lat': {'integer': 'μ', 'fraction': ''}}
# 10                                                                                       NaN
# 11                                                                                       NaN
# 12                                                                                       NaN
# 13                                                                                       NaN
# 14                                                                                       NaN
# 15   {'long': {'integer': 'δ', 'fraction': 'γο'}, 'lat': {'integer': 'λζ', 'fraction': 'γ'}}
# 16   {'long': {'integer': 'ε', 'fraction': 'ιβ'}, 'lat': {'integer': 'λζ', 'fraction': 'ς'}}
# 17     {'long': {'integer': 'ε', 'fraction': 'γ'}, 'lat': {'integer': 'λζ', 'fraction': ''}}
# 18    {'long': {'integer': 'ιβ', 'fraction': ''}, 'lat': {'integer': 'λη', 'fraction': 'L'}}
# 19    {'long': {'integer': 'ς', 'fraction': ''}, 'lat': {'integer': 'λς', 'fraction': 'Lδ'}}
#
#        people  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4   Turdetani
# 5   Turdetani
# 6
# 7
# 8
# 9
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15  Turdetani
# 16  Turdetani
# 17  Turdetani
# 18
# 19  Turdetani
#
#                                                                                                                                               text  \
# 0                                                                          τῆς Ἰσπανίας κατὰ δὲ Ἕλληνας Ἰβηρίας τρεῖς εἰσιν ἐπαρχίαι·
# 1                                                                                                     Βαιτικὴ καὶ Λουσιτανία καὶ Ταρρακωνησία
# 2             καὶ τῆς μὲν Βαιτικῆς ἡ πρὸς δυσμὰς καὶ ἄρκτους πλευρὰ ἀφορίζεται τῇ τε Λουσιτανίᾳ· καὶ τῆς Ταρρακωνησίας μέρει
# 3                                                                                                      ἧς πλευρᾶς ἡ περιγραφὴ ἔχει οὕτως·
# 4                                                                                                                                              NaN
# 5                                                                                                                                              NaN
# 6                                                                                                                                              NaN
# 7                                                                                                                                              NaN
# 8                                                                                                                                              NaN
# 9                                                                                                                                              NaN
# 10  ἡ δὲ πρὸς μεσημβρίαν πλευρὰ τῆς Βαιτικῆς περιορίζεται τῷ μὲν ὠκεανῷ κατὰ τὴν ἐκτὸς θάλασσαν καὶ τὸν Ἠράκλειον πορθμὸν·
# 11                                                                                      τῷ δὲ Ἰβηρικῷ πελάγει κατὰ τὴν ἐντὸς θάλασσαν.
# 12                                                                                    καὶ ταύτης δὲ τῆς πλευρᾶς ἡ περιγραφὴ ἔχει οὕτως·
# 13                                                                            μετὰ τὰς τοῦ Ἄνα ποταμοῦ ἐκβολὰς ἐν τῇ ἐκτὸς θαλάσσῃ
# 14                                                                                                                                    Τουρδητάνων
# 15                                                                                                                                             NaN
# 16                                                                                                                                             NaN
# 17                                                                                                                                             NaN
# 18                                                                                                                                             NaN
# 19                                                                                                                                             NaN
#
#                                                                                                                toponym  \
# 0                                                                                                                  NaN
# 1                                                                                                                  NaN
# 2                                                                                                                  NaN
# 3                                                                                                                  NaN
# 4                                                                       <τὸ δυσμικώτερον στόμα Ἄνα τοῦ ποταμοῦ>
# 5                                                                      τὸ ἀνατολικώτερον στόμα Ἄνα τοῦ ποταμοῦ
# 6                                                                        ἡ πρὸς ἀνατολὰς τοῦ ποταμοῦ ἐπιστροφή
# 7                                                        τὸ πρὸς τῷ πέρατι τῆς Λουσιτανίας τοῦ ποταμοῦ μέρος
# 8   καὶ ἡ ἐντεῦθεν γραμμὴ γραφομένη παρὰ τὴν Ταρρακωνησίαν ὡς ἐπὶ τὸ Βαλιαρικὸν πέλαγος πέρας ἔχουσα
# 9                                                                     αἱ δὲ πηγαὶ τοῦ ποταμοῦ ἐπέχουσι μοίρας
# 10                                                                                                                 NaN
# 11                                                                                                                 NaN
# 12                                                                                                                 NaN
# 13                                                                                                                 NaN
# 14                                                                                                                 NaN
# 15                                                                                                  Ὄνοβα Λιστουρία
# 16                                                                             <Βαιτίου ποταμοῦ τὸ δυτικὸν στόμα>
# 17                                                                           Βαιτίου ποταμοῦ τὸ ἀνατολικὸν στόμα
# 18                                                                                           αἱ πηγαὶ τοῦ ποταμοῦ
# 19                                                                                        ἡ κατὰ Ἄσταν εἴσχυσις
#
#                     type             type_sec  longitude   latitude
# 0            text string    area presentation        NaN        NaN
# 1            text string    area presentation        NaN        NaN
# 2            text string  borders description        NaN        NaN
# 3            text string  borders description        NaN        NaN
# 4               locality        coast section   4.083333  37.666667
# 5               locality        coast section   4.333333  37.500000
# 6               locality        coast section   6.333333  39.000000
# 7               locality        coast section   9.000000  39.000000
# 8               locality        coast section  12.000000  37.250000
# 9               locality        coast section  14.000000  40.000000
# 10           text string  borders description        NaN        NaN
# 11           text string  borders description        NaN        NaN
# 12           text string  borders description        NaN        NaN
# 13  section introduction        coast section        NaN        NaN
# 14                people        coast section        NaN        NaN
# 15              locality        coast section   4.666667  37.333333
# 16              locality        coast section   5.083333  37.166667
# 17              locality        coast section   5.333333  37.000000
# 18              locality        coast section  12.000000  38.500000
# 19              locality        coast section   6.000000  36.750000

# %% [markdown]
# Xi recension

# %%
dfTempX = dfXi.copy()
dfTempX['longitude'] = dfXi.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
dfTempX['latitude'] = dfXi.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)

# %% [markdown]
# # Data preparation for the map drawing

# %% [markdown]
# ### Coasts and boundaries (Omega)

# %% [markdown]
# Selection of coastal localities

# %%
f = dfTemp[(dfTemp.type_sec == 'coast section') & (dfTemp.type == 'locality') & dfTemp.category.apply(lambda row: row not in ['boundary','river path','river source'])][['longitude','latitude']]

# %%
f;

# %% [markdown]
# Coastal lines

# %%
#fbae = coast of Baetica, omega
baria = dfTemp[dfTemp.toponym == 'ἐφʹ ἧς Βαρεία πόλις '][['longitude','latitude']]
fbae = f.iloc[0:28]
fbae = fbae.append(baria)
fbae = fbae.values

# %%
#flus = coast of Lusitania, omega
flus = f.iloc[28:42].append(f.iloc[0:1]).sort_index(ascending=True)
flus = flus.values

# %%
#ftar = coast of Tarraconensis, omega
ftar1 = f.iloc[42:70].append(f.iloc[41:42]).sort_index(ascending=True)
ftar1 = ftar1.values
ftar2 = f.iloc[70:].sort_index(ascending=False)
baebound = dfTemp[dfTemp.toponym == 'μετὰ τὸ πρὸς τῇ Βαιτικῇ πέρας'][['longitude','latitude']]
ftar2 = ftar2.append(baebound).append(baria)
ftar2 = ftar2.values

# %%
dfTemp;

# %% [markdown]
# ### Coasts and boundaries (Xi)

# %% [markdown]
# Selection of coastal localities

# %%
g = dfTempX[(dfTempX.type_sec == 'coast section') & (dfTempX.type == 'locality') & dfTempX.category.apply(lambda row: row not in ['boundary','river path','river source'])][['longitude','latitude']]

# %% [markdown]
# Coastal lines

# %%
#gbae = coast of Baetica, xi
bariaX = dfTempX[dfTempX.toponym == 'ἐφʹ ἧς Βαραλία πόλις'][['longitude','latitude']]
gbae = g.iloc[0:26]
gbae = gbae.append(bariaX)
gbae = gbae.values

# %%
#glus = coast of Lusitania, xi
glus = g.iloc[27:41].append(g.iloc[0:1]).sort_index(ascending=True)
glus = glus.values

# %%
#gtar = coast of Tarraconensis, xi
gtar1 = g.iloc[41:68].append(g.iloc[40:41]).sort_index(ascending=True)
gtar1 = gtar1.values
gtar2 = g.iloc[69:].sort_index(ascending=False)
baeboundX = dfTempX[dfTempX.toponym == 'μετὰ τὸ πρὸς τῇ Βαιτικῇ πέρας'][['longitude','latitude']]
gtar2 = gtar2.append(baeboundX).append(bariaX)
gtar2 = gtar2.values

# %%
# make a dictionary for all coasts's lines using Xi for later use in function plot_maps
gs_dict={'gbae' : gbae, 'glus' : glus, 'gtar1' : gtar1, 'gtar2' : gtar2}

# %%
# make a dictionary for all coasts's lines using Omega for later use in function plot_maps
fs_dict={'fbae' : fbae, 'flus' : flus, 'ftar1' : ftar1, 'ftar2' : ftar2}

# %%
# make a dictionary for all data
df_dict={"dfTemp" : dfTemp,  "dfTempX" : dfTempX}

# %% [markdown]
# # Maps

# %% [markdown]
# ### Omega recension

# %%
fig=Geography(fs_dict,gs_dict,df_dict)

# %%
fig.plot_recension(fs_dict,gs_dict,df_dict,select_recension='Omega')
# Out:
#   <div class="bk-root" id="aba722e6-d66d-4959-bc63-259ddf564cfa" data-root-id="1003"></div>

# %% [markdown]
# ### Xi Recension

# %%
fig.plot_recension(fs_dict,gs_dict,df_dict,select_recension='Xi')
# Out:
#   <div class="bk-root" id="d91f52e3-a637-47a9-a79a-d011b179e364" data-root-id="1458"></div>

# %% [markdown]
# ## Comparison Ξ and Ω

# %%
fig.plot_compare_recension(fs_dict,gs_dict,df_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e99b8dd589dc> in <module>
# ----> 1 fig.plot_compare_recension(fs_dict,gs_dict,df_dict)
#       2
#
# ~\Dropbox\iberia_zenodo\notebooks\tools.py in plot_compare_recension(self, fs_dict, gs_dict, df_dict)
#      52         """
#      53
# ---> 54         a=self.df_dict['dfTempX'].reset_index(level=['chap_ID','sec_ID','ID'])
#      55         a=a[a.longitude.apply(lambda row: row not in [0])]
#      56         a=a[['ID','longitude','latitude']].dropna()
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4099             if not isinstance(level, (tuple, list)):
#    4100                 level = [level]
# -> 4101             level = [self.index._get_level_number(lev) for lev in level]
#    4102             if isinstance(self.index, MultiIndex):
#    4103                 if len(level) < self.index.nlevels:
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4099             if not isinstance(level, (tuple, list)):
#    4100                 level = [level]
# -> 4101             level = [self.index._get_level_number(lev) for lev in level]
#    4102             if isinstance(self.index, MultiIndex):
#    4103                 if len(level) < self.index.nlevels:
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1959
#    1960     def _get_level_number(self, level):
# -> 1961         self._validate_index_level(level)
#    1962         return 0
#    1963
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1956         elif level != self.name:
#    1957             raise KeyError('Level %s must be same as name (%s)' %
# -> 1958                            (level, self.name))
#    1959
#    1960     def _get_level_number(self, level):
#
# KeyError: 'Level chap_ID must be same as name (None)'

# %%
fig.plot_border_compare_recension(fs_dict,gs_dict,df_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-9f2216427c1c> in <module>
# ----> 1 fig.plot_border_compare_recension(fs_dict,gs_dict,df_dict)
#
# ~\Dropbox\iberia_zenodo\notebooks\tools.py in plot_border_compare_recension(self, fs_dict, gs_dict, df_dict)
#      96         """
#      97         g = self.df_dict['dfTempX'][(self.df_dict['dfTempX'].type_sec == 'coast section') & (self.df_dict['dfTempX'].type == 'locality') & self.df_dict['dfTempX'].category.apply(lambda         row: row not in ['boundary','river path','river source'])]     [['longitude','latitude']]
# ---> 98         g2=g.reset_index(level=['chap_ID','sec_ID','ID'])
#      99         g2=g2[g2.longitude.apply(lambda row: row not in [0])]
#     100         g2=g2[['ID','longitude','latitude']].dropna()
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4099             if not isinstance(level, (tuple, list)):
#    4100                 level = [level]
# -> 4101             level = [self.index._get_level_number(lev) for lev in level]
#    4102             if isinstance(self.index, MultiIndex):
#    4103                 if len(level) < self.index.nlevels:
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    4099             if not isinstance(level, (tuple, list)):
#    4100                 level = [level]
# -> 4101             level = [self.index._get_level_number(lev) for lev in level]
#    4102             if isinstance(self.index, MultiIndex):
#    4103                 if len(level) < self.index.nlevels:
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_level_number(self, level)
#    1959
#    1960     def _get_level_number(self, level):
# -> 1961         self._validate_index_level(level)
#    1962         return 0
#    1963
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1956         elif level != self.name:
#    1957             raise KeyError('Level %s must be same as name (%s)' %
# -> 1958                            (level, self.name))
#    1959
#    1960     def _get_level_number(self, level):
#
# KeyError: 'Level chap_ID must be same as name (None)'

# %% [markdown]
# # Interactive Overview of maps

# %%
import os 
import  ipywidgets as widgets
from ipywidgets import interact
from IPython.display import Image
import os
# Create widgets
directory = widgets.Dropdown(options=['image'])
images = widgets.Dropdown(options=os.listdir(directory.value))

# Updates the image options based on directory value
def update_images(*args):
    images.options = os.listdir(directory.value)

# Tie the image options to directory value
directory.observe(update_images, 'value')

# Show the images
def show_images(fdir, file):
    display(Image(f'{fdir}/{file}'))

_ = interact(show_images, fdir=directory, file=images)
