# %%
from citableclass import Credentials, Citable, Json2DF
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from utility import plot_maps,comp_plot_map_01,comp_plot_map_02

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.io import output_notebook, output_file, save
output_notebook()
from bokeh.models import HoverTool,BoxZoomTool,ResetTool, WheelZoomTool
from bokeh.layouts import row, gridplot, layout
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1004">Loading BokehJS ...</span>
#     </div>

# %%
title = Credentials(authors='olivier.defaux,gerd.grasshoff,malte.vogl', project='geography',title='Maps of the Iberian Peninsula')
title.titlepage()
# Out:
#         <h1>Maps of the Iberian Peninsula</h1>
#         <h2>Olivier Defaux<sup>1,2</sup>, Gerd Grasshoff<sup>1,2</sup>, Malte Vogl<sup>1</sup></h2>
#         1: Max-Planck-Institute for the History of Science, Berlin; 2: Humboldt-University, Berlin<br>
#         Date: 08. August 2019

# %% [markdown]
# On the basis of both recensions of the Geography, the localities of the Iberian peninsula are plotted and compared.

# %% [markdown]
# ### Load resources

# %%
cite = Citable('dict_omega.json',formats='local', project='geography')
x1= cite.digitalresource()

cite = Citable('dict_xi.json',formats='local', project='geography')
x2= cite.digitalresource()

# %% [markdown]
# ### Transforming to multi-level dataframes

# %%
init = Json2DF(x1,['book_ID','chap_ID','sec_ID','ID'],level=4)
init.convert()
dfOmega = init.dataframe

init2 = Json2DF(x2,['book_ID','chap_ID','sec_ID','ID'],level=4)
init2.convert()
dfXi = init2.dataframe

# %%
dfOmega
# Out:
#                                                                                  text  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN          á¼¸ÏƒÏ€Î±Î½á½·Î±Ï‚ Î’Î±Î¹Ï„Î¹Îºá¿†Ï‚ Î¸á½³ÏƒÎ¹Ï‚
#                 2.04.01 2.04.01.01  Ï„Î·Í‚Ï‚ Î™Ì“ÏƒÏ€Î±Î½Î¹Ì�Î±Ï‚ ÎºÎ±Ï„Î±Ì€ Î´ÎµÌ...
#                         2.04.01.02  Î’Î±Î¹Ï„Î¹ÎºÎ·Ì€ ÎºÎ±Î¹Ì€ Î›Î¿Ï…ÏƒÎ¹Ï„Î±Î½Î¹Ì�...
#                 2.04.02 2.04.02.01  ÎºÎ±Î¹Ì€ Ï„Î·Í‚Ï‚ Î¼ÎµÌ€Î½ Î’Î±Î¹Ï„Î¹ÎºÎ·Í‚Ï‚ ...
#                         2.04.02.02  Î·Ì”Í‚Ï‚ Ï€Î»ÎµÏ…Ï�Î±Í‚Ï‚ Î·Ì” Ï€ÎµÏ�Î¹Î³Ï�Î±Ï...
#                 2.04.03 2.04.03.01                                                NaN
#                         2.04.03.01                                                NaN
#                         2.04.03.02                                                NaN
#                         2.04.03.03                                                NaN
#                         2.04.03.04                                                NaN
#                         2.04.03.04                                                NaN
#                         2.04.03.07                                                NaN
#                         2.04.03.08                                                NaN
#                 2.04.04 2.04.04.01  Î·Ì” Î´ÎµÌ€ Ï€Ï�Î¿Ì€Ï‚ Î¼ÎµÏƒÎ·Î¼Î²Ï�Î¹Ì�Î±Î½ ...
#                         2.04.04.02  Ï„Ï‰Í‚Í… Î´ÎµÌ€ Î™Ì“Î²Î·Ï�Î¹ÎºÏ‰Í‚Í… Ï€ÎµÎ»Î±Ì...
#                         2.04.04.03  ÎºÎ±Î¹Ì€ Ï„Î±Ï…Ì�Ï„Î·Ï‚ Î´ÎµÌ€ Ï„Î·Í‚Ï‚ Ï€Î»Îµ...
#                 2.04.05 2.04.05.00  Î¼ÎµÏ„Î±Ì€ Ï„Î±Ì€Ï‚ Ï„Î¿Ï…Í‚ Î‘Ì“Ì�Î½Î± Ï€Î¿Ï„...
#                         2.04.05.01                           Î¤Î¿Ï…Ï�Î´Î·Ï„Î±Ì�Î½Ï‰Î½
#                         2.04.05.04                                                NaN
#                         2.04.05.05                                                NaN
#                         2.04.05.06                                                NaN
#                         2.04.05.07                                                NaN
#                         2.04.05.08                                                NaN
#                         2.04.05.09                                                NaN
#                         2.04.05.10                                                NaN
#                         2.04.05.11                                                NaN
#                         2.04.05.11                                                NaN
#                         2.04.05.12                                                NaN
#                         2.04.05.13                                                NaN
#                 2.04.06 2.04.06.01  Î’Î±ÏƒÏ„Î¿Ï…Î»Ï‰Í‚Î½ Ï„Ï‰Í‚Î½ ÎºÎ±Î»Î¿Ï…Î¼ÎµÌ�...
# ...                                                                               ...
#         2.06    2.06.72 2.06.72.07                                                NaN
#                         2.06.72.08                                                NaN
#                         2.06.72.09                                                NaN
#                         2.06.72.10                                                NaN
#                         2.06.72.11                                                NaN
#                 2.06.73 2.06.73.01  ÎµÎ¹Ì“ÏƒÎ¹Ì€ Î´ÎµÌ€ ÎºÎ±Î¹Ì€ Ï„Ï‰Í‚Î½ Î¼ÎµÌ€Î½...
#                         2.06.73.02                                                NaN
#                         2.06.73.03                                                NaN
#                 2.06.74 2.06.74.01  Ï„Ï‰Í‚Î½ Î´ÎµÌ€ Î›Î±Î¹Î·Ï„Î±Î½Ï‰Í‚Î½Î‡ Î¼ÎµÏƒÎ...
#                         2.06.74.02                                                NaN
#                 2.06.75 2.06.75.01  Î½Î·Í‚ÏƒÎ¿Î¹ Î´ÎµÌ€ Ï€Î±Ï�Î±Ì�ÎºÎµÎ¹Î½Ï„Î±Î¹ Ï...
#                         2.06.75.03                                                NaN
#                 2.06.76 2.06.76.01  ÎµÌ“Î½ Î´ÎµÌ€ Ï„Ï‰Í‚Í… Î”Ï…Ï„Î¹ÎºÏ‰Í‚Í… Î©Ì“Îº...
#                         2.06.76.02                                                NaN
#                         2.06.76.03                                                NaN
#                 2.06.77 2.06.77.01  ÎµÌ“Î½ Î´ÎµÌ€ Ï„Ï‰Í‚Í… Î’Î±Î»Î»Î¹Î±Ï�Î¹ÎºÏ‰Í‚Í...
#                         2.06.77.03                                                NaN
#                         2.06.77.04                                                NaN
#                         2.06.77.04                                                NaN
#                 2.06.78 2.06.78.01  ÎºÎ±Î¹Ì€ Î±Î¹Ì” Î’Î±Î»Î»Î¹Î±Ï�Î¹Ì�Î´ÎµÏ‚ Î½Î·Í...
#                         2.06.78.02  Ï‰Ì”Í‚Î½ ÎµÌ“Î½ Î¼ÎµÌ€Î½ Ï„Î·Í‚Í… Î¼ÎµÎ¹Ì�Î¶Î¿...
#                         2.06.78.04                                                NaN
#                         2.06.78.04                                                NaN
#                         2.06.78.05                                                NaN
#                         2.06.78.05                                                NaN
#                         2.06.78.06  ÎµÌ“Î½ Î´ÎµÌ€ Ï„Î·Í‚Í… ÎµÌ“Î»Î±Ì�Ï„Ï„Î¿Î½Î¹, Ï...
#                         2.06.78.07                                                NaN
#                         2.06.78.07                                                NaN
#                         2.06.78.08                                                NaN
#                         2.06.78.08                                                NaN
#
#                                                type_sec      category  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                       title           NaN
#                 2.04.01 2.04.01.01    area presentation           NaN
#                         2.04.01.02    area presentation           NaN
#                 2.04.02 2.04.02.01  borders description           NaN
#                         2.04.02.02  borders description           NaN
#                 2.04.03 2.04.03.01        coast section   river mouth
#                         2.04.03.01        coast section      boundary
#                         2.04.03.02        coast section   river mouth
#                         2.04.03.03        coast section    river path
#                         2.04.03.04        coast section    river path
#                         2.04.03.04        coast section      boundary
#                         2.04.03.07        coast section      boundary
#                         2.04.03.08        coast section  river source
#                 2.04.04 2.04.04.01  borders description           NaN
#                         2.04.04.02  borders description           NaN
#                         2.04.04.03  borders description           NaN
#                 2.04.05 2.04.05.00        coast section           NaN
#                         2.04.05.01        coast section           NaN
#                         2.04.05.04        coast section          city
#                         2.04.05.05        coast section   river mouth
#                         2.04.05.06        coast section   river mouth
#                         2.04.05.07        coast section  river source
#                         2.04.05.08        coast section          city
#                         2.04.05.09        coast section          city
#                         2.04.05.10        coast section       harbour
#                         2.04.05.11        coast section          cape
#                         2.04.05.11        coast section        temple
#                         2.04.05.12        coast section   river mouth
#                         2.04.05.13        coast section          city
#                 2.04.06 2.04.06.01        coast section           NaN
# ...                                                 ...           ...
#         2.06    2.06.72 2.06.72.07               inland          city
#                         2.06.72.08               inland          city
#                         2.06.72.09               inland          city
#                         2.06.72.10               inland          city
#                         2.06.72.11               inland          city
#                 2.06.73 2.06.73.01               inland           NaN
#                         2.06.73.02               inland          city
#                         2.06.73.03               inland          city
#                 2.06.74 2.06.74.01               inland           NaN
#                         2.06.74.02               inland          city
#                 2.06.75 2.06.75.01               island           NaN
#                         2.06.75.03               island        island
#                 2.06.76 2.06.76.01               island           NaN
#                         2.06.76.02               island        island
#                         2.06.76.03               island        island
#                 2.06.77 2.06.77.01               island           NaN
#                         2.06.77.03               island        island
#                         2.06.77.04               island        island
#                         2.06.77.04               island          city
#                 2.06.78 2.06.78.01               island           NaN
#                         2.06.78.02               island           NaN
#                         2.06.78.04               island        island
#                         2.06.78.04               island          city
#                         2.06.78.05               island        island
#                         2.06.78.05               island          city
#                         2.06.78.06               island           NaN
#                         2.06.78.07               island        island
#                         2.06.78.07               island          city
#                         2.06.78.08               island        island
#                         2.06.78.08               island          city
#
#                                                                                 coord  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                                                       NaN
#                 2.04.01 2.04.01.01                                                NaN
#                         2.04.01.02                                                NaN
#                 2.04.02 2.04.02.01                                                NaN
#                         2.04.02.02                                                NaN
#                 2.04.03 2.04.03.01  {'long': {'integer': 'Î´', 'fraction': 'Î¹Î²'}...
#                         2.04.03.01  {'long': {'integer': 'Î´', 'fraction': 'Î¹Î²'}...
#                         2.04.03.02  {'long': {'integer': 'Î´', 'fraction': 'Î³'}, ...
#                         2.04.03.03  {'long': {'integer': 'Ï‚', 'fraction': 'Î³'}, ...
#                         2.04.03.04  {'long': {'integer': 'Î¸', 'fraction': ''}, 'l...
#                         2.04.03.04  {'long': {'integer': 'Î¸', 'fraction': ''}, 'l...
#                         2.04.03.07  {'long': {'integer': 'Î¹Î²', 'fraction': ''}, ...
#                         2.04.03.08  {'long': {'integer': 'Î¹Î´', 'fraction': ''}, ...
#                 2.04.04 2.04.04.01                                                NaN
#                         2.04.04.02                                                NaN
#                         2.04.04.03                                                NaN
#                 2.04.05 2.04.05.00                                                NaN
#                         2.04.05.01                                                NaN
#                         2.04.05.04  {'long': {'integer': 'Î´', 'fraction': 'Î³Î¿'}...
#                         2.04.05.05  {'long': {'integer': 'Îµ', 'fraction': 'Î¹Î²'}...
#                         2.04.05.06  {'long': {'integer': 'Îµ', 'fraction': 'Î³'}, ...
#                         2.04.05.07  {'long': {'integer': 'Î¹Î²', 'fraction': ''}, ...
#                         2.04.05.08  {'long': {'integer': 'Ï‚', 'fraction': ''}, 'l...
#                         2.04.05.09  {'long': {'integer': 'Ï‚', 'fraction': ''}, 'l...
#                         2.04.05.10  {'long': {'integer': 'Ï‚', 'fraction': ''}, 'l...
#                         2.04.05.11  {'long': {'integer': 'Îµ', 'fraction': 'LÎ´'},...
#                         2.04.05.11  {'long': {'integer': 'Îµ', 'fraction': 'LÎ´'},...
#                         2.04.05.12  {'long': {'integer': 'Ï‚', 'fraction': 'Ï‚'}, ...
#                         2.04.05.13  {'long': {'integer': 'Ï‚', 'fraction': 'Î´'}, ...
#                 2.04.06 2.04.06.01                                                NaN
# ...                                                                               ...
#         2.06    2.06.72 2.06.72.07  {'long': {'integer': 'Î¹Îµ', 'fraction': 'Î³Î¿...
#                         2.06.72.08  {'long': {'integer': 'Î¹Ï‚', 'fraction': 'LÎ´'...
#                         2.06.72.09  {'long': {'integer': 'Î¹Îµ', 'fraction': 'L'},...
#                         2.06.72.10  {'long': {'integer': 'Î¹Ï‚', 'fraction': 'Î³'}...
#                         2.06.72.11  {'long': {'integer': 'Î¹Îµ', 'fraction': 'LÎ³'...
#                 2.06.73 2.06.73.01                                                NaN
#                         2.06.73.02  {'long': {'integer': 'Î¹Î·', 'fraction': 'Î³Î¿...
#                         2.06.73.03  {'long': {'integer': 'Î¹Î·', 'fraction': 'L'},...
#                 2.06.74 2.06.74.01                                                NaN
#                         2.06.74.02  {'long': {'integer': 'Î¹Î¶', 'fraction': 'Î³'}...
#                 2.06.75 2.06.75.01                                                NaN
#                         2.06.75.03  {'long': {'integer': 'Î¸', 'fraction': ''}, 'l...
#                 2.06.76 2.06.76.01                                                NaN
#                         2.06.76.02  {'long': {'integer': 'Î´', 'fraction': ''}, 'l...
#                         2.06.76.03  {'long': {'integer': 'Î´', 'fraction': 'Î³Î¿'}...
#                 2.06.77 2.06.77.01                                                NaN
#                         2.06.77.03  {'long': {'integer': 'Î¹Î´', 'fraction': 'LÎ³'...
#                         2.06.77.04  {'long': {'integer': 'Î¹Î´', 'fraction': ''}, ...
#                         2.06.77.04  {'long': {'integer': 'Î¹Î´', 'fraction': ''}, ...
#                 2.06.78 2.06.78.01                                                NaN
#                         2.06.78.02                                                NaN
#                         2.06.78.04  {'long': {'integer': 'Î¹Ï‚', 'fraction': 'Ï‚'}...
#                         2.06.78.04  {'long': {'integer': 'Î¹Ï‚', 'fraction': 'Ï‚'}...
#                         2.06.78.05  {'long': {'integer': 'Î¹Ï‚', 'fraction': 'LÎ´'...
#                         2.06.78.05  {'long': {'integer': 'Î¹Ï‚', 'fraction': 'LÎ´'...
#                         2.06.78.06                                                NaN
#                         2.06.78.07  {'long': {'integer': 'Î¹Î¶', 'fraction': 'Ï‚'}...
#                         2.06.78.07  {'long': {'integer': 'Î¹Î¶', 'fraction': 'Ï‚'}...
#                         2.06.78.08  {'long': {'integer': 'Î¹Î¶', 'fraction': 'L'},...
#                         2.06.78.08  {'long': {'integer': 'Î¹Î¶', 'fraction': 'L'},...
#
#                                        people  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN               NaN
#                 2.04.01 2.04.01.01        NaN
#                         2.04.01.02        NaN
#                 2.04.02 2.04.02.01        NaN
#                         2.04.02.02        NaN
#                 2.04.03 2.04.03.01  Turdetani
#                         2.04.03.01  Turdetani
#                         2.04.03.02  Turdetani
#                         2.04.03.03
#                         2.04.03.04
#                         2.04.03.04
#                         2.04.03.07
#                         2.04.03.08
#                 2.04.04 2.04.04.01        NaN
#                         2.04.04.02        NaN
#                         2.04.04.03        NaN
#                 2.04.05 2.04.05.00        NaN
#                         2.04.05.01        NaN
#                         2.04.05.04  Turdetani
#                         2.04.05.05  Turdetani
#                         2.04.05.06  Turdetani
#                         2.04.05.07
#                         2.04.05.08  Turdetani
#                         2.04.05.09
#                         2.04.05.10    Turduli
#                         2.04.05.11    Turduli
#                         2.04.05.11    Turduli
#                         2.04.05.12    Turduli
#                         2.04.05.13    Turduli
#                 2.04.06 2.04.06.01        NaN
# ...                                       ...
#         2.06    2.06.72 2.06.72.07  Iaccetani
#                         2.06.72.08  Iaccetani
#                         2.06.72.09  Iaccetani
#                         2.06.72.10  Iaccetani
#                         2.06.72.11  Iaccetani
#                 2.06.73 2.06.73.01        NaN
#                         2.06.73.02  Indigetes
#                         2.06.73.03  Indigetes
#                 2.06.74 2.06.74.01        NaN
#                         2.06.74.02   Laeetani
#                 2.06.75 2.06.75.01        NaN
#                         2.06.75.03
#                 2.06.76 2.06.76.01        NaN
#                         2.06.76.02
#                         2.06.76.03
#                 2.06.77 2.06.77.01        NaN
#                         2.06.77.03
#                         2.06.77.04
#                         2.06.77.04
#                 2.06.78 2.06.78.01        NaN
#                         2.06.78.02        NaN
#                         2.06.78.04
#                         2.06.78.04
#                         2.06.78.05
#                         2.06.78.05
#                         2.06.78.06        NaN
#                         2.06.78.07
#                         2.06.78.07
#                         2.06.78.08
#                         2.06.78.08
#
#                                                                               toponym  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                                                       NaN
#                 2.04.01 2.04.01.01                                                NaN
#                         2.04.01.02                                                NaN
#                 2.04.02 2.04.02.01                                                NaN
#                         2.04.02.02                                                NaN
#                 2.04.03 2.04.03.01  <Ï„Î¿Ì€ Î´Ï…ÏƒÎ¼Î¹ÎºÏ‰Ì�Ï„ÎµÏ�Î¿Î½ ÏƒÏ„Î¿Ì�Î¼Î...
#                         2.04.03.01  <Ï„Î¿Ì€ Î´Ï…ÏƒÎ¼Î¹ÎºÏ‰Ì�Ï„ÎµÏ�Î¿Î½ ÏƒÏ„Î¿Ì�Î¼Î...
#                         2.04.03.02  Ï„Î¿Ì€ Î±Ì“Î½Î±Ï„Î¿Î»Î¹ÎºÏ‰Ì�Ï„ÎµÏ�Î¿Î½ ÏƒÏ„Î¿...
#                         2.04.03.03  Î·Ì” Ï€Ï�Î¿Ì€Ï‚ Î±Ì“Î½Î±Ï„Î¿Î»Î±Ì€Ï‚ Ï„Î¿Ï…Í‚ ...
#                         2.04.03.04  Ï„Î¿Ì€ Ï€Ï�Î¿Ì€Ï‚ Ï„Ï‰Í‚Í… Ï€ÎµÌ�Ï�Î±Ï„Î¹ Ï„Î·...
#                         2.04.03.04  Ï„Î¿Ì€ Ï€Ï�Î¿Ì€Ï‚ Ï„Ï‰Í‚Í… Ï€ÎµÌ�Ï�Î±Ï„Î¹ Ï„Î·...
#                         2.04.03.07  ÎºÎ±Î¹Ì€ Î·Ì” ÎµÌ“Î½Ï„ÎµÏ…Í‚Î¸ÎµÎ½ Î³Ï�Î±Î¼Î¼Î...
#                         2.04.03.08  Î±Î¹Ì” Î´ÎµÌ€ Ï€Î·Î³Î±Î¹Ì€ Ï„Î¿Ï…Í‚ Ï€Î¿Ï„Î±Î¼...
#                 2.04.04 2.04.04.01                                                NaN
#                         2.04.04.02                                                NaN
#                         2.04.04.03                                                NaN
#                 2.04.05 2.04.05.00                                                NaN
#                         2.04.05.01                                                NaN
#                         2.04.05.04                ÎŸÌ“Ì�Î½Î¿Î²Î± Î›Î¹ÏƒÏ„Î¿Ï…Ï�Î¹Ì�Î±
#                         2.04.05.05  <Î’Î±Î¹Ï„Î¹Ì�Î¿Ï… Ï€Î¿Ï„Î±Î¼Î¿Ï…Í‚ Ï„Î¿Ì€ Î´Ï…...
#                         2.04.05.06  Î’Î±Î¹Ï„Î¹Ì�Î¿Ï… Ï€Î¿Ï„Î±Î¼Î¿Ï…Í‚ Ï„Î¿Ì€ Î±Ì“Î...
#                         2.04.05.07     Î±Î¹Ì” Ï€Î·Î³Î±Î¹Ì€ Ï„Î¿Ï…Í‚ Ï€Î¿Ï„Î±Î¼Î¿Ï…Í‚
#                         2.04.05.08  Î·Ì” ÎºÎ±Ï„Î±Ì€ Î‘Ì“Ì�ÏƒÏ„Î±Î½ ÎµÎ¹Ì“Ì�ÏƒÏ‡Ï…Ï...
#                         2.04.05.09                            Î¤Î¿Ï…Ï�Î´Î¿Ï…Ì�Î»Ï‰Î½
#                         2.04.05.10                  ÎœÎµÎ½ÎµÏƒÎ¸ÎµÌ�Ï‰Ï‚ Î»Î¹Î¼Î·Ì�Î½
#                         2.04.05.11  Ï„Î¿Ì€ Î±Ì“ÎºÏ�Ï‰Ï„Î·Ì�Ï�Î¹Î¿Î½ Î±Ì“Ï†Í´ Î¿Ï…Ì...
#                         2.04.05.11  Ï„Î¿Ì€ Î±Ì“ÎºÏ�Ï‰Ï„Î·Ì�Ï�Î¹Î¿Î½ Î±Ì“Ï†Í´ Î¿Ï…Ì...
#                         2.04.05.12  Î’Î±Î¹Ì�Î»Ï‰Î½Î¿Ï‚ Ï€Î¿Ï„Î±Î¼Î¿Ï…Í‚ ÎµÌ“ÎºÎ²Î¿...
#                         2.04.05.13                       Î’Î±Î¹Ì�Î»Ï‰Î½ Ï€Î¿Ì�Î»Î¹Ï‚
#                 2.04.06 2.04.06.01                                                NaN
# ...                                                                               ...
#         2.06    2.06.72 2.06.72.07                                   ÎšÎµÏ�ÎµÌ�ÏƒÎ¿Ï‚
#                         2.06.72.08                                   Î’Î±ÎºÎ±ÏƒÎ¹Ì�Ï‚
#                         2.06.72.09                                   Î™Ì“ÎµÏƒÏ€Î¿Ì�Ï‚
#                         2.06.72.10                                   Î‘Ì“Î½Î±Ì�Î²Î¹Ï‚
#                         2.06.72.11                                       ÎšÎ¹Ì�Î½Î½Î±
#                 2.06.73 2.06.73.01                                                NaN
#                         2.06.73.02                                   Î”ÎµÎºÎ¹Î±Ì�Î½Î±
#                         2.06.73.03                             Î™Ì“Î¿Ï…Î³ÎºÎ±Ï�Î¹Ì�Î±
#                 2.06.74 2.06.74.01                                                NaN
#                         2.06.74.02                           Î¡Ì”Î¿Ï…Î²Ï�Î¹ÎºÎ±Ì�Ï„Î±
#                 2.06.75 2.06.75.01                                                NaN
#                         2.06.75.03  Ï‰Ì”Í‚Î½ Ï„Î¿Ì€ Î¼ÎµÏ„Î±Î¾Ï…Ì€ ÎµÌ“Ï€ÎµÌ�Ï‡ÎµÎ...
#                 2.06.76 2.06.76.01                                                NaN
#                         2.06.76.02  Ï‰Ì”Í‚Î½ Ï„Î¿Ì€ Î¼ÎµÏ„Î±Î¾Ï…Ì€ ÎµÌ“Ï€ÎµÌ�Ï‡ÎµÎ...
#                         2.06.76.03  ÎºÎ±Î¹Ì€ Î±Î¹Ì” Ï„Ï‰Í‚Î½ Î˜ÎµÏ‰Í‚Î½ Î½Î·Í‚ÏƒÎ¿...
#                 2.06.77 2.06.77.01                                                NaN
#                         2.06.77.03  Ï‰Ì”Í‚Î½ Î·Ì” Î¼ÎµÌ€Î½ ÎµÌ“Î»Î±Ì�Ï„Ï„Ï‰Î½ ÎºÎ±...
#                         2.06.77.04  Î·Ì” Î´ÎµÌ€ Î¼ÎµÎ¹Ì�Î¶Ï‰Î½ Î•Ì“Ì�Î²Ï…ÏƒÏƒÎ¿Ï‚ ...
#                         2.06.77.04  Î·Ì” Î´ÎµÌ€ Î¼ÎµÎ¹Ì�Î¶Ï‰Î½ Î•Ì“Ì�Î²Ï…ÏƒÏƒÎ¿Ï‚ ...
#                 2.06.78 2.06.78.01                                                NaN
#                         2.06.78.02                                                NaN
#                         2.06.78.04                                       Î Î±Ì�Î»Î¼Î±
#                         2.06.78.04                                       Î Î±Ì�Î»Î¼Î±
#                         2.06.78.05                               Î Î¿Î»Î»ÎµÎ½Ï„Î¹Ì�Î±
#                         2.06.78.05                               Î Î¿Î»Î»ÎµÎ½Ï„Î¹Ì�Î±
#                         2.06.78.06                                                NaN
#                         2.06.78.07                                     Î™Ì“Ì�Î±Î¼Î½Î±
#                         2.06.78.07                                     Î™Ì“Ì�Î±Î¼Î½Î±
#                         2.06.78.08                                         ÎœÎ±Î³Ï‰Ì�
#                         2.06.78.08                                         ÎœÎ±Î³Ï‰Ì�
#
#                                                     type
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                          NaN
#                 2.04.01 2.04.01.01           text string
#                         2.04.01.02           text string
#                 2.04.02 2.04.02.01           text string
#                         2.04.02.02           text string
#                 2.04.03 2.04.03.01              locality
#                         2.04.03.01              locality
#                         2.04.03.02              locality
#                         2.04.03.03              locality
#                         2.04.03.04              locality
#                         2.04.03.04              locality
#                         2.04.03.07              locality
#                         2.04.03.08              locality
#                 2.04.04 2.04.04.01           text string
#                         2.04.04.02           text string
#                         2.04.04.03           text string
#                 2.04.05 2.04.05.00  section introduction
#                         2.04.05.01                people
#                         2.04.05.04              locality
#                         2.04.05.05              locality
#                         2.04.05.06              locality
#                         2.04.05.07              locality
#                         2.04.05.08              locality
#                         2.04.05.09              locality
#                         2.04.05.10              locality
#                         2.04.05.11              locality
#                         2.04.05.11              locality
#                         2.04.05.12              locality
#                         2.04.05.13              locality
#                 2.04.06 2.04.06.01                people
# ...                                                  ...
#         2.06    2.06.72 2.06.72.07              locality
#                         2.06.72.08              locality
#                         2.06.72.09              locality
#                         2.06.72.10              locality
#                         2.06.72.11              locality
#                 2.06.73 2.06.73.01  section introduction
#                         2.06.73.02              locality
#                         2.06.73.03              locality
#                 2.06.74 2.06.74.01  section introduction
#                         2.06.74.02              locality
#                 2.06.75 2.06.75.01  section introduction
#                         2.06.75.03              locality
#                 2.06.76 2.06.76.01  section introduction
#                         2.06.76.02              locality
#                         2.06.76.03              locality
#                 2.06.77 2.06.77.01  section introduction
#                         2.06.77.03              locality
#                         2.06.77.04              locality
#                         2.06.77.04              locality
#                 2.06.78 2.06.78.01  section introduction
#                         2.06.78.02  section introduction
#                         2.06.78.04              locality
#                         2.06.78.04              locality
#                         2.06.78.05              locality
#                         2.06.78.05              locality
#                         2.06.78.06  section introduction
#                         2.06.78.07              locality
#                         2.06.78.07              locality
#                         2.06.78.08              locality
#                         2.06.78.08              locality
#
# [660 rows x 7 columns]

# %% [markdown]
# ### Translate greek to decimal coordinates

# %%
def reformatCoord(row,longLat, xy='coord_x'):
    if type(row[xy]) == dict:
        return (row[xy][longLat]['integer'].strip(),row[xy][longLat]['fraction'].strip())
    else:
        return False

# %%
gfrac={"":0,"Lς":2/3,"ςL":2/3,"ιβ":1/12,"ς":1/6,"δ":1/4,"γ":1/3,"γιβ":5/12,"L":1/2,"Lιβ":7/12,"γο":2/3,"Lδ":3/4,"Lγ":5/6,"Lγιβ":11/12,"η":1/8}
gint={"":0,"α":1,"β":2,"γ":3,"δ":4,"ε":5,"ς":6,"ζ":7,"η":8,"θ":9,"ι":10,"κ":20,"λ":30,"μ":40}

# %%
def translate(row):
    if type(row)==tuple:
        try:
            temp_frac = gfrac[row[1]]
        except:
            temp_frac = gint[row[1]]
        try:
            if len(row[0]) == 1:
                temp_int = gint[row[0]]
            elif len(row[0]) == 2:
                temp_int = gint[row[0][0]] + gint[row[0][1]]
            elif row[0] == '':
                temp_int = 0
        except:
            temp_int = None
        return temp_int + temp_frac

# %% [markdown]
# Omega recension

# %%
dfTemp = dfOmega.copy()
dfTemp['longitude'] = dfOmega.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
dfTemp['latitude'] = dfOmega.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-6b0b03b96057> in translate(row)
#       3         try:
# ----> 4             temp_frac = gfrac[row[1]]
#       5         except:
#
# KeyError: 'Î¹Î²'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-7a744b37d761> in <module>
#       1 dfTemp = dfOmega.copy()
# ----> 2 dfTemp['longitude'] = dfOmega.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
#       3 dfTemp['latitude'] = dfOmega.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-53-6b0b03b96057> in translate(row)
#       4             temp_frac = gfrac[row[1]]
#       5         except:
# ----> 6             temp_frac = gint[row[1]]
#       7         try:
#       8             if len(row[0]) == 1:
#
# KeyError: 'Î¹Î²'

# %% [markdown]
# Xi recension

# %%
dfTempX = dfXi.copy()
dfTempX['longitude'] = dfXi.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
dfTempX['latitude'] = dfXi.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-6b0b03b96057> in translate(row)
#       3         try:
# ----> 4             temp_frac = gfrac[row[1]]
#       5         except:
#
# KeyError: 'Î¹Î²'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-c9cc8ae9b131> in <module>
#       1 dfTempX = dfXi.copy()
# ----> 2 dfTempX['longitude'] = dfXi.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
#       3 dfTempX['latitude'] = dfXi.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-13-6b0b03b96057> in translate(row)
#       4             temp_frac = gfrac[row[1]]
#       5         except:
# ----> 6             temp_frac = gint[row[1]]
#       7         try:
#       8             if len(row[0]) == 1:
#
# KeyError: 'Î¹Î²'

# %% [markdown]
# # Data preparation for the map drawing

# %% [markdown]
# ### Coasts and boundaries (Omega)

# %% [markdown]
# Selection of coastal localities

# %%
f = dfTemp[(dfTemp.type_sec == 'coast section') & (dfTemp.type == 'locality') & dfTemp.category.apply(lambda row: row not in ['boundary','river path','river source'])][['longitude','latitude']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-3f3d67153c0b> in <module>
# ----> 1 f = dfTemp[(dfTemp.type_sec == 'coast section') & (dfTemp.type == 'locality') & dfTemp.category.apply(lambda row: row not in ['boundary','river path','river source'])][['longitude','latitude']]
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# c:\users\moha\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['longitude' 'latitude'] not in index"

# %% [markdown]
# Coastal lines

# %%
#fbae = coast of Baetica, omega
baria = dfTemp[dfTemp.toponym == 'ἐφʹ ἧς Βαρεία πόλις '][['longitude','latitude']]
fbae = f.iloc[0:28]
fbae = fbae.append(baria)
fbae = fbae.values

# %%
#flus = coast of Lusitania, omega
flus = f.iloc[28:42].append(f.iloc[0:1]).sort_index(ascending=True)
flus = flus.values

# %%
#ftar = coast of Tarraconensis, omega
ftar1 = f.iloc[42:70].append(f.iloc[41:42]).sort_index(ascending=True)
ftar1 = ftar1.values
ftar2 = f.iloc[70:].sort_index(ascending=False)
baebound = dfTemp[dfTemp.toponym == 'μετὰ τὸ πρὸς τῇ Βαιτικῇ πέρας'][['longitude','latitude']]
ftar2 = ftar2.append(baebound).append(baria)
ftar2 = ftar2.values

# %% [markdown]
# ### Coasts and boundaries (Xi)

# %% [markdown]
# Selection of coastal localities

# %%
g = dfTempX[(dfTempX.type_sec == 'coast section') & (dfTempX.type == 'locality') & dfTempX.category.apply(lambda row: row not in ['boundary','river path','river source'])][['longitude','latitude']]

# %% [markdown]
# Coastal lines

# %%
#gbae = coast of Baetica, xi
bariaX = dfTempX[dfTempX.toponym == 'ἐφʹ ἧς Βαραλία πόλις'][['longitude','latitude']]
gbae = g.iloc[0:26]
gbae = gbae.append(bariaX)
gbae = gbae.values

# %%
#glus = coast of Lusitania, xi
glus = g.iloc[27:41].append(g.iloc[0:1]).sort_index(ascending=True)
glus = glus.values

# %%
#gtar = coast of Tarraconensis, xi
gtar1 = g.iloc[41:68].append(g.iloc[40:41]).sort_index(ascending=True)
gtar1 = gtar1.values
gtar2 = g.iloc[69:].sort_index(ascending=False)
baeboundX = dfTempX[dfTempX.toponym == 'μετὰ τὸ πρὸς τῇ Βαιτικῇ πέρας'][['longitude','latitude']]
gtar2 = gtar2.append(baeboundX).append(bariaX)
gtar2 = gtar2.values

# %%
# make a dictionary for all coasts's lines using Xi for later use in function plot_maps
gs_dict={'gbae' : gbae, 'glus' : glus, 'gtar1' : gtar1, 'gtar2' : gtar2}

# %%
# make a dictionary for all coasts's lines using Omega for later use in function plot_maps
fs_dict={'fbae' : fbae, 'flus' : flus, 'ftar1' : ftar1, 'ftar2' : ftar2}

# %%
# make a dictionary for all data
dfTempt_dic={"dfTemp" : dfTemp,  "dfTempX" : dfTempX}

# %% [markdown]
# # Maps

# %% [markdown]
# ### Omega recension

# %%
plot_maps(fs_dict,dfTempt_dic,'dfTemp','blue','grey','Omega Recension' )
# Out:
#   <div class="bk-root" id="e7fa6fa3-1a67-45a4-9e10-8497740ad1e3"></div>

# %% [markdown]
# ### Xi Recension

# %%
plot_maps(gs_dict,dfTempt_dic,'dfTempX','red','grey','Xi Recension' )
# Out:
#   <div class="bk-root" id="966f21ae-c71a-49cf-b10a-204fac71ca43"></div>

# %% [markdown]
# ## Comparison Ξ and Ω

# %%
a=dfTempX.reset_index(level=['chap_ID','sec_ID','ID'])
a=a[a.longitude.apply(lambda row: row not in [0])]
a=a[['ID','longitude','latitude']].dropna()

b=dfTemp.reset_index(level=['chap_ID','sec_ID','ID'])
b=b[b.longitude.apply(lambda row: row not in [0])]
b=b[['ID','longitude','latitude']].dropna()

c = pd.merge(left=a, right=b,how='inner')

IbEq = c[c["longitude"]==c["longitude"]]
IbEq = IbEq[IbEq["latitude"]==IbEq["latitude"]]

# %%
comp_plot_map_01(fs_dict,gs_dict,dfTempt_dic,IbEq,c)
# Out:
#   <div class="bk-root" id="4372860f-1bb8-47cf-9ce9-4b1903f38e15"></div>

# %%
df_dic=dfTempt_dic

# %%
g2=g.reset_index(level=['chap_ID','sec_ID','ID'])
g2=g2[g2.longitude.apply(lambda row: row not in [0])]
g2=g2[['ID','longitude','latitude']].dropna()

f2=f.reset_index(level=['chap_ID','sec_ID','ID'])
f2=f2[f2.longitude.apply(lambda row: row not in [0])]
f2=f2[['ID','longitude','latitude']].dropna()




k = pd.merge(left=f2, right=g2,how='inner')

IbEq2 = k[k["longitude"]==k["longitude"]]
IbEq2 = IbEq2[IbEq2["latitude"]==IbEq2["latitude"]]

# %%
comp_plot_map_02(fs_dict,gs_dict,f,g,IbEq2)
# Out:
#   <div class="bk-root" id="2fe99108-c438-4d7f-9ff7-782c6b34505d"></div>

# %% [markdown]
# # Interactive Overview of maps

# %%
import  ipywidgets as widgets
from ipywidgets import interact
# Create widgets
directory = widgets.Dropdown(options=['image'])
images = widgets.Dropdown(options=os.listdir(directory.value))

# Updates the image options based on directory value
def update_images(*args):
    images.options = os.listdir(directory.value)

# Tie the image options to directory value
directory.observe(update_images, 'value')

# Show the images
def show_images(fdir, file):
    display(Image(f'{fdir}/{file}'))

_ = interact(show_images, fdir=directory, file=images)
# Out:
# interactive(children=(Dropdown(description='fdir', options=('image',), value='image'), Dropdown(description='f…
