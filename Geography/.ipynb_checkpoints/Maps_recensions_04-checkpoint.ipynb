# %%
from citableclass import Credentials, Citable, Json2DF
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
title = Credentials(authors='olivier.defaux,gerd.grasshoff,malte.vogl', project='geography',title='Maps of the Iberian Peninsula')
title.titlepage()
# Out:
#         <h1>Maps of the Iberian Peninsula</h1>
#         <h2>Olivier Defaux<sup>1,2</sup>, Gerd Grasshoff<sup>1,2</sup>, Malte Vogl<sup>2</sup></h2>
#         1: Humboldt-University, Berlin; 2: Max-Planck-Institute for the History of Science, Berlin<br>
#         Date: 12. August 2019

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from utility import plot_maps,comp_plot_map_01,comp_plot_map_02
from tools import Geography

# %%
from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.io import output_notebook, output_file, save
output_notebook()
from bokeh.models import HoverTool,BoxZoomTool,ResetTool, WheelZoomTool
from bokeh.layouts import row, gridplot, layout
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ecfab881-3093-48d2-a47e-0b5ed7f994ef">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# On the basis of both recensions of the Geography, the localities of the Iberian peninsula are plotted and compared.

# %% [markdown]
# ### Load resources

# %%
cite = Citable('dict_omega.json',formats='local', project='geography')
x1= cite.digitalresource()

cite = Citable('dict_xi.json',formats='local', project='geography')
x2= cite.digitalresource()

# %% [markdown]
# ### Transforming to multi-level dataframes

# %%
init = Json2DF(x1,['book_ID','chap_ID','sec_ID','ID'],level=4)
init.convert()
dfOmega = init.dataframe

init2 = Json2DF(x2,['book_ID','chap_ID','sec_ID','ID'],level=4)
init2.convert()
dfXi = init2.dataframe

# %%
dfOmega
# Out:
#                                                                                  text  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                                   Ἰσπανίας Βαιτικῆς θέσις
#                 2.04.01 2.04.01.01  τῆς Ἰσπανίας κατὰ δὲ Ἕλληνας Ἰβηρίας ...
#                         2.04.01.02       Βαιτικὴ καὶ Λουσιτανία καὶ Ταρρακωνησία
#                 2.04.02 2.04.02.01  καὶ τῆς μὲν Βαιτικῆς ἡ πρὸς δυσμὰς καὶ...
#                         2.04.02.02        ἧς πλευρᾶς ἡ περιγραφὴ ἔχει οὕτως·
#                 2.04.03 2.04.03.01                                                NaN
#                         2.04.03.01                                                NaN
#                         2.04.03.02                                                NaN
#                         2.04.03.03                                                NaN
#                         2.04.03.04                                                NaN
#                         2.04.03.04                                                NaN
#                         2.04.03.07                                                NaN
#                         2.04.03.08                                                NaN
#                 2.04.04 2.04.04.01  ἡ δὲ πρὸς μεσημβρίαν πλευρὰ τῆς Βαιτικῆ...
#                         2.04.04.02  τῷ δὲ Ἰβηρικῷ πελάγει κατὰ τὴν ἐντὸ...
#                         2.04.04.03  καὶ ταύτης δὲ τῆς πλευρᾶς ἡ περιγραφὴ ε...
#                 2.04.05 2.04.05.00  μετὰ τὰς τοῦ Ἄνα ποταμοῦ ἐκβολὰς ἐν τ...
#                         2.04.05.01                                       Τουρδητάνων
#                         2.04.05.04                                                NaN
#                         2.04.05.05                                                NaN
#                         2.04.05.06                                                NaN
#                         2.04.05.07                                                NaN
#                         2.04.05.08                                                NaN
#                         2.04.05.09                                                NaN
#                         2.04.05.10                                                NaN
#                         2.04.05.11                                                NaN
#                         2.04.05.11                                                NaN
#                         2.04.05.12                                                NaN
#                         2.04.05.13                                                NaN
#                 2.04.06 2.04.06.01                Βαστουλῶν τῶν καλουμένων Ποινῶν
# ...                                                                               ...
#         2.06    2.06.72 2.06.72.07                                                NaN
#                         2.06.72.08                                                NaN
#                         2.06.72.09                                                NaN
#                         2.06.72.10                                                NaN
#                         2.06.72.11                                                NaN
#                 2.06.73 2.06.73.01  εἰσὶ δὲ καὶ τῶν μὲν Ἰνδιγετῶν· μεσόγε...
#                         2.06.73.02                                                NaN
#                         2.06.73.03                                                NaN
#                 2.06.74 2.06.74.01            τῶν δὲ Λαιητανῶν· μεσόγειος πόλις·
#                         2.06.74.02                                                NaN
#                 2.06.75 2.06.75.01  νῆσοι δὲ παράκεινται τῇ Ταρρακωνησίᾳ ἐ...
#                         2.06.75.03                                                NaN
#                 2.06.76 2.06.76.01  ἐν δὲ τῷ Δυτικῷ Ὠκεανῷ αἱ Καττιτερί...
#                         2.06.76.02                                                NaN
#                         2.06.76.03                                                NaN
#                 2.06.77 2.06.77.01  ἐν δὲ τῷ Βαλλιαρικῷ πελάγει αἵ τε Πιτ...
#                         2.06.77.03                                                NaN
#                         2.06.77.04                                                NaN
#                         2.06.77.04                                                NaN
#                 2.06.78 2.06.78.01  καὶ αἱ Βαλλιαρίδες νῆσοι δύο· Γυμνήσιαι ...
#                         2.06.78.02          ὧν ἐν μὲν τῇ μείζονι πόλεις δύο·
#                         2.06.78.04                                                NaN
#                         2.06.78.04                                                NaN
#                         2.06.78.05                                                NaN
#                         2.06.78.05                                                NaN
#                         2.06.78.06           ἐν δὲ τῇ ἐλάττονι, πόλεις αἴδε·
#                         2.06.78.07                                                NaN
#                         2.06.78.07                                                NaN
#                         2.06.78.08                                                NaN
#                         2.06.78.08                                                NaN
#
#                                                type_sec      category  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                       title           NaN
#                 2.04.01 2.04.01.01    area presentation           NaN
#                         2.04.01.02    area presentation           NaN
#                 2.04.02 2.04.02.01  borders description           NaN
#                         2.04.02.02  borders description           NaN
#                 2.04.03 2.04.03.01        coast section   river mouth
#                         2.04.03.01        coast section      boundary
#                         2.04.03.02        coast section   river mouth
#                         2.04.03.03        coast section    river path
#                         2.04.03.04        coast section    river path
#                         2.04.03.04        coast section      boundary
#                         2.04.03.07        coast section      boundary
#                         2.04.03.08        coast section  river source
#                 2.04.04 2.04.04.01  borders description           NaN
#                         2.04.04.02  borders description           NaN
#                         2.04.04.03  borders description           NaN
#                 2.04.05 2.04.05.00        coast section           NaN
#                         2.04.05.01        coast section           NaN
#                         2.04.05.04        coast section          city
#                         2.04.05.05        coast section   river mouth
#                         2.04.05.06        coast section   river mouth
#                         2.04.05.07        coast section  river source
#                         2.04.05.08        coast section          city
#                         2.04.05.09        coast section          city
#                         2.04.05.10        coast section       harbour
#                         2.04.05.11        coast section          cape
#                         2.04.05.11        coast section        temple
#                         2.04.05.12        coast section   river mouth
#                         2.04.05.13        coast section          city
#                 2.04.06 2.04.06.01        coast section           NaN
# ...                                                 ...           ...
#         2.06    2.06.72 2.06.72.07               inland          city
#                         2.06.72.08               inland          city
#                         2.06.72.09               inland          city
#                         2.06.72.10               inland          city
#                         2.06.72.11               inland          city
#                 2.06.73 2.06.73.01               inland           NaN
#                         2.06.73.02               inland          city
#                         2.06.73.03               inland          city
#                 2.06.74 2.06.74.01               inland           NaN
#                         2.06.74.02               inland          city
#                 2.06.75 2.06.75.01               island           NaN
#                         2.06.75.03               island        island
#                 2.06.76 2.06.76.01               island           NaN
#                         2.06.76.02               island        island
#                         2.06.76.03               island        island
#                 2.06.77 2.06.77.01               island           NaN
#                         2.06.77.03               island        island
#                         2.06.77.04               island        island
#                         2.06.77.04               island          city
#                 2.06.78 2.06.78.01               island           NaN
#                         2.06.78.02               island           NaN
#                         2.06.78.04               island        island
#                         2.06.78.04               island          city
#                         2.06.78.05               island        island
#                         2.06.78.05               island          city
#                         2.06.78.06               island           NaN
#                         2.06.78.07               island        island
#                         2.06.78.07               island          city
#                         2.06.78.08               island        island
#                         2.06.78.08               island          city
#
#                                                                                 coord  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                                                       NaN
#                 2.04.01 2.04.01.01                                                NaN
#                         2.04.01.02                                                NaN
#                 2.04.02 2.04.02.01                                                NaN
#                         2.04.02.02                                                NaN
#                 2.04.03 2.04.03.01  {'long': {'integer': 'δ', 'fraction': 'ιβ'}, '...
#                         2.04.03.01  {'long': {'integer': 'δ', 'fraction': 'ιβ'}, '...
#                         2.04.03.02  {'long': {'integer': 'δ', 'fraction': 'γ'}, 'l...
#                         2.04.03.03  {'long': {'integer': 'ς', 'fraction': 'γ'}, 'l...
#                         2.04.03.04  {'long': {'integer': 'θ', 'fraction': ''}, 'la...
#                         2.04.03.04  {'long': {'integer': 'θ', 'fraction': ''}, 'la...
#                         2.04.03.07  {'long': {'integer': 'ιβ', 'fraction': ''}, 'l...
#                         2.04.03.08  {'long': {'integer': 'ιδ', 'fraction': ''}, 'l...
#                 2.04.04 2.04.04.01                                                NaN
#                         2.04.04.02                                                NaN
#                         2.04.04.03                                                NaN
#                 2.04.05 2.04.05.00                                                NaN
#                         2.04.05.01                                                NaN
#                         2.04.05.04  {'long': {'integer': 'δ', 'fraction': 'γο'}, '...
#                         2.04.05.05  {'long': {'integer': 'ε', 'fraction': 'ιβ'}, '...
#                         2.04.05.06  {'long': {'integer': 'ε', 'fraction': 'γ'}, 'l...
#                         2.04.05.07  {'long': {'integer': 'ιβ', 'fraction': ''}, 'l...
#                         2.04.05.08  {'long': {'integer': 'ς', 'fraction': ''}, 'la...
#                         2.04.05.09  {'long': {'integer': 'ς', 'fraction': ''}, 'la...
#                         2.04.05.10  {'long': {'integer': 'ς', 'fraction': ''}, 'la...
#                         2.04.05.11  {'long': {'integer': 'ε', 'fraction': 'Lδ'}, '...
#                         2.04.05.11  {'long': {'integer': 'ε', 'fraction': 'Lδ'}, '...
#                         2.04.05.12  {'long': {'integer': 'ς', 'fraction': 'ς'}, 'l...
#                         2.04.05.13  {'long': {'integer': 'ς', 'fraction': 'δ'}, 'l...
#                 2.04.06 2.04.06.01                                                NaN
# ...                                                                               ...
#         2.06    2.06.72 2.06.72.07  {'long': {'integer': 'ιε', 'fraction': 'γο'}, ...
#                         2.06.72.08  {'long': {'integer': 'ις', 'fraction': 'Lδ'}, ...
#                         2.06.72.09  {'long': {'integer': 'ιε', 'fraction': 'L'}, '...
#                         2.06.72.10  {'long': {'integer': 'ις', 'fraction': 'γ'}, '...
#                         2.06.72.11  {'long': {'integer': 'ιε', 'fraction': 'Lγ'}, ...
#                 2.06.73 2.06.73.01                                                NaN
#                         2.06.73.02  {'long': {'integer': 'ιη', 'fraction': 'γο'}, ...
#                         2.06.73.03  {'long': {'integer': 'ιη', 'fraction': 'L'}, '...
#                 2.06.74 2.06.74.01                                                NaN
#                         2.06.74.02  {'long': {'integer': 'ιζ', 'fraction': 'γ'}, '...
#                 2.06.75 2.06.75.01                                                NaN
#                         2.06.75.03  {'long': {'integer': 'θ', 'fraction': ''}, 'la...
#                 2.06.76 2.06.76.01                                                NaN
#                         2.06.76.02  {'long': {'integer': 'δ', 'fraction': ''}, 'la...
#                         2.06.76.03  {'long': {'integer': 'δ', 'fraction': 'γο'}, '...
#                 2.06.77 2.06.77.01                                                NaN
#                         2.06.77.03  {'long': {'integer': 'ιδ', 'fraction': 'Lγ'}, ...
#                         2.06.77.04  {'long': {'integer': 'ιδ', 'fraction': ''}, 'l...
#                         2.06.77.04  {'long': {'integer': 'ιδ', 'fraction': ''}, 'l...
#                 2.06.78 2.06.78.01                                                NaN
#                         2.06.78.02                                                NaN
#                         2.06.78.04  {'long': {'integer': 'ις', 'fraction': 'ς'}, '...
#                         2.06.78.04  {'long': {'integer': 'ις', 'fraction': 'ς'}, '...
#                         2.06.78.05  {'long': {'integer': 'ις', 'fraction': 'Lδ'}, ...
#                         2.06.78.05  {'long': {'integer': 'ις', 'fraction': 'Lδ'}, ...
#                         2.06.78.06                                                NaN
#                         2.06.78.07  {'long': {'integer': 'ιζ', 'fraction': 'ς'}, '...
#                         2.06.78.07  {'long': {'integer': 'ιζ', 'fraction': 'ς'}, '...
#                         2.06.78.08  {'long': {'integer': 'ιζ', 'fraction': 'L'}, '...
#                         2.06.78.08  {'long': {'integer': 'ιζ', 'fraction': 'L'}, '...
#
#                                        people  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN               NaN
#                 2.04.01 2.04.01.01        NaN
#                         2.04.01.02        NaN
#                 2.04.02 2.04.02.01        NaN
#                         2.04.02.02        NaN
#                 2.04.03 2.04.03.01  Turdetani
#                         2.04.03.01  Turdetani
#                         2.04.03.02  Turdetani
#                         2.04.03.03
#                         2.04.03.04
#                         2.04.03.04
#                         2.04.03.07
#                         2.04.03.08
#                 2.04.04 2.04.04.01        NaN
#                         2.04.04.02        NaN
#                         2.04.04.03        NaN
#                 2.04.05 2.04.05.00        NaN
#                         2.04.05.01        NaN
#                         2.04.05.04  Turdetani
#                         2.04.05.05  Turdetani
#                         2.04.05.06  Turdetani
#                         2.04.05.07
#                         2.04.05.08  Turdetani
#                         2.04.05.09
#                         2.04.05.10    Turduli
#                         2.04.05.11    Turduli
#                         2.04.05.11    Turduli
#                         2.04.05.12    Turduli
#                         2.04.05.13    Turduli
#                 2.04.06 2.04.06.01        NaN
# ...                                       ...
#         2.06    2.06.72 2.06.72.07  Iaccetani
#                         2.06.72.08  Iaccetani
#                         2.06.72.09  Iaccetani
#                         2.06.72.10  Iaccetani
#                         2.06.72.11  Iaccetani
#                 2.06.73 2.06.73.01        NaN
#                         2.06.73.02  Indigetes
#                         2.06.73.03  Indigetes
#                 2.06.74 2.06.74.01        NaN
#                         2.06.74.02   Laeetani
#                 2.06.75 2.06.75.01        NaN
#                         2.06.75.03
#                 2.06.76 2.06.76.01        NaN
#                         2.06.76.02
#                         2.06.76.03
#                 2.06.77 2.06.77.01        NaN
#                         2.06.77.03
#                         2.06.77.04
#                         2.06.77.04
#                 2.06.78 2.06.78.01        NaN
#                         2.06.78.02        NaN
#                         2.06.78.04
#                         2.06.78.04
#                         2.06.78.05
#                         2.06.78.05
#                         2.06.78.06        NaN
#                         2.06.78.07
#                         2.06.78.07
#                         2.06.78.08
#                         2.06.78.08
#
#                                                                               toponym  \
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                                                       NaN
#                 2.04.01 2.04.01.01                                                NaN
#                         2.04.01.02                                                NaN
#                 2.04.02 2.04.02.01                                                NaN
#                         2.04.02.02                                                NaN
#                 2.04.03 2.04.03.01     <τὸ δυσμικώτερον στόμα Ἄνα τοῦ ποταμοῦ>
#                         2.04.03.01     <τὸ δυσμικώτερον στόμα Ἄνα τοῦ ποταμοῦ>
#                         2.04.03.02    τὸ ἀνατολικώτερον στόμα Ἄνα τοῦ ποταμοῦ
#                         2.04.03.03      ἡ πρὸς ἀνατολὰς τοῦ ποταμοῦ ἐπιστροφή
#                         2.04.03.04  τὸ πρὸς τῷ πέρατι τῆς Λουσιτανίας τοῦ ...
#                         2.04.03.04  τὸ πρὸς τῷ πέρατι τῆς Λουσιτανίας τοῦ ...
#                         2.04.03.07  καὶ ἡ ἐντεῦθεν γραμμὴ γραφομένη παρὰ τη...
#                         2.04.03.08   αἱ δὲ πηγαὶ τοῦ ποταμοῦ ἐπέχουσι μοίρας
#                 2.04.04 2.04.04.01                                                NaN
#                         2.04.04.02                                                NaN
#                         2.04.04.03                                                NaN
#                 2.04.05 2.04.05.00                                                NaN
#                         2.04.05.01                                                NaN
#                         2.04.05.04                                 Ὄνοβα Λιστουρία
#                         2.04.05.05            <Βαιτίου ποταμοῦ τὸ δυτικὸν στόμα>
#                         2.04.05.06          Βαιτίου ποταμοῦ τὸ ἀνατολικὸν στόμα
#                         2.04.05.07                          αἱ πηγαὶ τοῦ ποταμοῦ
#                         2.04.05.08                       ἡ κατὰ Ἄσταν εἴσχυσις
#                         2.04.05.09                                       Τουρδούλων
#                         2.04.05.10                                  Μενεσθέως λιμήν
#                         2.04.05.11  τὸ ἀκρωτήριον ἀφʹ οὗ ὁ πορθμὸς ἐν ὧ...
#                         2.04.05.11  τὸ ἀκρωτήριον ἀφʹ οὗ ὁ πορθμὸς ἐν ὧ...
#                         2.04.05.12                       Βαίλωνος ποταμοῦ ἐκβολαί
#                         2.04.05.13                                    Βαίλων πόλις
#                 2.04.06 2.04.06.01                                                NaN
# ...                                                                               ...
#         2.06    2.06.72 2.06.72.07                                           Κερέσος
#                         2.06.72.08                                           Βακασίς
#                         2.06.72.09                                           Ἰεσπός
#                         2.06.72.10                                           Ἀνάβις
#                         2.06.72.11                                             Κίννα
#                 2.06.73 2.06.73.01                                                NaN
#                         2.06.73.02                                           Δεκιάνα
#                         2.06.73.03                                        Ἰουγκαρία
#                 2.06.74 2.06.74.01                                                NaN
#                         2.06.74.02                                       Ῥουβρικάτα
#                 2.06.75 2.06.75.01                                                NaN
#                         2.06.75.03                  ὧν τὸ μεταξὺ ἐπέχει μοίρας
#                 2.06.76 2.06.76.01                                                NaN
#                         2.06.76.02                  ὧν τὸ μεταξὺ ἐπέχει μοίρας
#                         2.06.76.03    καὶ αἱ τῶν Θεῶν νῆσοι δύο τὸν ἀριθμόν·
#                 2.06.77 2.06.77.01                                                NaN
#                         2.06.77.03         ὧν ἡ μὲν ἐλάττων καλεῖται Ὀφιοῦσα
#                         2.06.77.04  ἡ δὲ μείζων Ἔβυσσος ἐν ᾗ πόλις ὁμώ...
#                         2.06.77.04  ἡ δὲ μείζων Ἔβυσσος ἐν ᾗ πόλις ὁμώ...
#                 2.06.78 2.06.78.01                                                NaN
#                         2.06.78.02                                                NaN
#                         2.06.78.04                                             Πάλμα
#                         2.06.78.04                                             Πάλμα
#                         2.06.78.05                                         Πολλεντία
#                         2.06.78.05                                         Πολλεντία
#                         2.06.78.06                                                NaN
#                         2.06.78.07                                            Ἴαμνα
#                         2.06.78.07                                            Ἴαμνα
#                         2.06.78.08                                              Μαγώ
#                         2.06.78.08                                              Μαγώ
#
#                                                     type
# book_ID chap_ID sec_ID  ID
# 2       2.04    2.04.00 NaN                          NaN
#                 2.04.01 2.04.01.01           text string
#                         2.04.01.02           text string
#                 2.04.02 2.04.02.01           text string
#                         2.04.02.02           text string
#                 2.04.03 2.04.03.01              locality
#                         2.04.03.01              locality
#                         2.04.03.02              locality
#                         2.04.03.03              locality
#                         2.04.03.04              locality
#                         2.04.03.04              locality
#                         2.04.03.07              locality
#                         2.04.03.08              locality
#                 2.04.04 2.04.04.01           text string
#                         2.04.04.02           text string
#                         2.04.04.03           text string
#                 2.04.05 2.04.05.00  section introduction
#                         2.04.05.01                people
#                         2.04.05.04              locality
#                         2.04.05.05              locality
#                         2.04.05.06              locality
#                         2.04.05.07              locality
#                         2.04.05.08              locality
#                         2.04.05.09              locality
#                         2.04.05.10              locality
#                         2.04.05.11              locality
#                         2.04.05.11              locality
#                         2.04.05.12              locality
#                         2.04.05.13              locality
#                 2.04.06 2.04.06.01                people
# ...                                                  ...
#         2.06    2.06.72 2.06.72.07              locality
#                         2.06.72.08              locality
#                         2.06.72.09              locality
#                         2.06.72.10              locality
#                         2.06.72.11              locality
#                 2.06.73 2.06.73.01  section introduction
#                         2.06.73.02              locality
#                         2.06.73.03              locality
#                 2.06.74 2.06.74.01  section introduction
#                         2.06.74.02              locality
#                 2.06.75 2.06.75.01  section introduction
#                         2.06.75.03              locality
#                 2.06.76 2.06.76.01  section introduction
#                         2.06.76.02              locality
#                         2.06.76.03              locality
#                 2.06.77 2.06.77.01  section introduction
#                         2.06.77.03              locality
#                         2.06.77.04              locality
#                         2.06.77.04              locality
#                 2.06.78 2.06.78.01  section introduction
#                         2.06.78.02  section introduction
#                         2.06.78.04              locality
#                         2.06.78.04              locality
#                         2.06.78.05              locality
#                         2.06.78.05              locality
#                         2.06.78.06  section introduction
#                         2.06.78.07              locality
#                         2.06.78.07              locality
#                         2.06.78.08              locality
#                         2.06.78.08              locality
#
# [660 rows x 7 columns]

# %% [markdown]
# ### Translate greek to decimal coordinates

# %%
def reformatCoord(row,longLat, xy='coord_x'):
    if type(row[xy]) == dict:
        return (row[xy][longLat]['integer'].strip(),row[xy][longLat]['fraction'].strip())
    else:
        return False

# %%
gfrac={"":0,"Lς":2/3,"ςL":2/3,"ιβ":1/12,"ς":1/6,"δ":1/4,"γ":1/3,"γιβ":5/12,"L":1/2,"Lιβ":7/12,"γο":2/3,"Lδ":3/4,"Lγ":5/6,"Lγιβ":11/12,"η":1/8}
gint={"":0,"α":1,"β":2,"γ":3,"δ":4,"ε":5,"ς":6,"ζ":7,"η":8,"θ":9,"ι":10,"κ":20,"λ":30,"μ":40}

# %%
def translate(row):
    if type(row)==tuple:
        try:
            temp_frac = gfrac[row[1]]
        except:
            temp_frac = gint[row[1]]
        try:
            if len(row[0]) == 1:
                temp_int = gint[row[0]]
            elif len(row[0]) == 2:
                temp_int = gint[row[0][0]] + gint[row[0][1]]
            elif row[0] == '':
                temp_int = 0
        except:
            temp_int = None
        return temp_int + temp_frac

# %% [markdown]
# Omega recension

# %%
dfTemp = dfOmega.copy()
dfTemp['longitude'] = dfOmega.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
dfTemp['latitude'] = dfOmega.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)

# %% [markdown]
# Xi recension

# %%
dfTempX = dfXi.copy()
dfTempX['longitude'] = dfXi.apply(lambda row: reformatCoord(row,'long','coord'),axis=1).apply(translate)
dfTempX['latitude'] = dfXi.apply(lambda row: reformatCoord(row,'lat','coord'),axis=1).apply(translate)

# %% [markdown]
# # Data preparation for the map drawing

# %% [markdown]
# ### Coasts and boundaries (Omega)

# %% [markdown]
# Selection of coastal localities

# %%
f = dfTemp[(dfTemp.type_sec == 'coast section') & (dfTemp.type == 'locality') & dfTemp.category.apply(lambda row: row not in ['boundary','river path','river source'])][['longitude','latitude']]

# %% [markdown]
# Coastal lines

# %%
#fbae = coast of Baetica, omega
baria = dfTemp[dfTemp.toponym == 'ἐφʹ ἧς Βαρεία πόλις '][['longitude','latitude']]
fbae = f.iloc[0:28]
fbae = fbae.append(baria)
fbae = fbae.values

# %%
#flus = coast of Lusitania, omega
flus = f.iloc[28:42].append(f.iloc[0:1]).sort_index(ascending=True)
flus = flus.values

# %%
#ftar = coast of Tarraconensis, omega
ftar1 = f.iloc[42:70].append(f.iloc[41:42]).sort_index(ascending=True)
ftar1 = ftar1.values
ftar2 = f.iloc[70:].sort_index(ascending=False)
baebound = dfTemp[dfTemp.toponym == 'μετὰ τὸ πρὸς τῇ Βαιτικῇ πέρας'][['longitude','latitude']]
ftar2 = ftar2.append(baebound).append(baria)
ftar2 = ftar2.values

# %% [markdown]
# ### Coasts and boundaries (Xi)

# %% [markdown]
# Selection of coastal localities

# %%
g = dfTempX[(dfTempX.type_sec == 'coast section') & (dfTempX.type == 'locality') & dfTempX.category.apply(lambda row: row not in ['boundary','river path','river source'])][['longitude','latitude']]

# %% [markdown]
# Coastal lines

# %%
#gbae = coast of Baetica, xi
bariaX = dfTempX[dfTempX.toponym == 'ἐφʹ ἧς Βαραλία πόλις'][['longitude','latitude']]
gbae = g.iloc[0:26]
gbae = gbae.append(bariaX)
gbae = gbae.values

# %%
#glus = coast of Lusitania, xi
glus = g.iloc[27:41].append(g.iloc[0:1]).sort_index(ascending=True)
glus = glus.values

# %%
#gtar = coast of Tarraconensis, xi
gtar1 = g.iloc[41:68].append(g.iloc[40:41]).sort_index(ascending=True)
gtar1 = gtar1.values
gtar2 = g.iloc[69:].sort_index(ascending=False)
baeboundX = dfTempX[dfTempX.toponym == 'μετὰ τὸ πρὸς τῇ Βαιτικῇ πέρας'][['longitude','latitude']]
gtar2 = gtar2.append(baeboundX).append(bariaX)
gtar2 = gtar2.values

# %%
# make a dictionary for all coasts's lines using Xi for later use in function plot_maps
gs_dict={'gbae' : gbae, 'glus' : glus, 'gtar1' : gtar1, 'gtar2' : gtar2}

# %%
# make a dictionary for all coasts's lines using Omega for later use in function plot_maps
fs_dict={'fbae' : fbae, 'flus' : flus, 'ftar1' : ftar1, 'ftar2' : ftar2}

# %%
# make a dictionary for all data
df_dict={"dfTemp" : dfTemp,  "dfTempX" : dfTempX}

# %% [markdown]
# # Maps

# %% [markdown]
# ### Omega recension

# %%
fig=Geography(fs_dict,gs_dict,df_dict)

# %%
fig._plot_recension(fs_dict,gs_dict,df_dict,title='Omega')
# Out:
#   <div class="bk-root" id="825eff4b-0829-4f41-8ff1-c15400410314"></div>

# %% [markdown]
# ### Xi Recension

# %%
fig._plot_recension(fs_dict,gs_dict,df_dict,title='Xi')
# Out:
#   <div class="bk-root" id="ba4dff45-b79e-42c1-866f-b36f6278147e"></div>

# %% [markdown]
# ## Comparison Ξ and Ω

# %%
fig._plot_compare_recension(fs_dict,gs_dict,df_dict)
# Out:
#   <div class="bk-root" id="9328868b-27bb-4d4e-b498-14addf282b3a"></div>

# %%
fig._plot_border_compare_recension(fs_dict,gs_dict,df_dict)
# Out:
#   <div class="bk-root" id="f04db851-4cd7-42e4-ba3a-54e3aff8f0dc"></div>

# %% [markdown]
# # Interactive Overview of maps

# %%
import os 
import  ipywidgets as widgets
from ipywidgets import interact
from IPython.display import Image
import os
# Create widgets
directory = widgets.Dropdown(options=['image'])
images = widgets.Dropdown(options=os.listdir(directory.value))

# Updates the image options based on directory value
def update_images(*args):
    images.options = os.listdir(directory.value)

# Tie the image options to directory value
directory.observe(update_images, 'value')

# Show the images
def show_images(fdir, file):
    display(Image(f'{fdir}/{file}'))

_ = interact(show_images, fdir=directory, file=images)
# Out:
# interactive(children=(Dropdown(description='fdir', options=('image',), value='image'), Dropdown(description='f…
