# %% [markdown]
#  # Regex and Prodigy (LABEL: LONG)

# %% [markdown]
# <font size= "3">
# Annotation of entities for sentences based on prodigy's format for different labels for further usage in Machine learning. Prodigy is an annotation tool based on spaCy. Please see here:
#     </p>
#   <a href="https://prodi.gy/ "> Prodigy </a>
# <font 3>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import re
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import spacy 
import re
from prodigy.util import write_jsonl

# %%
pwd
# Out:
# 'C:\\Users\\moha\\Documents\\vorlesung2019\\notebooks\\yeghaneh\\ml'

# %% [markdown]
# ## Read the Data

# %%
importVersion = '013'

# %%
path= '../data/01_df_v{0}.pickle'.format(importVersion)# Put the path of the data in your local machine here, consider the letter "r" before the path
dfAstroNova = pd.read_pickle(path)

# %%
type(dfAstroNova)
# Out:
# pandas.core.frame.DataFrame

# %%
dfAstroNova.head(5)
# Out:
#                                                 html  \
# 0                                  <p>Appendix B</p>
# 1  <p><span class="anchor" id="bookmark0"></span>...
# 2  <p>by Yaakov Zik <span style="font-variant: sm...
# 3  <p><span class="anchor" id="bookmark1"></span>...
# 4                              <p>General notes:</p>
#
#                                                 text links italic     chapter  \
# 0                                         Appendix B    []     []  appendix b
# 1          On the Table of Oppositions in Chapter 15    []     []  appendix b
# 2                             by Yaakov Zik Table i:    []     []  appendix b
# 3  Initial positions of Mars in Chapter 15 comput...    []     []  appendix b
# 4                                     General notes:    []     []  appendix b
#
#   graphic table marginal                                          sentences  \
# 0      []    []       []                                       [Appendix B]
# 1      []    []       []        [On the Table of Oppositions in Chapter 15]
# 2      []    []       []                           [by Yaakov Zik Table i:]
# 3      []    []       []  [Initial positions of Mars in Chapter 15 compu...
# 4      []    []       []                                   [General notes:]
#
#                                               tagged
# 0                    [[(Appendix, None), (B, None)]]
# 1  [[(On, None), (the, None), (Table, None), (of,...
# 2  [[(by, None), (Yaakov, None), (Zik, None), (Ta...
# 3  [[(Initial, None), (positions, None), (of, Non...
# 4                 [[(General, None), (notes, None)]]

# %%
len(dfAstroNova)
# Out:
# 1605

# %%
len(dfAstroNova['tagged'] )
# Out:
# 1605

# %% [markdown]
# ### Read the Sentences

# %%
df=dfAstroNova.sentences

# %%
texts=[]
for sen in dfAstroNova.sentences:
    texts +=sen

# %%
texts[0:10]
# Out:
# ['Appendix B',
#  'On the Table of Oppositions in Chapter 15',
#  'by Yaakov Zik Table i:',
#  'Initial positions of Mars in Chapter 15 computed with Guide 9 using JPL DE430.',
#  'General notes:',
#  "The time is measured from midnight; Gregorian dates are obtained by adding 10 days to Kepler's dates.",
#  'The dates are given in old style.',
#  'Geographical coordinates: Uraniborg 12 41 46 E, 55 54 30 N [50m]; Wandesburg (Wandsbek-Hamburg) 10 05 53 E, 53 35 10 N [15m]; Prague 14 26 E, 53 35 10 N [250m].',
#  'The longitudes are given in geocentric ecliptic coordinates.',
#  '1 2345']

# %% [markdown]
# ## Annotation Based on Consistant format with Prodigy

# %% [markdown]
# <fig size= 3>
# Prodigy accept a specific format; a JSONL format (newline-delimited JSON). Entities and other highlighted spans of text can be defined in the "spans" property. A example could look like this dictionary:
# </p>
# text': 'On 1595 October 30 at 8h 20m, they found Mars at 17° 48’ Taurus, with a diurnal motion of 22’ 54” ^15.',
#   'spans': [{'start': 22, 'end': 29, 'label': 'TIME'}]}
# </p>
# which start and end's numbers refer to the position of entitiy  in the sentence. (here PARA)
#
#
# <fig size>

# %%
label = "LONG"   
texts = texts  
regex_patterns = [
re.compile(r'(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?')           
                 ]
 
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)              

write_jsonl("NER_LONG_04.jsonl", examples)

# %% [markdown]
# ## See Misaligned Tokens

# %% [markdown]
# <fig size= 3>
# This step is very important, since if Pordigy faces with Misaligned tokens, we can see that before and try to adjust regex accordingly
# <fig size>

# %%
nlp = spacy.load("en_core_web_sm")  
for example in examples:  
    doc = nlp(example["text"])
    for span in example["spans"]:
        char_span = doc.char_span(span["start"], span["end"])
        if char_span is None:  
            print("Misaligned tokens", example["text"], span)

# %%
examples [0:1000]  # here we can search for Misaligned Tokens and try to find a remedy by regex
# Out:
# [{'text': 'Appendix B', 'spans': []},
#  {'text': 'On the Table of Oppositions in Chapter 15', 'spans': []},
#  {'text': 'by Yaakov Zik Table i:', 'spans': []},
#  {'text': 'Initial positions of Mars in Chapter 15 computed with Guide 9 using JPL DE430.',
#   'spans': []},
#  {'text': 'General notes:', 'spans': []},
#  {'text': "The time is measured from midnight; Gregorian dates are obtained by adding 10 days to Kepler's dates.",
#   'spans': []},
#  {'text': 'The dates are given in old style.', 'spans': []},
#  {'text': 'Geographical coordinates: Uraniborg 12 41 46 E, 55 54 30 N [50m]; Wandesburg (Wandsbek-Hamburg) 10 05 53 E, 53 35 10 N [15m]; Prague 14 26 E, 53 35 10 N [250m].',
#   'spans': []},
#  {'text': 'The longitudes are given in geocentric ecliptic coordinates.',
#   'spans': []},
#  {'text': '1 2345', 'spans': []},
#  {'text': 'Table 2:', 'spans': []},
#  {'text': 'Table of oppositions of Mars, 1580-1604', 'spans': []},
#  {'text': 'COMPUTED WITH GUIDE 9 USING JPL DE43O.', 'spans': []},
#  {'text': 'Compare with the table at the end of Chapter 15 (reproduced below).',
#   'spans': []},
#  {'text': 'Longitudes are given in geocentric ecliptic coordinates; dates are in old style.',
#   'spans': []},
#  {'text': "Kepler's table, for comparison", 'spans': []},
#  {'text': 'Mars from Earth to be a little greater than half of the distance of the Sun from Earth.',
#   'spans': []},
#  {'text': 'Kepler computed the diurnal latitudinal parallax of Mars to be 3\' 28", from which he determined the latitude of Mars without parallax to be 2° 25\'.',
#   'spans': []},
#  {'text': 'Since Mars\'s distance from the nonagesimal was 56° and its ecliptic latitude 2° 25\', Kepler computed the value of the diurnal longitudinal parallax (i.e., the difference between Mars\'s distance from the nonagesimal and its ecliptic longitude) to be 3\' 32" ^6.',
#   'spans': []},
#  {'text': 'Kepler\'s computations for the latitudinal and longitudinal parallax resulted in positions for Mars\'s ecliptic longitude of 198° 21\' 30" (18° 21\' 30" Libra), and its latitude 2° 21\' 30".',
#   'spans': []},
#  {'text': "The longitude of the true Sun was at 19° 20' 8' Aries (Figure 2A).",
#   'spans': []},
#  {'text': 'The deviation of elongation between Mars and the Sun was 58\' 38".',
#   'spans': []},
#  {'text': 'Kepler determined the diurnal motions of the Sun and Mars to be 58\' 38" and 22\' 36" respectively, and the sum of the diurnal motions was 1° 21\' 14".',
#   'spans': []},
#  {'text': 'With the sum of the diurnal motions of Mars and the Sun (1° 21\' 14"), Kepler computed the time it takes for Mars and the Sun to move 58\' 38", that is, about 17 hours 20 minutes.',
#   'spans': []},
#  {'text': 'As shown in Figure 2B, the Sun is assumed to be at the center of the planetary system.',
#   'spans': []},
#  {'text': 'The longitudes of Mars and Earth\'s in reference to the center of the Sun are 198° 21\' 30" and 199° 20\' 8" respectively.',
#   'spans': []},
#  {'text': 'The deviation of elongation between Mars and the Earth remain 58\' 38".',
#   'spans': []},
#  {'text': 'To find the position of Mars at opposition, Kepler computed the angular distance that Mars and Earth—now substituting the place of the Sun—moved during 17 hours 20 minutes; Mars moved eastward about 16\' 20" and the Sun westward about 42\' 18".',
#   'spans': []},
#  {'text': 'Accordingly, Kepler determined the longitude of Mars at opposition to be 198° 37\' 50" from which he subtracted about 39" in order to correct Mars\'s orbit; he got 198° 37\' 10" (18° 37\' 10" Libra).',
#   'spans': []},
#  {'text': 'The Sun moved westward and its longitude decreased from the time of observation to its position opposite to Mars.',
#   'spans': []},
#  {'text': 'Therefore, the time of opposition is 17 hours 20 minutes before March 29, at 21:43, the time when the observation was made.',
#   'spans': []},
#  {'text': 'Kepler determined the time of opposition on March 28, 4h 23m AM, old style.',
#   'spans': []},
#  {'text': 'Chapter 1', 'spans': []},
#  {'text': 'On the distinction between the first motion and the second or proper motions; and in the proper motions, between the first and the second inequality.',
#   'spans': []},
#  {'text': 'The testimony of the ages confirms that the motions of the planets are orbicular.',
#   'spans': []},
#  {'text': 'Reason, having borrowed from experience, immediately presumes this: that their gyrations are perfect circles.',
#   'spans': []},
#  {'text': 'For among figures it is circles, and among bodies the heavens, that are considered the most perfect.',
#   'spans': []},
#  {'text': 'However, when experience seems to teach something different to those who pay careful attention, namely, that the planets deviate from a simple circular path, it gives rise to a powerful sense of wonder, which at length drives people to look into causes.',
#   'spans': []},
#  {'text': 'It is just this from which astronomy arose among humans.',
#   'spans': []},
#  {'text': "Astronomy's aim is considered to be to show why the stars' motions appear to be irregular on earth, despite their being exceedingly well ordered in heaven, and to investigate the specific circles whereby the stars may be moved, so that by their aid the positions and appearances of those stars at any given time may be predicted.",
#   'spans': []},
#  {'text': 'Before the distinction between the first motion(1) and the second motions(2) was established, people noted (in contemplating the sun, moon and stars) that their diurnal paths were visually very nearly equivalent to circles.',
#   'spans': []},
#  {'text': 'These were, however, entwined one upon another like yarn on a ball, and the circles were for the most part smaller(3) circles of the sphere, rarely the greatest(4) (such',
#   'spans': []},
#  {'text': 'as here ABCE, FMNG cutting the equator AB in CN), part of them north and part south.',
#   'spans': []},
#  {'text': 'They also saw that the stars have different speeds in this diurnal and apparent motion.',
#   'spans': []},
#  {'text': 'The fixed stars are fastest of all, since those that are in conjunction with any of the planets on the preceding day (such as H with A and F) come to their setting first (such as H, moving along LK back to I).',
#   'spans': []},
#  {'text': 'The sun (on ABE) is slower, as on the following day it stands at E and so its setting follows that of the fixed stars at I with which on the previous day it was conjoined on HA.',
#   'spans': []},
#  {'text': 'Slower still than this, slowest of all the stars, is the moon, since after setting with the sun today (at A, the moon being at F), it lags by an appreciable interval (EG) tomorrow when the sun sets (at E, the whole heaven and the moon along with it having made a circuit around the earth along FMNOG).',
#   'spans': []},
#  {'text': 'Hence the Pythagoreans, when they shared out musical tones among the stars, gave the lowest (the hypate among the strings of the lyre)1 to the moon, because the motions of both were slowest.',
#   'spans': []},
#  {'text': 'Hence have originated the words προηγούμενος and ὑπολειπτικός ^2.',
#   'spans': []},
#  {'text': 'The former of these terms originally corresponded to a star which, on the next day, comes to its setting earlier (the sun E is said to be προηγούμενος with respect to the moon G).',
#   'spans': []},
#  {'text': 'The latter term corresponded to a star that is slower in the first motion (such as the moon here), which is, as it were, abandoned and left behind (at G) by the swifter ones (E and I).',
#   'spans': []},
#  {'text': 'For more on this subject see our Optics, Ch.', 'spans': []},
#  {'text': '10.', 'spans': []},
#  {'text': '3', 'spans': []},
#  {'text': 'This first adumbration of astronomy consists, not of the unfolding of a cause, but solely of the experience of the eyes, extremely slowly acquired.',
#   'spans': []},
#  {'text': 'It cannot be explained in figures or numbers, nor can it be extrapolated into the future, since it is always different from itself, to the extent that no spiral is equal to any other in increments of time, and none carries over into the next with a curvature of the same quantity.',
#   'spans': []},
#  {'text': "Nevertheless, there are some people today who, riding roughshod over two thousand years' work, care, erudition, and knowledge, are trying to revive this, obtruding admiration of themselves far and wide (an attempt which has not been fruitless among the ignorant).",
#   'spans': []},
#  {'text': 'Those with more experience consider them with good reason to be incompetent, or (if, like that man Patricius,4 they want to be known as philosophers) to act mad with reasoning.',
#   'spans': []},
#  {'text': 'For it was helpful to astronomers to understand that two simple motions, the first one and the second ones, the common and the proper, are intermingled, and that from this mingling that continuous sequence of conglomerated motions follows.',
#   'spans': []},
#  {'text': 'And so, when that common and extrinsically derived diurnal revolving effect is removed, the fixed stars are suddenly no longer the swiftest and the moon slowest, but quite the opposite, the latter being the swiftest in itself and in its proper motion FG while the former are clearly very slow or immobile.',
#   'spans': []},
#  {'text': 'When a planet (such as the moon at G) is "left behind" (by the sun at E or the fixed stars at I), it is carried in consequence*  through FG more swiftly than the sun (through AE) or the fixed stars (through HI).',
#   'spans': []},
#  {'text': "It, however, it appears to be 'leading' among the fixed stars, it goes along with a retrograde motion.",
#   'spans': []},
#  {'text': 'For example, if the sun at A along with a fixed star at H had been released from the same starting line AH on the previous day, so as to traverse BCDE and arrive at P while the fixed star traversed HLK and arrived at I, the sun, in the space of one day, would have retrogressed through the interval AP.',
#   'spans': []},
#  {'text': 'This turned out to be of great profit in astronomy in grasping the simplicity  of the motions.',
#   'spans': []},
#  {'text': "Instead of unending spirals, a new one always being added to the end of the earlier one at E or G, there remained little but the solitary circles FG and AE, and a single common motion, either of all the planets and the whole world as well in a direction opposite to the proper motions, or (with the world standing still, according to Aristarchus) of the earth's globe T around the axis QR in the same direction as the proper motions.",
#   'spans': []},
#  {'text': 'Now that the first and diurnal motion had thus been set aside, and only those motions that are apprehended by comparison over a period of days, and that belong to the planets individually, were considered, there appeared in these motions a much more complicated mingling than before, when the diurnal and common motion was still mixed in with them.',
#   'spans': []},
#  {'text': 'For although this residual mingling was there before, it was less observed—less striking to the eyes—because the diurnal motion was very swift.',
#   'spans': []},
#  {'text': 'And so this residual motion was divided into minute parts and spread out over several days and several diurnal spirals.',
#   'spans': []},
#  {'text': "But now, that minute division and distribution of the star's proper motions over so many days was removed (that is, by the removal of the diurnal motion), and so all the proper motions of the stars, as many as they are, and all the confusion of this multitude shone forth more obviously.",
#   'spans': []},
#  {'text': 'First, it was apparent that the three superior planets, Saturn, Jupiter, and Mars, attune their motions to their proximity to the sun.',
#   'spans': []},
#  {'text': 'For if the sun would approach them they moved forward and were swifter than usual; where the sun would come to the signs opposite the planets they retraced with crablike steps the road they had just covered; between these two times they became stationary; and these things always used to occur, no matter what the signs of the zodiac in which the planets might have been seen.',
#   'spans': []},
#  {'text': 'At the same time, it was clear to the eye that the planets appeared large when retrograde, and small when anticipating the coming of the sun with a direct and swift motion.',
#   'spans': []},
#  {'text': 'From this, the conclusion was easily reached that when the sun approaches they are raised up and recede from the lands, and when the sun departs towards the opposite signs they descend again towards the lands ^5.',
#   'spans': []},
#  {'text': 'And finally, it was observed that these phenomena of retrogressions and increase of luminosity, just described, was moved through the signs of the zodiac in the order that tended from west through the meridian eastward, so that whatever has happened at one time in Pisces soon would come to pass similarly in Aries, then in Taurus, and so on in consequence.',
#   'spans': []},
#  {'text': 'If one were to bundle all this together, and were at the same time to believe that the sun really moves through the zodiac in the space of a year, as Ptolemy and Tycho Brahe believed, he would then have to grant that the circuits of the three superior planets through the aethereal space, composed as they are of several motions, are real spirals, not (as before) in the manner of balled up yarn, with spirals set side by side, but more like the shape of a pretzel,6 as in the following diagram.',
#   'spans': []},
#  {'text': 'This is the accurate depiction of the motions of the star Mars, which it traversed through the aethereal air from the year 1580 until the year 1596, on the assumption that the earth stands still, as Ptolemy and Brahe would have it.',
#   'spans': []},
#  {'text': 'These motions, continued farther, would become unintelligibly intricate, for the continuation is boundless, never returning to its previous path.',
#   'spans': []},
#  {'text': 'Take note, too, that since the orb of Mars requires such a vast space, the spheres of the sun, Venus, Mercury, the moon, fire, air, water, and earth, have to be included in the tiny little circle around the earth A, and in its little area B. In addition, the greatest part even of this little space is given to Venus alone, much greater in proportion than is given to Mars here out of the whole area of the diagram.',
#   'spans': []},
#  {'text': 'Moreover, we are forced to ascribe similar spirals to the remaining four planets, and much more complicated ones to Venus, if the earth stands still.',
#   'spans': []},
#  {'text': "Ptolemy and Brahe offer explanations of the causes, order, permanence, and regularity of these spirals, the former using individual epicycles carried around on the eccentrics of the individual planets, in imitation of the sun's motion, and the latter by having all the eccentrics carried around upon the single orb of the sun.",
#   'spans': []},
#  {'text': 'Nevertheless, both leave the spirals themselves in the heavens.',
#   'spans': []},
#  {'text': 'Copernicus, by attributing a single annual motion to the earth, entirely rids all the planets of these extremely intricate spirals, leading the individual planets into their respective orbits7 quite bare and very nearly circular.',
#   'spans': []},
#  {'text': "In the period of time shown in the diagram, Mars traverses one and the same orbit as many times as the 'garlands' you see looped towards the center, with one extra, making, say, nine times, while at the same time the earth repeats its circle sixteen times.",
#   'spans': []},
#  {'text': "Again, however, it was noticed that these loops in each planet's spirals are unequal in different signs of the zodiac, so that in some places the planet would retrogress through a longer arc of the zodiac, at others through a shorter, and now for a longer, now for a shorter time.",
#   'spans': []},
#  {'text': 'Nor is the increment of brightness of a retrograde planet always the same.',
#   'spans': []},
#  {'text': 'Because, if one were to compute the times and distances between the midpoints of the retrogressions, neither times nor arcs would be equal, nor would any of the times answer to its arc in the same proportion.',
#   'spans': []},
#  {'text': 'Nevertheless, for each planet there was a certain sign of the zodiac from which, through the semicircle to the opposite sign in either direction, all those things successively increased.',
#   'spans': []},
#  {'text': "From these observations it came to be understood that for any planet there are two inequalities mixed together into one, the first of which completes its cycle with the planet's return to the same sign of the zodiac, the other with the sun's return to the planet.",
#   'spans': []},
#  {'text': 'Now the causes and measures of these inequalities could not be investigated without separating the mixed inequalities and looking into each one by itself.',
#   'spans': []},
#  {'text': "They therefore thought they should begin with the first inequality, it being more nearly constant and simple, since they saw an example of it in the sun's motion, without the interference of the other inequality.",
#   'spans': []},
#  {'text': 'But in order to separate the second inequality from this first one, they could not do anything but consider the planets on those nights at whose beginning they rise while the sun is setting, which thence were called ἀκρονυχίους [acronychal, or  "night rising"].',
#   'spans': []},
#  {'text': 'For since the presence and conjunction of the sun makes them go faster than usual, and the opposition of the sun has the opposite effect, before and after these points they are surely much removed from the positions they were going to occupy through the action of the first inequality.',
#   'spans': []},
#  {'text': 'Therefore, at the very moments of conjunction with and opposition to the sun they are traversing those very positions that are their own.',
#   'spans': []},
#  {'text': 'But since they cannot be seen when in conjunction with the sun, only the opposition to the sun remains as suitable for this purpose.',
#   'spans': []},
#  {'text': "But since the sun's mean and apparent motions*  are two different things, for the sun, too, is subject to the first inequality, the question is raised which of these releases the planets from the second inequality, and whether the planets should be considered when at opposition to the sun's apparent position or its mean position.",
#   'spans': []},
#  {'text': "Ptolemy chose the mean motion, thinking that the difference (if any) between taking the mean sun and the apparent sun could not be perceived in the observations, but that the form of computation and of the proofs would become free from difficulty if the sun's mean motion were taken.",
#   'spans': []},
#  {'text': 'Copernicus and Tycho followed Ptolemy, carrying over his assumptions.',
#   'spans': []},
#  {'text': 'I, as you see in Ch.', 'spans': []},
#  {'text': '15 of my Mysterium cosmographicum, instead establish the apparent position, the true body of the sun, as my reference point, and will vindicate that position with proofs in Parts 4 and 5 of this work.',
#   'spans': []},
#  {'text': "But before that, I shall prove in this first part that one who substitutes the sun's apparent for its mean motion establishes a completely different orbit for the planet in the aether, whichever of the more celebrated opinions of the world he follows.",
#   'spans': []},
#  {'text': 'Since this proof depends upon the equivalence of hypotheses, we shall begin with this equivalence.',
#   'spans': []},
#  {'text': 'Chapter 10', 'spans': []},
#  {'text': 'Consideration of the observations themselves, with which Tycho Brahe hunted for the moments of opposition to the mean sun.',
#   'spans': []},
#  {'text': 'In an enquiry of such precision, I could not have foregone a deeper inspection of the foundations themselves.',
#   'spans': []},
#  {'text': 'And Brahe had given me the opportunity to make use of his observations.',
#   'spans': []},
#  {'text': 'This is what I found.', 'spans': []},
#  {'text': 'On 1580 November 12 at 10h 50m,1 they set Mars down at 8° 36’ 50” Gemini2 without mentioning the horizontal variations,  by which term I wish the diurnal parallaxes and the refractions to be understood in what follows.',
#   'spans': []},
#  {'text': 'Now this observation is distant and isolated.', 'spans': []},
#  {'text': 'It was reduced to the moment of opposition using the diurnal motion from the Prutenic Tables ^3.',
#   'spans': []},
#  {'text': 'For in Maestlin,4 on the twelfth at noon, Mars is put at 8° 20’ Gemini, and on the seventeenth, again at noon, it is at 6° 25’ Gemini.',
#   'spans': []},
#  {'text': 'Therefore, the motion over five whole days would be 1° 55’.',
#   'spans': []},
#  {'text': 'In Stadius,5 it is 1° 52’.', 'spans': []},
#  {'text': 'Therefore, on the seventeenth at the same hour of 10h 50m, Mars ought to have been seen at either 6° 41’ 50” Gemini, or 6° 44’ 50”.',
#   'spans': []},
#  {'text': 'At 9h 40m (which Tycho gives as the moment of opposition), it is 1’ 4” farther forward, at either 6° 42’ 54” or 6° 45’ 54”.',
#   'spans': []},
#  {'text': 'They put it at 6° 46’ 10” Gemini.', 'spans': []},
#  {'text': 'You see that this opposition (as regards exactness) is a little more uncertain because it makes use of a diurnal motion which is not observed but imported from elsewhere, and about which the different authors differ from one another by three minutes over these five days.',
#   'spans': []},
#  {'text': 'On 1582 December 28 at 11h 30m, they set Mars down at 16° 47’ Cancer by observation ^6.',
#   'spans': []},
#  {'text': 'The moment of opposition assigned by Tycho comes 46 minutes later, during which the planet retrogressed less than one minute.',
#   'spans': []},
#  {'text': 'Tycho therefore puts it at 16° 46’ 16” Cancer ^7.', 'spans': []},
#  {'text': 'On an inserted sheet here, an attempt was made to correct for a refraction of two minutes.',
#   'spans': []},
#  {'text': 'This was, I think, first trial of the theory of refraction then being developed.',
#   'spans': []},
#  {'text': 'Nevertheless, he followed the observed value unchanged, thus declining to consider the planet as something which could alter its position.',
#   'spans': []},
#  {'text': 'Nor was there any need for  correction, since it was in Cancer, beyond the reach of refraction, and was in mid-sky where, in Cancer, there is no longitudinal parallax.',
#   'spans': []},
#  {'text': 'On 1585 January 31 at 12h 0m, Mars was placed at 21° 18’ 11” Leo ^8.',
#   'spans': []},
#  {'text': 'The diurnal motion, by comparison of observations, was 24’ 15”.',
#   'spans': []},
#  {'text': 'The moment of opposition followed at 19h 35m, 7 hours and 35 minutes later.',
#   'spans': []},
#  {'text': 'To this period belongs 7’ 41” of diurnal motion westward.',
#   'spans': []},
#  {'text': 'Therefore, at the designated moment, it would have been at 21° 10’ 30” Leo, which is what was accepted.',
#   'spans': []},
#  {'text': 'There is no mention of parallax.', 'spans': []},
#  {'text': 'Nothing had to be done about refraction, because Mars was high and at mid-sky.',
#   'spans': []},
#  {'text': 'I therefore find the bit of advice in the table about refraction (properly) ignored.',
#   'spans': []},
#  {'text': 'On 1587 March 7 at 19h 10m they deduced the position of Mars from the observations, which was 25° 10’ 20” Virgo.',
#   'spans': []},
#  {'text': 'This they kept in the table, but changed the time to 17h 22m.',
#   'spans': []},
#  {'text': 'The difference of 1h 48m multiplied by a diurnal motion of 24’ gives the same number of minutes and seconds (that is, 1’ 48”), no more.',
#   'spans': []},
#  {'text': 'It therefore should have been 25° 8’ 32” Virgo, which also approaches nearer the point opposite the sun.',
#   'spans': []},
#  {'text': 'The difference is of practically no importance ^9.', 'spans': []},
#  {'text': 'On 1589 April 15 at 12h 5m they established the position of Mars very carefully at 3° 58\' 21" Scorpio, and corrected for longitudinal parallax so as to make it 3° 57’ 11” ^10.',
#   'spans': []},
#  {'text': "There remain 1h 30m until the designated moment of opposition, which, for a diurnal motion of 22', bring the planet back 1’ 22”, so as to be at 3° 55’ 49”.",
#   'spans': []},
#  {'text': 'They took the value of 3° 58’ 10”.', 'spans': []},
#  {'text': 'The former is closer to the sun’s mean position.', 'spans': []},
#  {'text': 'On 1591 June 6 at 12h 20m, Mars is placed at 27° 15’ Sagittarius ^11.',
#   'spans': []},
#  {'text': 'There remained 2 days 4 hours and 5 minutes until the designated moment.',
#   'spans': []},
#  {'text': 'In four days it was found to be moved forward 1° 12’ 47”.',
#   'spans': []},
#  {'text': 'Therefore, to 2d 4h 5m correspond 39’ 29”.', 'spans': []},
#  {'text': 'Consequently, at that moment Mars was at 26° 35’ 31” Sagittarius.',
#   'spans': []},
#  {'text': 'There is no need to consider any horizontal variations in longitude, since Mars is at mid-sky and at the beginning of Capricorn.',
#   'spans': []},
#  {'text': 'The table has 26° 32’ Sagittarius.', 'spans': []},
#  {'text': 'On 1593 24 August at 10h 30m they report Mars as being at 12° 38’ Pisces12 with an observed diurnal motion of 16’ 45”, and this near the nonagesimal13 where there is no longitudinal parallax.',
#   'spans': []},
#  {'text': 'The moment designated for the opposition preceded this by 8h 17m (for it was at 2h 13m),14 to which corresponds a motion of 5’ 48” eastward.',
#   'spans': []},
#  {'text': 'Therefore, the planet falls at 12° 43’ 48” Pisces.', 'spans': []},
#  {'text': 'And the table has 12° 43’ 45”.', 'spans': []},
#  {'text': 'On 1595 October 30 at 8h 20m, they found Mars at 17° 48’ Taurus, with a diurnal motion of 22’ 54” ^15.',
#   'spans': []},
#  {'text': 'The designated moment preceded by 11h 48m, for which is required a motion of Mars of 11’ 7” eastward, so that it would be at 17° 59’ 7” Taurus.',
#   'spans': []},
#  {'text': 'But it was projected eastward on account of parallax.',
#   'spans': []},
#  {'text': 'Therefore, possibly using another observation on the meridian, they put down 17° 56’ 15” Taurus in the table.',
#   'spans': []},
#  {'text': 'On 1597 December 10 at 8h 30m, they first placed Mars at 3° 30’ Cancer, and again at 4° 1’ Cancer, the mean being 3° 45½’ Cancer ^16.',
#   'spans': []},
#  {'text': 'The moment of opposition came 3 days 5h 5m later, to which, from Magini, corresponds 1° 15’ westward.',
#   'spans': []},
#  {'text': 'Therefore, Mars would have been at 2° 30½’ Cancer.', 'spans': []},
#  {'text': 'In the table, it was put at 2° 28’.', 'spans': []},
#  {'text': 'The reason for the rough measurement, carried out with a measuring staff, is clear from the date.',
#   'spans': []},
#  {'text': 'Tycho had left the island, leaving all  instruments but the staff behind.',
#   'spans': []},
#  {'text': 'Nevertheless, he did not wish to ignore this opposition completely.',
#   'spans': []},
#  {'text': 'But I wish he had still remained on the island, for this opposition was a marvelous opportunity, not often recurring within a man’s lifetime, for examining Mars’s parallax.',
#   'spans': []},
#  {'text': 'On 1600 January 13/2317 at 11h 50m, the right ascension of Mars was: 18 19',
#   'spans': []},
#  {'text': 'Hence, Mars is at 10° 38’ 46” Leo, at an adjusted time of 11h 40m reduced to the meridian of Uraniborg.',
#   'spans': []},
#  {'text': 'But on January 24/February 3 at the same time it was at 6° 18’ Leo.',
#   'spans': []},
#  {'text': 'This gives a diurnal motion of 23’ 44”, and a position on January 19/29 at 9h 40m of 8° 18’ 45” Leo, just as they put it.',
#   'spans': []},
#  {'text': 'I have presented these discrepant values for the right ascension in order to show that even in the observations themselves there is an uncertainty of several minutes unless extreme care be exercised and all possible aids used.',
#   'spans': []},
#  {'text': 'At that time the instruments (except the largest) had arrived in Bohemia, but they were still not well enough positioned, and were affected by the journey besides.',
#   'spans': []},
#  {'text': 'However, even in observations at the island it too often happened that right ascensions measured from two different stars differed by three minutes.',
#   'spans': []},
#  {'text': 'When I asked Christian [Longomontanus], on this subject, whether I should consider this an effect of the limitations of observation or vision, he replied, “This is not unusual.”',
#   'spans': []},
#  {'text': 'Finally, the reader should be advised that Tycho, in his table, claimed to have made use of the solar parallax in correcting the positions of Mars.',
#   'spans': []},
#  {'text': 'But it will now shortly be made clear that the parallax of Mars is a slippery and imperceptible business.',
#   'spans': []},
#  {'text': 'However, this does not much affect the certainty of the positions in this table, as Mars can almost always be observed in mid-sky where it has no longitudinal parallax.',
#   'spans': []},
#  {'text': 'Chapter 11', 'spans': []},
#  {'text': 'On the diurnal parallaxes of the star Mars.', 'spans': []},
#  {'text': 'The starting point of my new elaboration and renewal of the motions was where I have just stopped.',
#   'spans': []},
#  {'text': 'For it is clear from Part I that the positions of Mars should be taken at the moments of true opposition to the sun.',
#   'spans': []},
#  {'text': 'However, it is also clear that not every trace of the second inequality is thus removed, it being also necessary to refer the arc measured on the ecliptic to the planet’s orbit.',
#   'spans': []},
#  {'text': 'But the planet’s orbit must first be investigated by the inclination of the planes and by finding out the nodes.',
#   'spans': []},
#  {'text': 'Again, the inclination and the nodes  cannot be found without knowing the diurnal parallax, at least if this should turn out to be relatively large.',
#   'spans': []},
#  {'text': 'One must therefore start with the parallax.', 'spans': []},
#  {'text': 'I shall present two ways to find it.', 'spans': []},
#  {'text': 'The first way (and the one more familiar to others) will be examined using the Brahean observations.',
#   'spans': []},
#  {'text': 'In 1582, when Mars was opposite the sun in Cancer, I found the observation done with incredible care, with Tycho’s manuscript title, “For investigating the parallaxes of Mars”, from which you will, however, deduce either no parallax at all, or one exceedingly small.',
#   'spans': []},
#  {'text': 'I pass over without saying, that (as is customary) they compared the star Mars with nearby stars on the ecliptic, and frequently with ones at a great distance.',
#   'spans': []},
#  {'text': 'Now it is usual to find the parallax of a mobile star (for Mars moves, with a retrograde motion when opposite the sun) by comparing morning and evening observations.',
#   'spans': []},
#  {'text': 'As a result, it has happened that almost all the stars by which Mars was observed in the morning are different from those by which it was observed in the evening.',
#   'spans': []},
#  {'text': 'For a fixed star which is at hand in the morning (and higher than Mars), if it be near the ecliptic, has either set by evening (when Mars is in the west) or is rendered useless by refraction for this delicate procedure.',
#   'spans': []},
#  {'text': 'Another star therefore had to be substituted.', 'spans': []},
#  {'text': 'But if the fixed stars are substituted for one another, there is always less trust in the procedure than if the same star should be retained.',
#   'spans': []},
#  {'text': 'Brahe, however, announced to the learned world in many places that from the observations of that year, the parallax of Mars was found to be considerably greater than that of the sun.',
#   'spans': []},
#  {'text': 'I therefore very carefully scrutinized the whole book in order to examine his operation or computation more deeply.',
#   'spans': []},
#  {'text': 'I did indeed find a chapter which professed to offer a procedure for investigating the parallax of Mars from the observations of that year.',
#   'spans': []},
#  {'text': 'But here was something really surprising: they fitted the position of Mars found by observation into a Copernican diagram drawn very laboriously and carefully.',
#   'spans': []},
#  {'text': 'In this diagram, they took up the immense labor of solving all triangles created by the double epicycle on the concentric, in numbers replete with a great many digits.',
#   'spans': []},
#  {'text': 'Finally, this was the goal of the calculation: to issue a pronouncement that the parallax of Mars is indeed greater than the solar parallax.',
#   'spans': []},
#  {'text': 'Brahe had thus asked one thing, but his assistants in calculation carried out something else.',
#   'spans': []},
#  {'text': 'He wanted them to find out the parallax of Mars by comparing morning and evening observations with one another, but they had in fact found out how much parallax the Copernican diagram would bring about.',
#   'spans': []},
#  {'text': 'Whether Brahe’s pronouncement on parallax was founded solely upon his trust in his assistants, is unknown to me ^1.',
#   'spans': []},
#  {'text': 'As for us, let us consult the actual observations, insofar as they pertain to our undertaking.',
#   'spans': []},
#  {'text': 'In 1582 on the night between 23 and 24 November, the distances from the fixed stars remained the same at different times.',
#   'spans': []},
#  {'text': 'This, then, was a station point ^2.', 'spans': []},
#  {'text': 'On the following two days, the motion was 11’ and 15’.',
#   'spans': []},
#  {'text': 'On the night of 26 December,3 it passed between the second and seventh stars of Gemini,4 its distance (measured with the staff) from the head of the lower of the Twins (the second star) being 2° 25’ or 2° 26’, but from the seventh,',
#   'spans': []},
#  {'text': '1° 6’ or 1° 7’, making the latitude about 4° 9’.', 'spans': []},
#  {'text': 'Then, at 8h 28m, it was 44° 41’ from', 'spans': []},
#  {'text': 'the eye of Taurus,5 whose latitude is 5° 31’ south, longitude 4° 12½’ Gemini, in 1600.',
#   'spans': []},
#  {'text': 'Hence, Mars’s longitude as if the year were 1600 is 17° 53⅓’ Cancer,6 or, at the end of 1582, 17° 38’ Cancer, at an altitude of 40° 50’.',
#   'spans': []},
#  {'text': 'It is thus beyond the effects of refraction.', 'spans': []},
#  {'text': 'Again, at 7h 15m on the morning of December 27, it was 36° 43’ from Cor Leonis,7 whose latitude is 0° 26½’; hence, its longitude at the end of 1582 is 17° 28⅓’ Cancer, altitude 14° 4’, and thus affected by refraction.',
#   'spans': []},
#  {'text': 'Therefore, from 8h 28½m in the evening to 19h 15m, an interval of 10h 46½m, it was observed to retrogress 9⅔’.',
#   'spans': []},
#  {'text': 'For the diurnal motion, on the 29th at 7h 47m, the distance of Mars from the southern foot of Erichthonius8 was 29° 38½’ But on the 30th at 8h 8m the distance from the same star was 29° 13½ ^9.',
#   'spans': []},
#  {'text': 'Therefore, over 24h 21m it moved 25’.', 'spans': []},
#  {'text': 'And this diurnal motion remained the same on the 27th.',
#   'spans': []},
#  {'text': 'Therefore, to 10h 46½m there should have corresponded 11½’ of arc, but we found only 9⅔’.',
#   'spans': []},
#  {'text': 'Let us consider this.', 'spans': []},
#  {'text': 'On the previous evening, when Mars was rising farther to the east (because it was retrograde), parallax moved it eastward, and in the morning, when it was setting and was farther to the west, parallax moved it westward.',
#   'spans': []},
#  {'text': 'So, just as the moon’s diurnal parallax apparently slows its motion, the same parallax in turn quickens Mars’s retrograde motion.',
#   'spans': []},
#  {'text': 'Therefore, if parallax is perceived, it is perceived through an excessively enlarged diurnal motion.',
#   'spans': []},
#  {'text': 'But this motion is diminished.', 'spans': []},
#  {'text': 'Therefore, there is no parallax.', 'spans': []},
#  {'text': 'Again, refraction is perceived as contrary to parallax.',
#   'spans': []},
#  {'text': 'Now the refraction at altitude 13° is 4’ from the table of fixed stars, and 8’ from the table of the sun,10 and only a very small part of this affects the longitude, as Cancer descends quite obliquely.',
#   'spans': []},
#  {'text': 'So the refraction in longitude comes to three minutes at most, which, added to 9⅔’, makes the refraction-free motion 12⅔’ over 10¾ hours, which motion, if it also were free from parallax, ought to have been 11½’.',
#   'spans': []},
#  {'text': 'Therefore, the excess of 1⅓’ is the longitudinal parallax for the two observations—clearly minimal, untrustworthy, and entirely contemptible.',
#   'spans': []},
#  {'text': 'On 1583 January 16 at 7h 30m in the evening,11 Mars was 23° 29’ from the bright star in the foot of Erichthonius at an altitude of 51°.',
#   'spans': []},
#  {'text': 'The next morning at 5h 0m, it was 43° 58’ from Cor Leonis at an altitude of 15°.',
#   'spans': []},
#  {'text': 'And, measured by the straight edge, Mars was perfectly collinear with the two stars.',
#   'spans': []},
#  {'text': 'And so, since Mars’s motion is carried out along this line, Brahe made a note that the longitudinal parallax is given from the diurnal motion of Mars.',
#   'spans': []},
#  {'text': 'This is obtained here as follows.', 'spans': []},
#  {'text': 'On January 16 at 10½h it was 23° 27’ from the bright star in the foot of Erichthonius.',
#   'spans': []},
#  {'text': 'On January 17 at 10⅗h 12 it was 23° 12½’ from the same star.',
#   'spans': []},
#  {'text': 'Therefore, the diurnal motion would be 14½’.', 'spans': []},
#  {'text': 'Now in order to comply with Brahe’s advice, we must set out the distance between the foot of Erichthonius and Cor Leonis, which is found to be 67° 21’.',
#   'spans': []},
#  {'text': "Subtracting Mars's distance from the bright star in the foot of Erichthonius, 23° 29’, leaves Mars's distance from Cor Leonis, 43° 52’, at 7½h in the evening, which at 5h in the morning was 43° 58’, 6 minutes greater.",
#   'spans': []},
#  {'text': 'The time interval is 9½ hours, to which ought to correspond 5⅝’ of the diurnal motion.',
#   'spans': []},
#  {'text': 'Here, therefore, the  sum of the two parallaxes is no more than ⅜’ except that the amount of Mars’s longitudinal refraction at 15° is added to it.',
#   'spans': []},
#  {'text': 'But this is quite small.', 'spans': []},
#  {'text': "For Cancer and Leo are setting extremely obliquely, and Mars's large northern latitude put it at nearly the same altitude as Cor Leonis.",
#   'spans': []},
#  {'text': 'On January 17 at 5h 20m in the evening,13 Mars was 23° 16’ from the foot of Erichthonius.',
#   'spans': []},
#  {'text': 'On the following day, the 18th, at 3h 0m in the morning, this distance was 23° 9’, and at 5h 5m in the evening it was 23° 1½’.',
#   'spans': []},
#  {'text': 'So the motion over 23h 45m is 14½’, but over 9h 40m it is 7’.',
#   'spans': []},
#  {'text': 'This should have been 6’.', 'spans': []},
#  {'text': 'We are left with a longitudinal parallax of no more than 1’.',
#   'spans': []},
#  {'text': 'Refraction does not affect anything, since in both instances the altitude of Mars was about 30°.',
#   'spans': []},
#  {'text': 'Likewise, at 7h 34m its distance from the seventh star of Gemini14 was 7° 51’.',
#   'spans': []},
#  {'text': 'At 4h 52m in the morning, it was 7° 59’ from the same star.',
#   'spans': []},
#  {'text': 'Therefore, over 9h 18m it moved 8’.', 'spans': []},
#  {'text': 'We thus have one minute more than before.', 'spans': []},
#  {'text': 'Of this star (at the shoulder of Gemini), Brahe wrote, “Note that I am taking Mars’s distance from this star because its course passes through it, as it were, so that the morning and evening distances compared might show the parallax.” I have reproduced this here so that the reader may rest assured that Brahe did not proceed without a purpose.',
#   'spans': []},
#  {'text': 'On January 18 at 8h 52m in the evening15 there was 44° 22’ between Mars and Cor Leonis.',
#   'spans': []},
#  {'text': 'At 4¾h in the morning the same distance was 44° 27⅓’.',
#   'spans': []},
#  {'text': 'Therefore, the motion over 7h 53m was 5⅓’.', 'spans': []},
#  {'text': 'On January 19 following, at 7h 3m, this distance was 44° 32½’.',
#   'spans': []},
#  {'text': 'Therefore, for 22h 11m the motion is 10½’.', 'spans': []},
#  {'text': 'And for 8 hours there would be less than 4’ of motion.',
#   'spans': []},
#  {'text': 'Our profit is about 1½’ of parallax.', 'spans': []},
#  {'text': 'But now let us calculate, for January 17, how much of an increase in the hourly motion should result from a parallax greater than the solar parallax as usually accepted.',
#   'spans': []},
#  {'text': 'Since we consider the sun’s parallax to be three minutes, let Mars have four.',
#   'spans': []},
#  {'text': '16', 'spans': []},
#  {'text': 'It follows that the motion of mars over those hours should have appeared 4’ greater than what follows proportionally from the diurnal motion.',
#   'spans': []},
#  {'text': 'Since this is repudiated by the observations, Mars’s parallax is found – often none at all.',
#   'spans': []},
#  {'text': 'There was even an occasional note in Brahe’s hand saying, “It strayed over to the wrong side.” So this is the first way of investigating Mars’s parallax.',
#   'spans': []},
#  {'text': 'I shall now add the other way, because of its beauty; I cannot use the Brahean observations in it.',
#   'spans': []},
#  {'text': 'Therefore, in using my own observations, I am going to give you a clown show, and will show by example why Brahe needed such diligence, precision of instruments, assistants, and other equipment.',
#   'spans': []},
#  {'text': 'I have two instruments, which I use through the generosity of Baron Friedrich Hoffmann, L.B ^17.',
#   'spans': []},
#  {'text': 'an iron sextant and a brass azimuthal quadrant.', 'spans': []},
#  {'text': 'The latter is two and a half feet in diameter and the former three and a half, and both are calibrated in one-minute divisions.',
#   'spans': []},
#  {'text': 'Now at this very time, 1604, at which I am considering parallax (whether that of the sun more than Mars’s is hard to say, for my Hipparchus18 requires Mars’s aid even in the lunar eclipses), a very suitable occasion for observation arose, if only the climate zone had been different and Mars had moved a little higher.',
#   'spans': []},
#  {'text': 'For about 19/29 February19 of this year 1604, Mars was stationary both in longitude and in latitude at the same time.',
#   'spans': []},
#  {'text': 'This occurred in Libra, and therefore from Mars’s rising to the sun’s rising the angle of the horizon with the ecliptic continually decreased.',
#   'spans': []},
#  {'text': 'Consequently, according to Ch.', 'spans': []},
#  {'text': '9 of the Astronomiae Optica20 the latitudinal parallax, if any, continually increases.',
#   'spans': []},
#  {'text': 'But from the increment (found through the columns of the parallactic table21 opposite the initial and final angles of the ecliptic with the horizon), the whole horizontal parallax (at the front of the column) is known.',
#   'spans': []},
#  {'text': 'There follows the series of my observations ^22.', 'spans': []},
#  {'text': 'On the night between Thursday and Friday, which was February 17/27, while Corvus was on the meridian, there was 9° 44’ between Mars and Spica, and between it and the Northern Pan,23 17° 41’; and between Mars and Arcturus, 29° 13’.',
#   'spans': []},
#  {'text': 'Also, to test the sextant, we measured the interval between Arcturus and Spica as 32° 57’, which should have been 33° 1’ 45”, as is clear if you calculate it using the right ascensions and declinations, or latitudes and longitudes, which Tycho assigned to these stars in Book I of the Progymnasmata ^24.',
#   'spans': []},
#  {'text': 'Therefore, my distances are smaller than the true distances by 4¾ minutes.',
#   'spans': []},
#  {'text': 'I applied this correction to the distances of Mars from the fixed stars, so as to make it 9° 48’ 45” from Spica, 17° 45’ 45” from the Pan, and 29° 17’ 45” from Arcturus ^25.',
#   'spans': []},
#  {'text': 'I then used the quadrant to obtain the meridian altitude of Mars, 32° 4’, and of Spica, 30° 50’.',
#   'spans': []},
#  {'text': 'Since the latter has a declination of 9° 2’, Mars is left with a declination of 7° 48”.',
#   'spans': []},
#  {'text': 'However, the altitude of Spica showed that my perpendicular was not well enough set up.',
#   'spans': []},
#  {'text': 'For the altitude of the equator, at my location, is 39° 54’.',
#   'spans': []},
#  {'text': 'Accordingly, the meridian altitude of Spica is 30° 52’, and of Mars, 32° 6’.',
#   'spans': []},
#  {'text': 'Now, from the declination of Mars and its distance from the fixed star, its right ascension comes out: 26',
#   'spans': []},
#  {'text': 'I am not certain whether, when (as happened a few times) the clamps holding the arm loosened and it (being a heavy piece of iron) fell precipitously and hit hard, it might not have changed the position of the sights, since they are removable and subject to dislocation.',
#   'spans': []},
#  {'text': 'But from this right ascension, I first select,  from Tycho’s table of right ascensions, the degree of the right sphere that was riding at the same time, 28° 1’ 0” Libra,27 whose declination, from another of that author’s tables,28 is 10° 48’ 30” [South].',
#   'spans': []},
#  {'text': 'But that of Mars is 7° 48’ [South].', 'spans': []},
#  {'text': 'Therefore, Mars is distant from the ecliptic, the oblique path, by 3° 0’ 30” on the circle of declination.',
#   'spans': []},
#  {'text': 'But the angle which the circle of declination makes with the ecliptic is 68° 59’ from the appropriate table.',
#   'spans': []},
#  {'text': 'Its complement is 21° 1’.', 'spans': []},
#  {'text': 'And in my table of parallax,29 under the heading of 60’, I find, opposite 68° 59’, the entry 56’ 1”.',
#   'spans': []},
#  {'text': 'Under 30”, however, I find 28”.', 'spans': []},
#  {'text': 'But since I have thrice 60’ in this distance of Mars from the ecliptic (which I call the base of the latitude  ), I multiply what I extracted under 60’ by 3 ^30.',
#   'spans': []},
#  {'text': 'This gives me a latitude of 2° 48’ 31”.', 'spans': []},
#  {'text': 'The same operation opposite 21° 1’ shows me what has to be subtracted from the place rising at the same time, namely, 1° 5’ 4”.',
#   'spans': []},
#  {'text': 'Accordingly, Mars’s position will be 26° 56’ Libra.', 'spans': []},
#  {'text': 'I come within a minute of this using a computation whose fundamentals I am going to be presenting in this work.',
#   'spans': []},
#  {'text': 'To test the latitude of Mars, I also consulted the distance from Arcturus, through the star’s latitude and longitude provided from Tycho, and Mars’s longitudinal position just found, and it replied to me that Mars was at a latitude of 2° 47’ 48”.',
#   'spans': []},
#  {'text': 'Before, it was at 2° 48’ 31”.', 'spans': []},
#  {'text': 'On February 19/29 we had moved the sight, and began to observe Mars rising.',
#   'spans': []},
#  {'text': 'Its distances from Arcturus were noted, and were these:',
#   'spans': []},
#  {'text': 'I think we are ten minutes too high.', 'spans': []},
#  {'text': 'For the wind was blowing so hard that it was only by a glowing coal that we could cast light upon the scale so as to read it.',
#   'spans': []},
#  {'text': 'And the altitude of Mars was then 11°.', 'spans': []},
#  {'text': 'Later, the back of Leo31 culminated at altitude 62° 37’, according to a corrected plumb line.',
#   'spans': []},
#  {'text': 'Thus the altitude of the equator was shown to be 39° 55’: almost correct.',
#   'spans': []},
#  {'text': 'At that moment, Mars’s altitude was 23°.', 'spans': []},
#  {'text': 'We next reinvestigated the former distance [to Arcturus], which came out to be:  Therefore without doubt the previous distance was',
#   'spans': []},
#  {'text': 'For first, when Mars was near the horizon, refraction moved it toward  Arcturus, later letting it drops down when Mars had acquired some altitude.',
#   'spans': []},
#  {'text': 'It was, however, the cold and the extremely biting winds that occasioned so much variety in observations made at the same time.',
#   'spans': []},
#  {'text': 'For it was impossible to handle the iron and close the clamps with bare hands, and with gloves the arm was not securely enough clamped to be read to the minutes.',
#   'spans': []},
# ...
#  {'text': 'XII.', 'spans': []},
#  {'text': 'Finally, in 1604, when I had published my previously written Ephemerides, in which on the night between March 29 and 30/April 8 and 9 the planet was placed on a line from Arcturus to Spica, that very thing appeared.',
#   'spans': []},
#  {'text': 'For on the evening of April 8 it was slightly east of that line, but already on April 9 it was to the west.',
#   'spans': []},
#  {'text': 'At that time, with the help of Johann Schuler and using Hofmann’s sextant, I found 33° 4’ between Arcturus and Spica, which ought to have been 33° 1½’.',
#   'spans': []},
#  {'text': 'Therefore, the reading was 2½’ too great.', 'spans': []},
#  {'text': 'Immediately after, between Arcturus and Mars there was 29° 43½’; therefore, correctly, 29° 41’.',
#   'spans': []},
#  {'text': 'And since the latitude of Arcturus is 31° 2½’ north, this left 2° 21½’ as the latitude of Mars ^34.',
#   'spans': []},
#  {'text': 'There was then 54° 8½’ between Cor Leonis and Mars, and at the same time, the same amount between Cor Leonis and Spica.',
#   'spans': []},
#  {'text': 'This should, however, have been 54° 2’.', 'spans': []},
#  {'text': 'There were therefore 6½ minutes too much, while before the excess was only 2½’.',
#   'spans': []},
#  {'text': 'The origin of this uncertainty of four minutes could not be ascribed to the intervention of obstacles, as we were unable to eliminate it while observing.',
#   'spans': []},
#  {'text': 'But let us suppose that, as before, the excess was 2½’, making the distance between Mars and Cor Leonis 54° 6’.',
#   'spans': []},
#  {'text': 'The error could then be in Spica’s position, possibly because Mars was mistaken for Spica, since they were close to one another.',
#   'spans': []},
#  {'text': 'Hence, Mars’s latitude comes out to 2° 21½’, longitude 18° 25’ Libra.',
#   'spans': []},
#  {'text': 'The hour is known since, at the time of observation, the Back of Leo was culminating, whose right ascension is 163° 13’.',
#   'spans': []},
#  {'text': 'Now the sun’s position at noon is 18° 56’ 24“ Aries, whose right ascension is 17° 27’ 55“.',
#   'spans': []},
#  {'text': 'Hence the difference in ascensions is 145° 45’, which resolves into 9 hours 43 min.',
#   'spans': []},
#  {'text': 'The rising point was 22½° Scorpio.', 'spans': []},
#  {'text': 'Therefore, the nonagesimal was 39° from the zenith, and the distance of Mars from the earth was a little greater than half that of the sun from the earth.',
#   'spans': []},
#  {'text': 'So the parallax was about 5½’, and its latitudinal part, 3’ 28“.',
#   'spans': []},
#  {'text': 'Therefore the latitude without parallax was 2° 25’ (whether this correction was rightly made, we shall consider below).',
#   'spans': []},
#  {'text': 'And because the altitude of the nonagesimal was 51°, and Mars’s distance from the nonagesimal was 56°, the longitudinal parallax was 3’ 32“.',
#   'spans': []},
#  {'text': 'Therefore, Mars would be at 18° 21½’ Libra ^35.', 'spans': []},
#  {'text': 'At our chosen moment, the sun’s position is 19° 20’ 8“ Aries.',
#   'spans': []},
#  {'text': 'The two celestial bodies are 58½’ apart.', 'spans': []},
#  {'text': 'The sun’s diurnal motion is 58’ 38“, and that of Mars, 22’ 36“.',
#   'spans': []},
#  {'text': '(For in 1587 in Virgo it is 24’, and in 1589 at 4° Scorpio it is 22’ 8“).',
#   'spans': []},
#  {'text': 'The sum of the diurnal motions is 1° 21’ 14“.', 'spans': []},
#  {'text': 'From all these beginnings, it follows that the true opposition preceded the observation by 17 hours 20 min., namely, on 29 March/8 April at 4h 23m in the morning.',
#   'spans': []},
#  {'text': 'Mars’s position was 18° 37’ 50“ Libra.', 'spans': []},
#  {'text': 'For reduction to the orbit, subtract about 39 sec., making Mars’s position 18° 37’ 10“ Libra.',
#   'spans': []},
#  {'text': 'The latitude was slightly greater than 2° 25’, but, when parallax is ignored, it is 2° 22’ north.',
#   'spans': []},
#  {'text': 'Now these twelve eccentric positions of Mars (so called because the  longitudes are freed from the effects of the second inequality) have been established with all possible care.',
#   'spans': []},
#  {'text': 'If in this prickly business something has escaped me somewhere (and it did escape sometimes for a period of as much as eighteen months: I relied upon a false foundation—false, that is, for the applied observation—and all that work was in vain), I am entirely at a loss to imagine what it could be.',
#   'spans': []},
#  {'text': 'I shall therefore set out all the positions in the following table, with the addition of the mean longitudes from Tycho.',
#   'spans': []},
#  {'text': 'I could have gotten these from the Prutenic tables, or from the computation upon which Ptolemy based his demonstrations and which he designed for that purpose, but this would be unnecessary.',
#   'spans': []},
#  {'text': 'For if the mean motion needed correction, it will be corrected later.',
#   'spans': []},
#  {'text': 'For the present, it will serve to measure the time intervals without any appreciable error.',
#   'spans': []},
#  {'text': '36', 'spans': []},
#  {'text': 'Chapter 16', 'spans': []},
#  {'text': 'A method of finding a hypothesis to account for the first\ninequality.',
#   'spans': []},
#  {'text': 'Ptolemy, in Book 9 chapter 41 of the Great Work, where he is about to take up the first inequality, made by way of preface a somewhat cursory declaration of the suppositions of which he wished to make use.',
#   'spans': []},
#  {'text': 'It is, in summary, as follows: We see that a planet spends unequal times on opposite semicircles.',
#   'spans': []},
#  {'text': 'As, although from 2⅔° Cancer through Leo to 26¾° Sagittarius is less than a semicircle, and from 26° Sagittarius through Aquarius to Cancer is more than a semicircle, nonetheless the planet is found to spend longer on the former than on the latter, although a law of uniformity2 would require the contrary.',
#   'spans': []},
#  {'text': 'For from a mean longitude of 2s 23° 18’ to 9s 5° 44’ is 6s 12° 26’, more than a  semicircle, that is, more than half of the planet’s periodic time ^3.',
#   'spans': []},
#  {'text': 'So from 12° 16’ Pisces through Leo to 12° 27’ Virgo is about a semicircle and 11 minutes.',
#   'spans': []},
#  {'text': 'But if the mean longitude of the former position (11s 9° 55’) be subtracted from the longitude of the latter (5s 14° 59’), the difference is seen to be 6s 5° 5’, which is 5° 5’ more than half.',
#   'spans': []},
#  {'text': 'The planet consequently takes a proportionally shorter time from Virgo through Aquarius to Pisces.',
#   'spans': []},
#  {'text': 'Now if you examine adjacent positions one at a time and compare the intervening arcs with the times or with the arcs of mean longitude, you will see that the planet is slowest at one fixed point on the zodiac, and swiftest at the opposite point, and that at the intermediate points its motion gradually increases or decreases, according to its proximity to one or the other.',
#   'spans': []},
#  {'text': 'These things reveal first of all that the motion of a planet (however irregular it may appear) is governed according to cycles, and that the present cycle is the successive modification of motion and a return to its same state.',
#   'spans': []},
#  {'text': 'For if the planet moved in straight lines joined by angles (such as if it should move around a pentangle—I was once engaged in such ideas), its motion would sometimes suddenly change from swifter to slower in an evident manner, according to the relationship of the lines, and this would happen not in one but in many places on the zodiac, according to the number of lines.',
#   'spans': []},
#  {'text': 'However, since so great an inequality still remains in the planet’s motion, after the removal of the inequality that depends upon the sun, it therefore will be incapable of being either governed or demonstrated by the supposition of a simple circle (one set up at the center of observation).',
#   'spans': []},
#  {'text': 'This can, however, be done by composition of several circles, or the equivalent (as Ptolemy said in his preliminaries to Book 3).',
#   'spans': []},
#  {'text': 'The simplest ways of doing this are two: by using either an eccentric circle or a concentric with an epicycle.',
#   'spans': []},
#  {'text': 'Thus Ptolemy chooses an eccentric for the first inequality, for the sake of distinguishing between the two and providing an aid to comprehension, since an epicycle would be required for the second inequality.',
#   'spans': []},
#  {'text': 'Then, thinking over this general description, he denies that a mere eccentric suffices the planets.',
#   'spans': []},
#  {'text': 'For he first considered closely what would duly follow from the simultaneous revolution of an epicycle (to account for the second inequality) and an eccentric (for the first inequality), and it was then evident, by comparing observations, that the center of the epicycle approaches much nearer to the earth at apogee, and flees farther from it at perigee, than the simple eccentric that accounts for the first inequality allows.',
#   'spans': []},
#  {'text': 'From this discovery, by a continuous train of thought, he alights on the measure of this approach, and relates that he discovered that the center of the eccentric that carries the center of the epicycle is exactly at the midpoint between the center of observation, the earth, and the center of uniformity or of the eccentric accounting for the first inequality.',
#   'spans': []},
#  {'text': 'And, without a single demonstration, he nevertheless relies upon this principle for the three superior planets.',
#   'spans': []},
#  {'text': 'Copernicus, as he frequently did on other occasions, here too followed his master  religiously, his form of hypothesis being accommodated to this measure.',
#   'spans': []},
#  {'text': 'Not without reason, astronomers have wondered about this, and I among them (using Maestlin’s voice), as you see in the Mysterium cosmographicum Ch.',
#   'spans': []},
#  {'text': '22 p.', 'spans': []},
#  {'text': '79.', 'spans': []},
#  {'text': 'Despite my having opined, in that passage of the said book, that Ptolemy used blind guesswork to establish this, the truth is the opposite.',
#   'spans': []},
#  {'text': 'For he was able to prove it with a perfectly good demonstration given a suitable  observation, as I shall demonstrate below.',
#   'spans': []},
#  {'text': 'One finds fault with the theorist only in that he did not transmit to posterity those observations along with the demonstration.',
#   'spans': []},
#  {'text': 'And so, since I thought then that this was altogether too much to assume,4 and also saw it pointedly called into question by Copernicus when he argued for a change in Mars’s eccentricity on the basis of his figures which were not in accord with this bisection of the eccentricity, I envisaged a method which would lead me to a knowledge of the ratio of the two eccentricities (because, as I said, it is not indubitably 2:1).',
#   'spans': []},
#  {'text': 'And since Ptolemy used three acronychal5 observations and this preconceived opinion of the ratio of the eccentricities to find the position of the apogee, the correction of the mean longitude, and finally, the magnitude of the eccentricity, I saw that in order to weaken the sinews of the problem (once the axiom of the ratio of the eccentricity is taken away), it will be indeterminate and not having a single case, and thus I would need in addition the support of a fourth acronychal observation.',
#   'spans': []},
#  {'text': 'And so, in the year 1600, having acquired knowledge of this art, I came to Tycho, and was happy to learn that he too did not assume this ratio, but made an investigation, as his figures indicate.',
#   'spans': []},
#  {'text': 'For he makes the center of the (Copernican*)  eccentric distant from the center of vision by 13,680 units, while the point of equality in turn is another 3,780 of these units beyond that.',
#   'spans': []},
#  {'text': 'In the Ptolemaic form, this would be as if he were to make the distance of the centers of vision and of the eccentric 9,900, and the remaining distance between the center of the eccentric and the point of equality 7,560.',
#   'spans': []},
#  {'text': 'Now I myself could also have taken the bisection of the eccentricity as certainly established, and with better reason than Ptolemy, because in Ch.',
#   'spans': []},
#  {'text': '22 of  my Mysterium I had brought forward a physical cause for the bisection.',
#   'spans': []},
#  {'text': 'Indeed, it was for this very reason that I had come to Tycho, that I might use his observations to inquire further into my opinions expressed in that book.',
#   'spans': []},
#  {'text': 'I of course did this without prejudice, and continue to do so.',
#   'spans': []},
#  {'text': 'And if I survive to see astronomy achieve its purity and perfection, so that a verdict can be given in the case which I have brought before her tribunal in that book, I promise the reader that I shall retract that book and, upon confirming what is seen as true, will faithfully reveal the remainder that has turned out not to be so ^6.',
#   'spans': []},
#  {'text': 'But back to the argument.', 'spans': []},
#  {'text': 'About center B let the eccentric FG be described, and on it, through B, the diameter of the apsides HI, taken as if immutable over any number of years.',
#   'spans': []},
#  {'text': 'If there be danger of error in this assumption, we are not lacking ways of taking it into account.',
#   'spans': []},
#  {'text': 'On this line below B let A be the observer, and above B let C be that center about which angles are made proportional to amounts of time, since (as was just said above) these are not proportional about A. Now let F, G, D, and E be four observations distributed about the circumference of the circle, so situated that the planet, stripped of the second inequality, would appear there as if  viewed from point A. For indeed, according to Ptolemy, A is the true center of vision or the center of the earth, while according to Tycho and Copernicus vision takes place along the lines FA, GA, DA, and EA, and A is the sun ^7.',
#   'spans': []},
#  {'text': 'But it was said above that in either way the planet is likewise shorn of its second inequality.',
#   'spans': []},
#  {'text': 'Now let each point be connected with each of the others, and let AF be at 25° 43’ Virgo, AG at 26° 43’ Sagittarius, AD at 12° 16’ Pisces, and AE at 17° 31⅔’ Taurus.',
#   'spans': []},
#  {'text': 'Hence, the four angles about A are given: FAG is 91° 0’, GAD is 75° 33’, DAE is 65° 15⅔’, and EAF is 128° 11⅓’.',
#   'spans': []},
#  {'text': 'These must be corrected somewhat on account of the precession of the equinoxes.',
#   'spans': []},
#  {'text': 'For in relation to the fixed stars the planet is not so far forward at E (the last observation) as is indicated by these numbers.',
#   'spans': []},
#  {'text': 'Wherefore FAE is a little greater, and the others smaller by the same amount.',
#   'spans': []},
#  {'text': 'In the same way, by subtraction of the [mean] longitudes, the angles about C are also obtained.',
#   'spans': []},
#  {'text': 'Proposition.', 'spans': []},
#  {'text': 'It is now required to select values for angles FAH and FCH such that, once these are supposed, the points F, G, D, E stand on one circle, and that center B of that circle lie between the points C and A on the line CA.',
#   'spans': []},
#  {'text': 'The solution is not geometrical, at least if algebra is not geometrical, but proceeds by a double iteration ^8.',
#   'spans': []},
#  {'text': 'For algebra, too, forsakes us here, because terms communicated by strictly straight lines through straight line do not extend to angles,9 unless perchance one would wish to cram the entire theory of sines into this one operation.',
#   'spans': []},
#  {'text': 'But behold what we are required to do.', 'spans': []},
#  {'text': 'If we were to assume a value for the angle FAH, then since the line AF has a certain sidereal position, the other leg AH would also be assumed to have a certain sidereal position.',
#   'spans': []}]

# %%
text= "Misaligned tokens For a third trial, then, supposing Mars’s eccentric position in 1585 was 5° 20' 2"  Libra, εδζ came out to be 21° 15' 54", and εγζ 21° 13' 54"  #try to find the Misaligned Tokens
text[22:28]
# Out:
# '8h 20m'
