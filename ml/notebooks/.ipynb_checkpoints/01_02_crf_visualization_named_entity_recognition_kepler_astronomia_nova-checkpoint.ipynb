# %% [markdown]
# # Named Entity Recognition (NER) by Machine learning
#
# In the following notebook, you can find a simple implementation of named entity recognition by machine learning

# %% [markdown]
# ## Import the required tools

# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt
import collections
import os
from itertools import permutations
from sklearn.metrics import make_scorer,confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
import sklearn_crfsuite  # to install this package in windows with pip please run: 'pip install sklearn-crfsuite'
from sklearn_crfsuite import metrics, scorers
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
import eli5  # to install this package in windows with conda please run: 'conda install -c conda-forge eli5'
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\moha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\moha\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Please download the data '01_df_v013.pickle' in github on  your local machine from  this directory: vorlesung2019/notebooks/yeghaneh/data

# %%
importVersion = '013'  # The  desired version pickle-file of your data (now we are working on version 013 of our data)

# %%
path= '../data/01_df_v{0}.pickle'.format(importVersion)  # Put the path of the data in your local machine here, consider the letter "r" before the path

# %% [markdown]
# ### Let's use data "01_df_v013" to build a NER system.
# The data 01_df_v013 is annotated (labeled) data of english version of well-known kepler's book: New Astronomy (Latin: Astronomia nova). You can find that in the repository.

# %% [markdown]
# ### Read the data

# %%
dfAstroNova = pd.read_pickle(path)# The data  is saves as a pickle file. We read it as a pandas dataFrame
type(dfAstroNova)
# Out:
# pandas.core.frame.DataFrame

# %%
 # Sort the data based on the chapters of the book 
dfAstroNova['chapter'] = dfAstroNova.chapter.replace("appendix b",np.nan).astype(float)  
dfAstroNova.sort_values(by='chapter' , inplace=True)
dfAstroNova.chapter.fillna('appendix b', inplace=True)

# %%
len(dfAstroNova)   # Number of rows.
# Out:
# 1605

# %%
dfAstroNova.head(5)
# Out:
#                                                  html  \
# 18  <p><span class="anchor" id="bookmark0"></span>...
# 34  <p>But before that, I shall prove in this firs...
# 33  <p>But since the sun's mean and apparent motio...
# 32  <p>Now the causes and measures of these inequa...
# 30  <p>Again, however, it was noticed that these l...
#
#                                                  text links  \
# 18                                          Chapter 1    []
# 34  But before that, I shall prove in this first p...    []
# 33  But since the sun's mean and apparent motions*...    []
# 32  Now the causes and measures of these inequalit...    []
# 30  Again, however, it was noticed that these loop...    []
#
#                          italic chapter graphic table  \
# 18                           []       1      []    []
# 34                           []       1      []    []
# 33  [Mysterium cosmographicum,]       1      []    []
# 32                           []       1      []    []
# 30                           []       1      []    []
#
#                                              marginal  \
# 18                                                 []
# 34                                                 []
# 33  [ Terms: * The sun's apparent position is that...
# 32                                               [ 5]
# 30                                                 []
#
#                                             sentences  \
# 18                                        [Chapter 1]
# 34  [But before that, I shall prove in this first ...
# 33  [But since the sun's mean and apparent motions...
# 32  [Now the causes and measures of these inequali...
# 30  [Again, however, it was noticed that these loo...
#
#                                                tagged
# 18                      [[(Chapter, None), (1, NUM)]]
# 34  [[(But, None), (before, None), (that, None), (...
# 33  [[(But, None), (since, None), (the, None), (su...
# 32  [[(Now, None), (the, None), (causes, None), (a...
# 30  [[(Again, None), (however, None), (it, None), ...

# %%
dfAstroNova[740:745]
# Out:
#                                                   html  \
# 594  <p><span class="anchor" id="bookmark1"></span>...
# 596  <p>And concerning the first, it is worthy of c...
# 595  <p>This is a good time for me to take up the o...
# 598  <p>But it is answered, first, that the analogy...
# 599  <p>On this account I would nearly separate lig...
#
#                                                   text  \
# 594  Whether the motion from the sun, like its ligh...
# 596  And concerning the first, it is worthy of cons...
# 595  This is a good time for me to take up the obje...
# 598  But it is answered, first, that the analogy be...
# 599  On this account I would nearly separate light ...
#
#                           links     italic chapter graphic table marginal  \
# 594  [{'#fn1': 'άντίφραχις.↩'}]         []      35      []    []       []
# 596                          []         []      35      []    []       []
# 595                          []  [species]      35      []    []       []
# 598                          []         []      35      []    []       []
# 599                          []         []      35      []    []       []
#
#                                              sentences  \
# 594  [Whether the motion from the sun, like its lig...
# 596  [And concerning the first, it is worthy of con...
# 595  [This is a good time for me to take up the obj...
# 598  [But it is answered, first, that the analogy b...
# 599  [On this account I would nearly separate light...
#
#                                                 tagged
# 594  [[(Whether, None), (the, None), (motion, None)...
# 596  [[(And, None), (concerning, None), (the, None)...
# 595  [[(This, None), (is, None), (a, None), (good, ...
# 598  [[(But, None), (it, None), (is, None), (answer...
# 599  [[(On, None), (this, None), (account, None), (...

# %%
dfAstroNova[1585:1590]
# Out:
#                                                    html  \
# 1568  <p>{marginal: The words of the observation hav...
# 1569  <p>This interpretation is furthered by the obs...
# 0                                     <p>Appendix B</p>
# 1     <p><span class="anchor" id="bookmark0"></span>...
# 2     <p>by Yaakov Zik <span style="font-variant: sm...
#
#                                                    text links italic  \
# 1568   Consider whether the meaning could be this: t...    []     []
# 1569  This interpretation is furthered by the observ...    []     []
# 0                                            Appendix B    []     []
# 1             On the Table of Oppositions in Chapter 15    []     []
# 2                                by Yaakov Zik Table i:    []     []
#
#          chapter graphic table  \
# 1568          70      []    []
# 1569          70      []    []
# 0     appendix b      []    []
# 1     appendix b      []    []
# 2     appendix b      []    []
#
#                                                marginal  \
# 1568  [ The words of the observation have their comm...
# 1569                                                 []
# 0                                                    []
# 1                                                    []
# 2                                                    []
#
#                                               sentences  \
# 1568  [Consider whether the meaning could be this: t...
# 1569  [This interpretation is furthered by the obser...
# 0                                          [Appendix B]
# 1           [On the Table of Oppositions in Chapter 15]
# 2                              [by Yaakov Zik Table i:]
#
#                                                  tagged
# 1568  [[(Consider, None), (whether, None), (the, Non...
# 1569  [[(This, None), (interpretation, None), (is, N...
# 0                       [[(Appendix, None), (B, None)]]
# 1     [[(On, None), (the, None), (Table, None), (of,...
# 2     [[(by, None), (Yaakov, None), (Zik, None), (Ta...

# %%
dfAstroNova.tail(5)
# Out:
#                                                  html  \
# 13                     <p>{table: appendix B t 2}</p>
# 14  <p>Kepler's table, for comparison {table: appe...
# 15  <p>Mars from Earth to be a little greater than...
# 16  <p><img height="300" src="media/image1.jpeg" w...
# 17  <p>The Sun moved westward and its longitude de...
#
#                                                  text  \
# 13
# 14                    Kepler's table, for comparison
# 15  Mars from Earth to be a little greater than ha...
# 16   As shown in Figure 2B, the Sun is assumed to ...
# 17  The Sun moved westward and its longitude decre...
#
#                                                 links  \
# 13                                                 []
# 14                                                 []
# 15  [{'#fn6': '
# Kepler's observations yield topoce...
# 16                                                 []
# 17                                                 []
#
#                              italic     chapter             graphic  \
# 13                               []  appendix b                  []
# 14                               []  appendix b                  []
# 15                               []  appendix b                  []
# 16                               []  appendix b  [ appendix b gr 1]
# 17  [4<sup>h</sup> 23<sup>m </sup>]  appendix b                  []
#
#                 table marginal  \
# 13  [ appendix B t 2]       []
# 14  [ appendix B t 3]       []
# 15                 []       []
# 16                 []       []
# 17                 []       []
#
#                                             sentences  \
# 13                                                 []
# 14                   [Kepler's table, for comparison]
# 15  [Mars from Earth to be a little greater than h...
# 16  [As shown in Figure 2B, the Sun is assumed to ...
# 17  [The Sun moved westward and its longitude decr...
#
#                                                tagged
# 13                                                 []
# 14  [[(Kepler, None), (s, None), (table, None), (f...
# 15  [[(Mars, None), (from, None), (Earth, None), (...
# 16  [[(As, None), (shown, None), (in, None), (Figu...
# 17  [[(The, None), (Sun, None), (moved, None), (we...

# %% [markdown]
# ### Primary Data Exploration

# %%
dfAstroNova["text"][5]    #  5th row of the data in the format of text
# Out:
# "The time is measured from midnight; Gregorian dates are obtained by adding 10 days to Kepler's dates. The dates are given in old style."

# %%
dfAstroNova["tagged"][5] # 5th row of the data in a format (token, label). A list of lists of tuples! later position tags of the token will be added to each tuple. the tokens are chosen before by some rules.
# Out:
# [[('The', 'None'),
#   ('time', 'None'),
#   ('is', 'None'),
#   ('measured', 'None'),
#   ('from', 'None'),
#   ('midnight', 'None'),
#   ('Gregorian', 'None'),
#   ('dates', 'None'),
#   ('are', 'None'),
#   ('obtained', 'None'),
#   ('by', 'None'),
#   ('adding', 'None'),
#   ('10', 'NUM'),
#   ('days', 'None'),
#   ('to', 'None'),
#   ('Kepler', 'None'),
#   ('s', 'None'),
#   ('dates', 'None')],
#  [('The', 'None'),
#   ('dates', 'None'),
#   ('are', 'None'),
#   ('given', 'None'),
#   ('in', 'None'),
#   ('old', 'None'),
#   ('style', 'None')]]

# %%
 df = sum(dfAstroNova['tagged'], [])  # Flatt the data by removing first lists
len(df)
# Out:
# 6699

# %%
df[5]
# Out:
# [('Copernicus', 'None'),
#  ('and', 'None'),
#  ('Tycho', 'None'),
#  ('followed', 'None'),
#  ('Ptolemy', 'None'),
#  ('carrying', 'None'),
#  ('over', 'None'),
#  ('his', 'None'),
#  ('assumptions', 'None')]

# %%
df_flatten = sum(df,[]) # Flatt the data by removing the second list

# %%
df_flatten[0:20]  # Here we have tokens (entities) with their labels
# Out:
# [('Chapter', 'None'),
#  ('1', 'NUM'),
#  ('But', 'None'),
#  ('before', 'None'),
#  ('that', 'None'),
#  ('I', 'None'),
#  ('shall', 'None'),
#  ('prove', 'None'),
#  ('in', 'None'),
#  ('this', 'None'),
#  ('first', 'None'),
#  ('part', 'None'),
#  ('that', 'None'),
#  ('one', 'None'),
#  ('who', 'None'),
#  ('substitutes', 'None'),
#  ('the', 'None'),
#  ('sun', 'None'),
#  ('s', 'None'),
#  ('apparent', 'None')]

# %%
len(df_flatten) # Number of all tokens (roughly speaking all words or entities)
# Out:
# 169231

# %%
tokens = [x[0] for x in df_flatten] # Extract the tokens for further use in the frequency plot

# %%
labels=([x[1] for x in df_flatten]) # Extract the labels for further use in the frequency plot

# %%
tokens[0:5]
# Out:
# ['Chapter', '1', 'But', 'before', 'that']

# %%
labels[0:5]
# Out:
# ['None', 'NUM', 'None', 'None', 'None']

# %%
# Frequency plot of all tokens in text, as you see there is a lot 'the', 'of',... in text, they normally consider as noise, we will back to that later.
freqdist = nltk.FreqDist(tokens)
plt.figure(figsize=(25,5))
freqdist.plot(100, title='Frequency plot of words')

# %%
stop_words=["the", "of", "is", "to", "and","in", "be", "at", "that", "from", "it", "a", "as","this", "was" ] # we can consider these as stop words or we can use nltk stop words.

# %%
# nltk stop words
from nltk.corpus import stopwords
stop_words_nltk=set(stopwords.words('english'))

# List of nltk stop words {‘ourselves’, ‘hers’, ‘between’, ‘yourself’, ‘but’, ‘again’, ‘there’, ‘about’, ‘once’, ‘during’, ‘out’, ‘very’, ‘having’, ‘with’, ‘they’, ‘own’, ‘an’, ‘be’, ‘some’, ‘for’, ‘do’, ‘its’, ‘yours’, ‘such’, ‘into’, ‘of’, ‘most’, ‘itself’, ‘other’, ‘off’, ‘is’, ‘s’, ‘am’, ‘or’, ‘who’, ‘as’, ‘from’, ‘him’, ‘each’, ‘the’, ‘themselves’, ‘until’, ‘below’, ‘are’, ‘we’, ‘these’, ‘your’, ‘his’, ‘through’, ‘don’, ‘nor’, ‘me’, ‘were’, ‘her’, ‘more’, ‘himself’, ‘this’, ‘down’, ‘should’, ‘our’, ‘their’, ‘while’, ‘above’, ‘both’, ‘up’, ‘to’, ‘ours’, ‘had’, ‘she’, ‘all’, ‘no’, ‘when’, ‘at’, ‘any’, ‘before’, ‘them’, ‘same’, ‘and’, ‘been’, ‘have’, ‘in’, ‘will’, ‘on’, ‘does’, ‘yourselves’, ‘then’, ‘that’, ‘because’, ‘what’, ‘over’, ‘why’, ‘so’, ‘can’, ‘did’, ‘not’, ‘now’, ‘under’, ‘he’, ‘you’, ‘herself’, ‘has’, ‘just’, ‘where’, ‘too’, ‘only’, ‘myself’, ‘which’, ‘those’, ‘i’, ‘after’, ‘few’, ‘whom’, ‘t’, ‘being’, ‘if’, ‘theirs’, ‘my’, ‘against’, ‘a’, ‘by’, ‘doing’, ‘it’, ‘how’, ‘further’, ‘was’, ‘here’, ‘than’}

# %%
# We can consider these words like 'the', 'of',... as noises. so we temporary remove those!  
new_tokens =[]     

for w in tokens:
    if w not in stop_words_nltk: new_tokens.append(w)

# %%
# Frequency plot of all tokens in text
freqdist = nltk.FreqDist(new_tokens) 
plt.figure(figsize=(25,5)) 
freqdist.plot(100, title='Frequency plot of words after removing noise')

# %%
# This shows where the search words occur in the file which the current entry belongs to. We concentrate on some causal words
mytext = nltk.Text(tokens) 
mytext.dispersion_plot(["since", "as", "for", "because", "cause", "raise", "affects"])

# %%
# A measure of the lexical richness of the text
from __future__ import division  
def lexical_diversity(text):
    a=len(text)/len(set(text))
    return a

# %%
lexical_diversity("mytext")
# Out:
# 1.2

# %%
unique_tokens=sorted(set(mytext))

# %%
print(unique_tokens[0:5] , unique_tokens[5000:5005])  # Samples of unique tokens, see some times two numbers is considered as a token!
# Out:
# ['0\' 33"', '0\' 9"', '000', '000,000', '014'] ['discovery', 'discredited', 'discrepancies', 'discrepancy', 'discrepant']

# %%
len(sorted(set(mytext)))
# Out:
# 9513

# %%
causal_words=list([mytext.count("since"), mytext.count("as") ,mytext.count("for"), mytext.count("because"),  mytext.count("cause"), mytext.count( "raise"),  mytext.count("affects")])

# %%
bar_list=plt.bar(["since", "as" , "for", "because", "cause", "raise","affects"],causal_words) 
plt.title('Frequeny Distribution of some possible causal words ')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Distribution of the different labels

# %%
from collections import Counter
a=Counter(labels)
print(a)
keys=a.keys()
values=a.values()
# Out:
# Counter({'None': 157833, 'GEOM': 5144, 'NUM': 3152, 'COORD': 1230, 'ANG': 705, 'ECLIP': 692, 'DATE': 311, 'TIME': 164})

# %%
# frequency distribution of all the lables
bar_list=plt.bar(a.keys(),a.values()) 
bar_list[0].set_color('r')
plt.title('Frequeny Distribution of all labels ')
plt.xlabel('Labels')
plt.ylabel('Frequency')
plt.show()

# %%
del a['None']
bar_list=plt.bar(a.keys(),a.values() ) 
bar_list[2].set_color('g')
plt.title('Frequeny Distribution of the known labels')
plt.xlabel('Labels')
plt.ylabel('Frequency')
plt.show()

# %%
def pre_process_2(s):
    w = nltk.pos_tag(s)
    return w

# %%
(keys,values)
# Out:
# (dict_keys(['NUM', 'DATE', 'GEOM', 'ECLIP', 'ANG', 'COORD', 'TIME']),
#  dict_values([3152, 311, 5144, 692, 705, 1230, 164]))

# %%
token_tags = pre_process_2(tokens)

# %%
data=[(i, j, k) for ((i, j), k) in zip(token_tags, labels)]

# %%
data[1:3]   # This is very similar to nltk data format, but we need another format which has sentences as a list in order to feed in CRF classifier.
# Out:
# [('1', 'CD', 'NUM'), ('But', 'CC', 'None')]

# %% [markdown]
# ### Make a consistant data with nltk data type

# %%
b=df[1500:1503] # Sentences of the data without POS tagging, It needs to be in the same format of nltk typical data
b
# Out:
# [[('Therefore', 'None'),
#   ('CD', 'GEOM'),
#   ('being', 'None'),
#   ('dropped', 'None'),
#   ('perpendicular', 'None'),
#   ('to', 'None'),
#   ('AB', 'GEOM'),
#   ('where', 'None'),
#   ('AD', 'GEOM'),
#   ('which', 'None'),
#   ('is', 'None'),
#   ('half', 'None'),
#   ('AB', 'GEOM'),
#   ('is', 'None'),
#   ('1000', 'NUM'),
#   ('AC', 'GEOM'),
#   ('will', 'None'),
#   ('be', 'None'),
#   ('3333⅓', 'NUM')],
#  [('Looking', 'None'),
#   ('this', 'None'),
#   ('up', 'None'),
#   ('in', 'None'),
#   ('a', 'None'),
#   ('table', 'None'),
#   ('of', 'None'),
#   ('secants', 'None'),
#   ('we', 'None'),
#   ('find', 'None'),
#   ('the', 'None'),
#   ('angles', 'None'),
#   ('CAD', 'GEOM'),
#   ('and', 'None'),
#   ('CBD', 'GEOM'),
#   ('to', 'None'),
#   ('be', 'None'),
#   ("72° 33'", 'COORD')],
#  [('So', 'None'),
#   ('also', 'None'),
#   ('at', 'None'),
#   ('16°', 'ANG'),
#   ('or', 'None'),
#   ('17°', 'ANG'),
#   ('Aquarius', 'None'),
#   ('with', 'None'),
#   ('AB', 'GEOM'),
#   ('1000', 'NUM'),
#   ('AC', 'GEOM'),
#   ('is', 'None'),
#   ('1375', 'NUM'),
#   ('so', 'None'),
#   ('if', 'None'),
#   ('AD', 'GEOM'),
#   ('1000', 'NUM'),
#   ('AC', 'GEOM'),
#   ('is', 'None'),
#   ('2750', 'NUM'),
#   ('showing', 'None'),
#   ("68° 40'", 'COORD'),
#   ('in', 'None'),
#   ('the', 'None'),
#   ('table', 'None'),
#   ('of', 'None'),
#   ('secants', 'None')]]

# %%
# Put the pos tag of each token in the second component of each tuple.
position_to_add = 1 # 
result = []
for lst in df:
    ret_li = []
    for tpl in lst:
        # new_tpl = [*tpl]
        # new_tpl.append('None')
        new_tpl = tuple([*tpl[0:position_to_add]] + [nltk.tag.pos_tag([tpl[0]])[0][1]] + [*tpl[position_to_add:]])
        ret_li.append(new_tpl)

    result.append(ret_li)

# %%
result[0:2] # Here you see, we have the almost same format of data with nltk data set
# Out:
# [[('Chapter', 'NN', 'None'), ('1', 'CD', 'NUM')],
#  [('But', 'CC', 'None'),
#   ('before', 'IN', 'None'),
#   ('that', 'IN', 'None'),
#   ('I', 'PRP', 'None'),
#   ('shall', 'MD', 'None'),
#   ('prove', 'NN', 'None'),
#   ('in', 'IN', 'None'),
#   ('this', 'DT', 'None'),
#   ('first', 'RB', 'None'),
#   ('part', 'NN', 'None'),
#   ('that', 'IN', 'None'),
#   ('one', 'CD', 'None'),
#   ('who', 'WP', 'None'),
#   ('substitutes', 'NNS', 'None'),
#   ('the', 'DT', 'None'),
#   ('sun', 'NN', 'None'),
#   ('s', 'NN', 'None'),
#   ('apparent', 'NN', 'None'),
#   ('for', 'IN', 'None'),
#   ('its', 'PRP$', 'None'),
#   ('mean', 'NN', 'None'),
#   ('motion', 'NN', 'None'),
#   ('establishes', 'NNS', 'None'),
#   ('a', 'DT', 'None'),
#   ('completely', 'RB', 'None'),
#   ('different', 'JJ', 'None'),
#   ('orbit', 'NN', 'None'),
#   ('for', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('planet', 'NN', 'None'),
#   ('in', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('aether', 'NN', 'None'),
#   ('whichever', 'NN', 'None'),
#   ('of', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('more', 'RBR', 'None'),
#   ('celebrated', 'VBN', 'None'),
#   ('opinions', 'NNS', 'None'),
#   ('of', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('world', 'NN', 'None'),
#   ('he', 'PRP', 'None'),
#   ('follows', 'VBZ', 'None')]]

# %%
len(result)
# Out:
# 6699

# %%
result[0:3]
# Out:
# [[('Chapter', 'NN', 'None'), ('1', 'CD', 'NUM')],
#  [('But', 'CC', 'None'),
#   ('before', 'IN', 'None'),
#   ('that', 'IN', 'None'),
#   ('I', 'PRP', 'None'),
#   ('shall', 'MD', 'None'),
#   ('prove', 'NN', 'None'),
#   ('in', 'IN', 'None'),
#   ('this', 'DT', 'None'),
#   ('first', 'RB', 'None'),
#   ('part', 'NN', 'None'),
#   ('that', 'IN', 'None'),
#   ('one', 'CD', 'None'),
#   ('who', 'WP', 'None'),
#   ('substitutes', 'NNS', 'None'),
#   ('the', 'DT', 'None'),
#   ('sun', 'NN', 'None'),
#   ('s', 'NN', 'None'),
#   ('apparent', 'NN', 'None'),
#   ('for', 'IN', 'None'),
#   ('its', 'PRP$', 'None'),
#   ('mean', 'NN', 'None'),
#   ('motion', 'NN', 'None'),
#   ('establishes', 'NNS', 'None'),
#   ('a', 'DT', 'None'),
#   ('completely', 'RB', 'None'),
#   ('different', 'JJ', 'None'),
#   ('orbit', 'NN', 'None'),
#   ('for', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('planet', 'NN', 'None'),
#   ('in', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('aether', 'NN', 'None'),
#   ('whichever', 'NN', 'None'),
#   ('of', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('more', 'RBR', 'None'),
#   ('celebrated', 'VBN', 'None'),
#   ('opinions', 'NNS', 'None'),
#   ('of', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('world', 'NN', 'None'),
#   ('he', 'PRP', 'None'),
#   ('follows', 'VBZ', 'None')],
#  [('Since', 'IN', 'None'),
#   ('this', 'DT', 'None'),
#   ('proof', 'NN', 'None'),
#   ('depends', 'NNS', 'None'),
#   ('upon', 'IN', 'None'),
#   ('the', 'DT', 'None'),
#   ('equivalence', 'NN', 'None'),
#   ('of', 'IN', 'None'),
#   ('hypotheses', 'NNS', 'None'),
#   ('we', 'PRP', 'None'),
#   ('shall', 'MD', 'None'),
#   ('begin', 'NN', 'None'),
#   ('with', 'IN', 'None'),
#   ('this', 'DT', 'None'),
#   ('equivalence', 'NN', 'None')]]

# %% [markdown]
# ### Train and test split

# %%
# We one consider two third of data as the training set and one-third of data as the testing set
train_sents=result[0:4000]
test_sents=result[4001:]

# %% [markdown]
# ### Features

# %% [markdown]
# Next, define some features. In this example we use word identity, word suffix, word shape and word POS tag; also, some information from nearby words is used.
#
# This makes a simple baseline, but you certainly can add and remove some features to get (much?) better results - experiment with it.
#
# sklearn-crfsuite (and python-crfsuite) supports several feature formats; here we use feature dicts.

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    
    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],        
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True
        
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True
                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
#train and test split based on features
X_train = [sent2features(s) for s in train_sents]
y_train = [sent2labels(s) for s in train_sents]

X_test = [sent2features(s) for s in test_sents]
y_test = [sent2labels(s) for s in test_sents]

# %% [markdown]
# ### Model

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    c1=0.1, 
    c2=0.1, 
    max_iterations=100, 
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# CRF(algorithm='lbfgs', all_possible_states=None,
#   all_possible_transitions=True, averaging=None, c=None, c1=0.1, c2=0.1,
#   calibration_candidates=None, calibration_eta=None,
#   calibration_max_trials=None, calibration_rate=None,
#   calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#   gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#   max_linesearch=None, min_freq=None, model_filename=None,
#   num_memories=None, pa_type=None, period=None, trainer_cls=None,
#   variance=None, verbose=False)

# %% [markdown]
# ### Prediction and Evaluation

# %%
# There is much more "None" entities in data set, but we're more interested in other entities. To account for this we'll use averaged F1 scores computed for all labels except for "None".
labels = list(crf.classes_)
labels.remove('None')
labels
# Out:
# ['NUM', 'DATE', 'GEOM', 'ECLIP', 'ANG', 'COORD', 'TIME']

# %%
# Prediction based on crf model
y_pred = crf.predict(X_test)
print(y_pred[13], y_test[13]) # for intution! a sample of our prediction and real value. It is correct! but how can  we see it for all the data, see next followincells!
# Out:
# ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'GEOM'] ['None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None', 'GEOM']

# %%
metrics.flat_f1_score(y_test, y_pred, 
                      average='weighted', labels=labels)
# Out:
# 0.9556716851686405

# %%
# Is it accuracy a proper metric here?
metrics.flat_accuracy_score(y_test, y_pred)
# Out:
# 0.9959143878545893

# %%
# Result of classification report for evaluation
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#         DATE      0.982     0.955     0.968       112
#        ECLIP      0.989     0.918     0.953       306
#         GEOM      0.990     0.961     0.976      1995
#         TIME      0.868     0.892     0.880        37
#          ANG      0.780     0.770     0.775       244
#        COORD      0.873     0.880     0.877       485
#          NUM      0.987     0.989     0.988      1407
#
#    micro avg      0.964     0.947     0.956      4586
#    macro avg      0.924     0.909     0.917      4586
# weighted avg      0.964     0.947     0.956      4586

# %%
y_test_flatten = sum(y_test, [])
y_pred_flatten = sum(y_pred, [])

# %%
# The result of the confusion matrix, it basically shows how many errors has the prediction through each labels
cm=nltk.ConfusionMatrix(y_test_flatten, y_pred_flatten)
print(cm)
# Out:
#       |           C           E                         |
#       |           O     D     C     G           N     T |
#       |     A     O     A     L     E     N     o     I |
#       |     N     R     T     I     O     U     n     M |
#       |     G     D     E     P     M     M     e     E |
# ------+-------------------------------------------------+
#   ANG |  <188>   54     .     .     .     2     .     . |
# COORD |    43  <427>    .     .     .     3    12     . |
#  DATE |     .     1  <107>    .     .     .     4     . |
# ECLIP |     9     5     .  <281>    .    11     .     . |
#  GEOM |     .     .     .     . <1918>    .    77     . |
#   NUM |     1     .     .     2     . <1391>    8     5 |
#  None |     .     2     2     .    19     .<60008>    . |
#  TIME |     .     .     .     1     .     3     .   <33>|
# ------+-------------------------------------------------+
# (row = reference; col = test)

# %% [markdown]
# ### Inspect Model weights

# %%
eli5.show_weights(crf, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>ANG</th>
#
#                 <th>COORD</th>
#
#                 <th>DATE</th>
#
#                 <th>ECLIP</th>
#
#                 <th>GEOM</th>
#
#                 <th>NUM</th>
#
#                 <th>None</th>
#
#                 <th>TIME</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>ANG</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="ANG &rArr; ANG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.39%)" title="ANG &rArr; COORD">
#                             -0.762
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.73%)" title="ANG &rArr; DATE">
#                             -0.598
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 88.09%)" title="ANG &rArr; ECLIP">
#                             -1.21
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 88.45%)" title="ANG &rArr; GEOM">
#                             -1.159
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 83.92%)" title="ANG &rArr; NUM">
#                             1.859
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.08%)" title="ANG &rArr; None">
#                             0.031
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.99%)" title="ANG &rArr; TIME">
#                             -0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>COORD</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.57%)" title="COORD &rArr; ANG">
#                             -0.502
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.28%)" title="COORD &rArr; COORD">
#                             -0.534
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="COORD &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.18%)" title="COORD &rArr; ECLIP">
#                             -0.082
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.37%)" title="COORD &rArr; GEOM">
#                             -0.071
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 94.12%)" title="COORD &rArr; NUM">
#                             0.442
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.14%)" title="COORD &rArr; None">
#                             -0.085
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="COORD &rArr; TIME">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>DATE</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.44%)" title="DATE &rArr; ANG">
#                             -0.134
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; COORD">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; ECLIP">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.33%)" title="DATE &rArr; GEOM">
#                             -0.419
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; NUM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 95.08%)" title="DATE &rArr; None">
#                             0.343
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; TIME">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>ECLIP</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.29%)" title="ECLIP &rArr; ANG">
#                             -0.424
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 89.60%)" title="ECLIP &rArr; COORD">
#                             -0.997
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="ECLIP &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 81.77%)" title="ECLIP &rArr; ECLIP">
#                             2.223
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.14%)" title="ECLIP &rArr; GEOM">
#                             -0.085
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.51%)" title="ECLIP &rArr; NUM">
#                             -0.062
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.19%)" title="ECLIP &rArr; None">
#                             0.026
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="ECLIP &rArr; TIME">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>GEOM</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 87.64%)" title="GEOM &rArr; ANG">
#                             -1.276
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.13%)" title="GEOM &rArr; COORD">
#                             0.794
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="GEOM &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 93.77%)" title="GEOM &rArr; ECLIP">
#                             0.479
#                         </t

# %% [markdown]
# ### Hyperparameter Optimization

# %%
# %%time
# Define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=100, 
    all_possible_transitions=True
)
params_space = {
    'c1': sp.stats.expon(scale=0.5),
    'c2': sp.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space, 
                        cv=3, 
                        verbose=1, 
                        
                        n_jobs=-1, 
                        n_iter=100, 
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 30.6min finished
# Wall time: 30min 44s

# %% [markdown]
# ## Best result:

# %%
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.026006224468059044, 'c2': 0.006148172343584089}
# best CV score: 0.9064493295354228
# model size: 0.32M

# %%
rs.cv_results_
# Out:
# C:\Users\moha\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\moha\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\moha\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\moha\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\moha\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'mean_fit_time': array([6.92085155, 5.71561702, 6.1322995 , 6.13768331, 6.83018963,
#         6.27217094, 5.70831418, 6.01931262, 5.75102377, 5.92169142,
#         6.02051791, 5.81975468, 6.32412481, 6.04082958, 5.98653396,
#         6.23556678, 6.01147167, 5.93902294, 5.68954953, 6.13595661,
#         5.86477296, 5.86714911, 5.86758471, 5.84261727, 6.004517  ,
#         6.29221503, 5.65649239, 5.85740383, 5.67036446, 5.98037752,
#         5.81645346, 5.95120589, 5.72775785, 5.86622055, 5.86483264,
#         5.68504731, 5.6418283 , 5.86894576, 6.69935942, 5.75001939,
#         5.66788753, 5.8533717 , 6.03710667, 5.89139684, 5.82237275,
#         5.88957763, 6.05389031, 5.95085923, 5.70807179, 5.61701655,
#         5.85321434, 6.28475928, 6.1143283 , 6.18172638, 5.81707215,
#         5.84942317, 5.93403713, 5.8130513 , 5.81181216, 5.73211058,
#         5.59724951, 5.81491431, 5.92911887, 6.00266234, 6.01761603,
#         5.87556283, 5.83407513, 5.76209768, 5.84213225, 5.8526481 ,
#         5.74428217, 5.81426382, 5.78445347, 5.94768572, 5.97536596,
#         5.87729724, 6.3410546 , 6.03088466, 6.03386744, 6.26384767,
#         6.01819928, 6.09354003, 6.25096766, 5.84175253, 6.00398485,
#         5.63692355, 5.64485884, 5.64682921, 5.71729461, 5.80317171,
#         5.83374333, 5.56996067, 5.74234955, 5.7229414 , 5.70301739,
#         5.60345689, 5.63983997, 5.68585261, 5.71484701, 5.75071295]),
#  'std_fit_time': array([1.0633452 , 0.10783676, 0.28832412, 0.85810666, 1.18756178,
#         0.30263398, 0.18079291, 0.06009171, 0.28319717, 0.35359057,
#         0.43021044, 0.30396264, 0.49348805, 0.40379007, 0.30425457,
#         0.41022327, 0.46697427, 0.35971249, 0.22024177, 0.52608256,
#         0.27515714, 0.35921139, 0.30600864, 0.21699625, 0.14458084,
#         0.78132039, 0.22086697, 0.37790045, 0.26805286, 0.32919531,
#         0.3667297 , 0.65779946, 0.22251243, 0.31490332, 0.20772484,
#         0.25718104, 0.16278278, 0.29227733, 1.3202344 , 0.23520148,
#         0.24553112, 0.38000349, 0.39407872, 0.2323777 , 0.20549983,
#         0.13762356, 0.4685894 , 0.316084  , 0.29235183, 0.27654332,
#         0.24756962, 0.41219303, 0.30382659, 0.14879557, 0.2423354 ,
#         0.30299782, 0.44149365, 0.17906767, 0.22487289, 0.19969902,
#         0.1900976 , 0.31709431, 0.32770701, 0.49796265, 0.08033497,
#         0.23999732, 0.41620414, 0.16827771, 0.26798839, 0.20120772,
#         0.20263744, 0.23036244, 0.19688833, 0.20577978, 0.28403148,
#         0.16541631, 0.73946435, 0.26092282, 0.2551961 , 0.18108233,
#         0.21455497, 0.3728482 , 0.69147678, 0.28343478, 0.33493484,
#         0.26219304, 0.30033254, 0.29002725, 0.27457381, 0.47542762,
#         0.51015995, 0.23817792, 0.43573378, 0.13063684, 0.21512143,
#         0.22604334, 0.22215624, 0.249052  , 0.41581606, 0.45051848]),
#  'mean_score_time': array([0.35475628, 0.32779797, 0.36827723, 0.3153851 , 0.30108833,
#         0.32530944, 0.31952786, 0.33146787, 0.33723569, 0.33632517,
#         0.34270883, 0.36026796, 0.37855872, 0.33251826, 0.37835368,
#         0.34650294, 0.32509947, 0.33760142, 0.35928019, 0.3413562 ,
#         0.40581441, 0.33160988, 0.33054916, 0.3545564 , 0.3342456 ,
#         0.33918762, 0.33220641, 0.34643523, 0.33970769, 0.32173379,
#         0.3274099 , 0.34921678, 0.34886678, 0.32805808, 0.36970576,
#         0.35408282, 0.36521514, 0.35407718, 0.3842291 , 0.33325251,
#         0.3346916 , 0.33284616, 0.34810352, 0.37158092, 0.32422519,
#         0.33452392, 0.36448789, 0.33114076, 0.34062258, 0.31487846,
#         0.34702468, 0.36739596, 0.38097231, 0.35568913, 0.35574333,
#         0.35880383, 0.34329669, 0.33702477, 0.34545064, 0.33012907,
#         0.32382123, 0.34790023, 0.35661769, 0.31500864, 0.37627157,
#         0.35676289, 0.32284848, 0.33016443, 0.35044503, 0.35014415,
#         0.3384908 , 0.32310208, 0.34936523, 0.33670775, 0.34009012,
#         0.35072486, 0.3553741 , 0.34706243, 0.34973121, 0.37489756,
#         0.34557144, 0.32997576, 0.32022278, 0.33880226, 0.35928178,
#         0.32500744, 0.33575527, 0.3216842 , 0.34083223, 0.32344683,
#         0.32431602, 0.34277956, 0.33506719, 0.33160583, 0.32539574,
#         0.33815948, 0.32620581, 0.31908139, 0.32379333, 0.32687004]),
#  'std_score_time': array([4.12182889e-02, 3.79579470e-02, 2.40704027e-02, 2.31740434e-02,
#         3.00868167e-02, 3.08462160e-02, 2.73022322e-02, 3.08134223e-02,
#         4.05139616e-02, 2.97268844e-02, 2.85895817e-02, 3.42227357e-02,
#         4.16138646e-02, 2.10040264e-02, 3.13680548e-02, 5.18218636e-02,
#         3.37318027e-02, 1.99502541e-02, 1.50617319e-05, 2.06524798e-02,
#         7.68991916e-02, 2.16370500e-02, 2.40571507e-02, 4.42166306e-02,
#         4.37676602e-02, 3.11598366e-02, 2.55687786e-02, 2.03800738e-02,
#         4.21268816e-02, 3.35038449e-02, 3.46301844e-02, 1.93835783e-02,
#         4.09890504e-02, 1.27677863e-02, 1.94836359e-02, 7.36642641e-03,
#         2.89630910e-02, 1.94765637e-02, 1.55632207e-02, 1.47265023e-02,
#         4.66529055e-02, 2.59165644e-02, 7.96642839e-03, 2.51712899e-02,
#         2.74757023e-02, 6.65655463e-03, 1.94694055e-02, 1.56333716e-02,
#         4.31251858e-02, 2.54200975e-02, 3.74205467e-02, 3.90509068e-02,
#         5.06692847e-02, 3.43395152e-02, 3.27347343e-02, 4.76795832e-02,
#         5.25236278e-02, 3.07785208e-02, 3.33283737e-02, 2.18821481e-02,
#         1.97919679e-02, 3.11143988e-02, 5.33297841e-02, 2.58517247e-02,
#         3.38065778e-02, 1.02035116e-02, 3.21012965e-02, 2.07812277e-02,
#         3.79783384e-02, 4.89841696e-02, 2.78949120e-02, 3.86858383e-02,
#         4.76078557e-02, 3.84543467e-02, 2.55962076e-02, 1.78903742e-02,
#         8.92376221e-03, 1.81245026e-02, 3.57022673e-02, 3.14071702e-02,
#         3.80776486e-02, 2.42446213e-02, 2.35608377e-02, 2.14813972e-02,
#         6.00743075e-02, 3.81656544e-02, 3.58706582e-02, 3.27519045e-02,
#         3.98100423e-02, 2.81205814e-02, 3.43141896e-02, 2.27471738e-02,
#         2.98584328e-02, 3.42600357e-02, 3.34698877e-02, 3.46996923e-02,
#         4.05626072e-02, 3.13758347e-02, 2.90892662e-02, 2.08109528e-02]),
#  'param_c1': masked_array(data=[0.18833483396684259, 1.2147169601815384,
#                     0.2673147841242122, 1.5741861761984857,
#                     2.070902573149958, 1.7413199833472877,
#                     0.28554388110877643, 2.08258146911218,
#                     0.5560118391144688, 0.8019395511030996,
#                     0.23421169480508863, 0.3831317360295659,
#                     0.27415700665462533, 2.332242258822471,
#                     0.16991117281468582, 0.35222102974488506,
#                     1.1602135207342736, 0.13145628430658446,
#                     0.49668203112897447, 0.34242067231860124,
#                     0.31655848964664773, 2.0434549737455816,
#                     0.04446901836502886, 0.6488781429292753,
#                     1.2036642611183435, 0.8501837255503651,
#                     0.987765813103878, 0.10420879105905256,
#                     0.10718830325359578, 0.5125927880352945,
#                     0.14498169276274522, 0.3140608612149746,
#                     0.18481209636349447, 0.21587569162001402,
#                     0.3994855985522479, 0.1863610011511443,
#                     1.4968457905143484, 0.07607622622242446,
#                     1.573710525976324, 0.17459150386048483,
#                     0.08292481117120727, 0.5685550815290717,
#                     0.34344218020697026, 0.9089270415067378,
#                     0.702706475522861, 0.43916796983824724,
#                     0.9197331231472748, 0.17929703274827744,
#                     0.03019739764984096, 0.6997987434850637,
#                     0.4223366337550307, 0.03151466446988614,
#                     0.044763164830144114, 0.40011124955973915,
#                     0.12490530944368607, 0.20015044567526824,
#                     0.6477971651771233, 0.00634841831513775,
#                     0.019784174453814037, 0.09641653860223509,
#                     0.6473923138577373, 0.13064814744230455,
#                     1.1538165054323453, 1.113677575403683,
#                     0.022628846590637967, 0.24557728821587788,
#                     0.5414897973973868, 0.3142399221625702,
#                     0.07659063179375984, 0.06360274616753017,
#                     0.053857466411589165, 0.3970343990237562,
#                     0.12564341798407272, 0.17956907211165113,
#                     0.20643846188170795, 0.026006224468059044,
#                     0.24499868681852602, 0.16389620782533904,
#                     1.179625164157633, 1.332014266576424,
#                     1.9348197332945307, 0.6033774977412296,
#                     1.784080037996089, 0.036877971822216145,
#                     0.23887637333547987, 1.209449170482768,
#                     0.07138343890596564, 0.6753705206395707,
#                     0.2790340954116206, 0.3911648162958407,
#                     0.19919741830018445, 0.06478522320360043,
#                     0.33743661479132436, 0.04625175895189195,
#                     0.6147803859054335, 0.13238471552859854,
#                     0.46099489482993056, 0.1947207656645708,
#                     0.2611341813292749, 0.16407119514708962],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_c2': masked_array(data=[0.052011588831326866, 0.04257961411192765,
#                     0.019845232706698912, 0.0814042498492469,
#                     0.026245504800525555, 0.08059874804179794,
#                     0.05445413056277418, 0.15258283500139877,
#                     0.050107171407197754, 0.18878792209311865,
#                     0.035035150691902654, 0.05770039658989721,
#                     0.1149382042583363, 0.009990034119876277,
#                     0.014543942931222213, 0.03791412979461167,
#                     0.09128179038685262, 0.019434837118073964,
#                     0.12688625607875365, 0.0722459538256342,
#                     0.08059517520726346, 0.026646306046960305,
#                     0.006651516238097251, 0.005767972257201664,
#                     0.04602451508925564, 0.055462080416121155,
#                     0.1335740865686463, 0.007328757797434073,
#                     0.01398970703211009, 0.018226227463605776,
#                     0.11458248386774644, 0.040996243158823276,
#                     0.1870511570610635, 0.019870484915481483,
#                     0.07623086888801245, 0.03202579761212738,
#                     0.09524484944940415, 0.004304345917039622,
#                     0.08221331511618248, 0.010014253424766178,
#                     0.044350790707127746, 0.04348133800546292,
#                     0.054023247821704035, 0.05519105447665465,
#                     0.01790343511856354, 0.0001721473813590041,
#                     0.04934043670477549, 0.014380458461771328,
#                     0.05192783276613704, 0.06069310530471209,
#                     0.11477095632848658, 0.04531590507411777,
#                     0.03374057210629999, 0.024375899041210673,
#                     0.02139186380487193, 0.014617853066554817,
#                     0.015332225563459296, 0.04368534474402074,
#                     0.09414423007242206, 0.016317200801310883,
#                     0.06988513754415543, 0.01935101705458817,
#                     0.001305128713593155, 0.006941287200950812,
#                     0.14739527963616864, 0.001521346431106021,
#                     0.012354981773464944, 0.013977966538297762,
#                     0.1286599968203849, 0.2681970264844006,
#                     0.0297339650279327, 0.13375970367522125,
#                     0.0460933724390353, 0.0003080750831008322,
#                     0.0010173919198806422, 0.006148172343584089,
#                     0.06881783967843604, 0.014301363043322921,
#                     0.0509572334200975, 0.06971851816031316,
#                     0.05462517951552386, 0.04300325716983644,
#                     0.013681729711349393, 0.1417705169448201,
#                     0.2386161294097852, 0.03413255029069264,
#                     0.054110650542878606, 0.021154082544428663,
#                     0.09660819938214352, 0.06281279877957643,
#                     0.1275166958817747, 0.058861817502801284,
#                     0.0642782512554153, 0.04093028188525258,
#                     0.09786791672521919, 0.04348581062961145,
#                     0.006366824989714373, 0.06331533541114209,
#                     0.013022283305732425, 0.05380507997149863],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'c1': 0.18833483396684259, 'c2': 0.052011588831326866},
#   {'c1': 1.2147169601815384, 'c2': 0.04257961411192765},
#   {'c1': 0.2673147841242122, 'c2': 0.019845232706698912},
#   {'c1': 1.5741861761984857, 'c2': 0.0814042498492469},
#   {'c1': 2.070902573149958, 'c2': 0.026245504800525555},
#   {'c1': 1.7413199833472877, 'c2': 0.08059874804179794},
#   {'c1': 0.28554388110877643, 'c2': 0.05445413056277418},
#   {'c1': 2.08258146911218, 'c2': 0.15258283500139877},
#   {'c1': 0.5560118391144688, 'c2': 0.050107171407197754},
#   {'c1': 0.8019395511030996, 'c2': 0.18878792209311865},
#   {'c1': 0.23421169480508863, 'c2': 0.035035150691902654},
#   {'c1': 0.3831317360295659, 'c2': 0.05770039658989721},
#   {'c1': 0.27415700665462533, 'c2': 0.1149382042583363},
#   {'c1': 2.332242258822471, 'c2': 0.009990034119876277},
#   {'c1': 0.16991117281468582, 'c2': 0.014543942931222213},
#   {'c1': 0.35222102974488506, 'c2': 0.03791412979461167},
#   {'c1': 1.1602135207342736, 'c2': 0.09128179038685262},
#   {'c1': 0.13145628430658446, 'c2': 0.019434837118073964},
#   {'c1': 0.49668203112897447, 'c2': 0.12688625607875365},
#   {'c1': 0.34242067231860124, 'c2': 0.0722459538256342},
#   {'c1': 0.31655848964664773, 'c2': 0.08059517520726346},
#   {'c1': 2.0434549737455816, 'c2': 0.026646306046960305},
#   {'c1': 0.04446901836502886, 'c2': 0.006651516238097251},
#   {'c1': 0.6488781429292753, 'c2': 0.005767972257201664},
#   {'c1': 1.2036642611183435, 'c2': 0.04602451508925564},
#   {'c1': 0.8501837255503651, 'c2': 0.055462080416121155},
#   {'c1': 0.987765813103878, 'c2': 0.1335740865686463},
#   {'c1': 0.10420879105905256, 'c2': 0.007328757797434073},
#   {'c1': 0.10718830325359578, 'c2': 0.01398970703211009},
#   {'c1': 0.5125927880352945, 'c2': 0.018226227463605776},
#   {'c1': 0.14498169276274522, 'c2': 0.11458248386774644},
#   {'c1': 0.3140608612149746, 'c2': 0.040996243158823276},
#   {'c1': 0.18481209636349447, 'c2': 0.1870511570610635},
#   {'c1': 0.21587569162001402, 'c2': 0.019870484915481483},
#   {'c1': 0.3994855985522479, 'c2': 0.07623086888801245},
#   {'c1': 0.1863610011511443, 'c2': 0.03202579761212738},
#   {'c1': 1.4968457905143484, 'c2': 0.09524484944940415},
#   {'c1': 0.07607622622242446, 'c2': 0.004304345917039622},
#   {'c1': 1.573710525976324, 'c2': 0.08221331511618248},
#   {'c1': 0.17459150386048483, 'c2': 0.010014253424766178},
#   {'c1': 0.08292481117120727, 'c2': 0.044350790707127746},
#   {'c1': 0.5685550815290717, 'c2': 0.04348133800546292},
#   {'c1': 0.34344218020697026, 'c2': 0.054023247821704035},
#   {'c1': 0.9089270415067378, 'c2': 0.05519105447665465},
#   {'c1': 0.702706475522861, 'c2': 0.01790343511856354},
#   {'c1': 0.43916796983824724, 'c2': 0.0001721473813590041},
#   {'c1': 0.9197331231472748, 'c2': 0.04934043670477549},
#   {'c1': 0.17929703274827744, 'c2': 0.014380458461771328},
#   {'c1': 0.03019739764984096, 'c2': 0.05192783276613704},
#   {'c1': 0.6997987434850637, 'c2': 0.06069310530471209},
#   {'c1': 0.4223366337550307, 'c2': 0.11477095632848658},
#   {'c1': 0.03151466446988614, 'c2': 0.04531590507411777},
#   {'c1': 0.044763164830144114, 'c2': 0.03374057210629999},
#   {'c1': 0.40011124955973915, 'c2': 0.024375899041210673},
#   {'c1': 0.12490530944368607, 'c2': 0.02139186380487193},
#   {'c1': 0.20015044567526824, 'c2': 0.014617853066554817},
#   {'c1': 0.6477971651771233, 'c2': 0.015332225563459296},
#   {'c1': 0.00634841831513775, 'c2': 0.04368534474402074},
#   {'c1': 0.019784174453814037, 'c2': 0.09414423007242206},
#   {'c1': 0.09641653860223509, 'c2': 0.016317200801310883},
#   {'c1': 0.6473923138577373, 'c2': 0.06988513754415543},
#   {'c1': 0.13064814744230455, 'c2': 0.01935101705458817},
#   {'c1': 1.1538165054323453, 'c2': 0.001305128713593155},
#   {'c1': 1.113677575403683, 'c2': 0.006941287200950812},
#   {'c1': 0.022628846590637967, 'c2': 0.14739527963616864},
#   {'c1': 0.24557728821587788, 'c2': 0.001521346431106021},
#   {'c1': 0.5414897973973868, 'c2': 0.012354981773464944},
#   {'c1': 0.3142399221625702, 'c2': 0.013977966538297762},
#   {'c1': 0.07659063179375984, 'c2': 0.1286599968203849},
#   {'c1': 0.06360274616753017, 'c2': 0.2681970264844006},
#   {'c1': 0.053857466411589165, 'c2': 0.0297339650279327},
#   {'c1': 0.3970343990237562, 'c2': 0.13375970367522125},
#   {'c1': 0.12564341798407272, 'c2': 0.0460933724390353},
#   {'c1': 0.17956907211165113, 'c2': 0.0003080750831008322},
#   {'c1': 0.20643846188170795, 'c2': 0.0010173919198806422},
#   {'c1': 0.026006224468059044, 'c2': 0.006148172343584089},
#   {'c1': 0.24499868681852602, 'c2': 0.06881783967843604},
#   {'c1': 0.16389620782533904, 'c2': 0.014301363043322921},
#   {'c1': 1.179625164157633, 'c2': 0.0509572334200975},
#   {'c1': 1.332014266576424, 'c2': 0.06971851816031316},
#   {'c1': 1.9348197332945307, 'c2': 0.05462517951552386},
#   {'c1': 0.6033774977412296, 'c2': 0.04300325716983644},
#   {'c1': 1.784080037996089, 'c2': 0.013681729711349393},
#   {'c1': 0.036877971822216145, 'c2': 0.1417705169448201},
#   {'c1': 0.23887637333547987, 'c2': 0.2386161294097852},
#   {'c1': 1.209449170482768, 'c2': 0.03413255029069264},
#   {'c1': 0.07138343890596564, 'c2': 0.054110650542878606},
#   {'c1': 0.6753705206395707, 'c2': 0.021154082544428663},
#   {'c1': 0.2790340954116206, 'c2': 0.09660819938214352},
#   {'c1': 0.3911648162958407, 'c2': 0.06281279877957643},
#   {'c1': 0.19919741830018445, 'c2': 0.1275166958817747},
#   {'c1': 0.06478522320360043, 'c2': 0.058861817502801284},
#   {'c1': 0.33743661479132436, 'c2': 0.0642782512554153},
#   {'c1': 0.04625175895189195, 'c2': 0.04093028188525258},
#   {'c1': 0.6147803859054335, 'c2': 0.09786791672521919},
#   {'c1': 0.13238471552859854, 'c2': 0.04348581062961145},
#   {'c1': 0.46099489482993056, 'c2': 0.006366824989714373},
#   {'c1': 0.1947207656645708, 'c2': 0.06331533541114209},
#   {'c1': 0.2611341813292749, 'c2': 0.013022283305732425},
#   {'c1': 0.16407119514708962, 'c2': 0.05380507997149863}],
#  'split0_test_score': array([0.83437505, 0.80707238, 0.832781  , 0.80006979, 0.78930403,
#         0.79147865, 0.8320172 , 0.78266027, 0.82118361, 0.80736775,
#         0.8347947 , 0.8284006 , 0.82807249, 0.78528458, 0.83606152,
#         0.82586395, 0.80986552, 0.8401911 , 0.82028051, 0.82986788,
#         0.82865088, 0.79088223, 0.84812764, 0.81706158, 0.80657722,
#         0.8146901 , 0.80801222, 0.84044125, 0.84187975, 0.82414239,
#         0.82984068, 0.83026311, 0.82476182, 0.83392439, 0.82813505,
#         0.83619601, 0.79890322, 0.83943077, 0.79888497, 0.83653475,
#         0.83680982, 0.82352441, 0.83087945, 0.81561491, 0.81579731,
#         0.82431011, 0.8128806 , 0.83718783, 0.84118572, 0.81922402,
#         0.82537132, 0.84119741, 0.84073973, 0.82926876, 0.84149985,
#         0.83644563, 0.8195129 , 0.8461253 , 0.83768376, 0.84527576,
#         0.81997548, 0.84249465, 0.80934158, 0.80910053, 0.83421387,
#         0.83065136, 0.82359679, 0.82914267, 0.83266811, 0.82280743,
#         0.84318184, 0.82237201, 0.83900363, 0.82639178, 0.83248676,
#         0.85195146, 0.83042113, 0.83716947, 0.8045577 , 0.80325234,
#         0.78698899, 0.82069251, 0.79505592, 0.83238792, 0.82166101,
#         0.80531659, 0.83683806, 0.82038687, 0.82654687, 0.82807051,
#         0.82590787, 0.83748403, 0.8302251 , 0.8390623 , 0.82116986,
#         0.84008711, 0.82565395, 0.83218111, 0.83182568, 0.83714118]),
#  'split1_test_score': array([0.92137497, 0.9094756 , 0.92556168, 0.90335568, 0.89758087,
#         0.90054035, 0.92105647, 0.89268903, 0.91856257, 0.90813299,
#         0.92453688, 0.91974395, 0.91936249, 0.89369188, 0.92676769,
#         0.92327758, 0.90976459, 0.92387014, 0.91753651, 0.91877417,
#         0.91885678, 0.89833626, 0.92870808, 0.91996164, 0.90855036,
#         0.91372789, 0.90770499, 0.92745339, 0.92817128, 0.92030877,
#         0.91929107, 0.92260455, 0.91107066, 0.92516185, 0.91845131,
#         0.92460184, 0.90321399, 0.92896717, 0.90143154, 0.92772506,
#         0.92484596, 0.9174458 , 0.92204626, 0.91437361, 0.91843809,
#         0.92081073, 0.91393829, 0.92577065, 0.920169  , 0.91579614,
#         0.91544639, 0.9209148 , 0.92388245, 0.92147537, 0.92523209,
#         0.92545383, 0.91865327, 0.92080258, 0.91608502, 0.92561674,
#         0.91618994, 0.92526525, 0.91185604, 0.91210749, 0.91274983,
#         0.92413229, 0.91915617, 0.92300304, 0.9155673 , 0.90640418,
#         0.92397099, 0.91545542, 0.92445371, 0.92468511, 0.92508849,
#         0.92759849, 0.92154582, 0.92716919, 0.91112706, 0.90755948,
#         0.8985479 , 0.91613084, 0.89822304, 0.91446446, 0.90931034,
#         0.90961977, 0.92302636, 0.91832318, 0.91867187, 0.91940685,
#         0.91489889, 0.92193597, 0.91928437, 0.92369188, 0.9164236 ,
#         0.92436428, 0.92056218, 0.92243653, 0.92412083, 0.92563965]),
#  'split2_test_score': array([0.93429221, 0.90855268, 0.93591425, 0.89410573, 0.87221906,
#         0.88329365, 0.93340279, 0.86230518, 0.92931921, 0.90670586,
#         0.9350269 , 0.93197443, 0.92588234, 0.8675189 , 0.93778613,
#         0.93553928, 0.90817391, 0.93602349, 0.91987398, 0.92970302,
#         0.93219338, 0.87892312, 0.94071981, 0.93146465, 0.91057822,
#         0.9179146 , 0.90434242, 0.94112179, 0.93697904, 0.93706804,
#         0.92589618, 0.93269534, 0.92001893, 0.9366588 , 0.92832286,
#         0.93648631, 0.89139234, 0.94035988, 0.88691807, 0.9364514 ,
#         0.93331111, 0.92686336, 0.93168747, 0.91433117, 0.92680041,
#         0.94093899, 0.91668266, 0.93824202, 0.93218105, 0.92066228,
#         0.92315567, 0.93167423, 0.93426268, 0.93985913, 0.93645262,
#         0.9361633 , 0.929262  , 0.93400445, 0.92540995, 0.93827646,
#         0.92526022, 0.93723707, 0.91660377, 0.91818811, 0.92070955,
#         0.94071421, 0.93629493, 0.93902734, 0.92210074, 0.91191397,
#         0.93526044, 0.92391187, 0.93362048, 0.94190755, 0.94345079,
#         0.93983892, 0.93277903, 0.93784886, 0.91321378, 0.90108351,
#         0.87935597, 0.92817652, 0.89009417, 0.91918932, 0.91337066,
#         0.91113505, 0.93284669, 0.92888341, 0.92877845, 0.93156492,
#         0.92465553, 0.9300498 , 0.93078911, 0.93126936, 0.91685002,
#         0.93518621, 0.9391677 , 0.9316784 , 0.93704734, 0.93395239]),
#  'mean_test_score': array([0.89666517, 0.87501656, 0.89806932, 0.86582729, 0.85301872,
#         0.85842081, 0.89547629, 0.84586902, 0.88967134, 0.87405219,
#         0.89810366, 0.89335675, 0.89109002, 0.8488159 , 0.90018908,
#         0.89487635, 0.87591815, 0.90001328, 0.8858806 , 0.89276596,
#         0.89321754, 0.85603091, 0.90583741, 0.88947785, 0.87521811,
#         0.88209401, 0.87333688, 0.90298983, 0.90232824, 0.89382231,
#         0.89166052, 0.89517144, 0.88526867, 0.89856551, 0.89162053,
#         0.899079  , 0.86448678, 0.9029034 , 0.86239564, 0.90022115,
#         0.89830692, 0.88926142, 0.89485506, 0.88142344, 0.88699413,
#         0.89533552, 0.88115011, 0.90038436, 0.89783109, 0.88521098,
#         0.88797547, 0.89791463, 0.89961357, 0.89685085, 0.90104663,
#         0.89933853, 0.88912532, 0.90029723, 0.89304573, 0.90304188,
#         0.88712509, 0.90165087, 0.87924965, 0.87978103, 0.88921066,
#         0.89848232, 0.89299861, 0.8970407 , 0.89009769, 0.8803608 ,
#         0.90079002, 0.88723021, 0.89901094, 0.89764366, 0.90032505,
#         0.90644933, 0.8948992 , 0.90071328, 0.87628158, 0.87061493,
#         0.85494729, 0.88831638, 0.86110786, 0.88866649, 0.88143239,
#         0.87533963, 0.89755519, 0.88918062, 0.8913162 , 0.89299786,
#         0.88847179, 0.89647518, 0.89341706, 0.89799311, 0.88479858,
#         0.89986425, 0.89511058, 0.8954162 , 0.89764816, 0.89889563]),
#  'std_test_score': array([0.04437665, 0.04806329, 0.04637606, 0.04666801, 0.0462437 ,
#         0.04787347, 0.0451712 , 0.04640039, 0.04864487, 0.0471743 ,
#         0.04498723, 0.04621859, 0.04465621, 0.04619275, 0.04558446,
#         0.04907335, 0.04672829, 0.04260634, 0.04641347, 0.04471543,
#         0.04599594, 0.0467607 , 0.04111568, 0.05143999, 0.04856169,
#         0.04771025, 0.04622921, 0.04459551, 0.04291045, 0.0497621 ,
#         0.04381266, 0.04609872, 0.04295643, 0.04596553, 0.04508827,
#         0.04474542, 0.04664227, 0.04513896, 0.04531461, 0.04519058,
#         0.04363834, 0.04665915, 0.04542536, 0.04655111, 0.05047819,
#         0.05090878, 0.04830493, 0.04499239, 0.04036824, 0.04671957,
#         0.04439609, 0.04035985, 0.0418607 , 0.04839107, 0.04237001,
#         0.04470294, 0.04943192, 0.03869678, 0.03934606, 0.0411876 ,
#         0.04764383, 0.04212983, 0.04948897, 0.05005898, 0.03903864,
#         0.04845679, 0.04958888, 0.04847253, 0.04071152, 0.04077372,
#         0.04101015, 0.04600855, 0.04261209, 0.05088951, 0.04856876,
#         0.03887271, 0.0458399 , 0.04516002, 0.05074261, 0.04772368,
#         0.04870596, 0.04808728, 0.04684097, 0.03985658, 0.04231307,
#         0.04953619, 0.04313626, 0.04885332, 0.04600137, 0.04619515,
#         0.0444348 , 0.04185992, 0.04494623, 0.0418006 , 0.04500951,
#         0.04251479, 0.0497152 , 0.04488953, 0.04685901, 0.04381496]),
#  'rank_test_score': array([ 36,  87,  27,  91,  98,  95,  38, 100,  59,  88,  26,  48,  57,
#          99,  15,  44,  84,  16,  72,  53,  49,  96,   2,  60,  86,  76,
#          89,   4,   6,  46,  54,  41,  73,  23,  55,  20,  92,   5,  93,
#          14,  25,  61,  45,  78,  71,  40,  79,  11,  30,  74,  68,  29,
#          18,  35,   8,  19,  64,  13,  50,   3,  70,   7,  82,  81,  62,
#          24,  51,  34,  58,  80,   9,  69,  21,  32,  12,   1,  43,  10,
#          83,  90,  97,  67,  94,  65,  77,  85,  33,  63,  56,  52,  66,
#          37,  47,  28,  75,  17,  42,  39,  31,  22]),
#  'split0_train_score': array([0.9999001 , 0.9694836 , 1.        , 0.96075581, 0.95194999,
#         0.95682715, 0.99920168, 0.949292  , 0.98646316, 0.97233262,
#         1.        , 0.9972007 , 0.99690246, 0.94956674, 1.        ,
#         0.99940059, 0.96784925, 1.        , 0.98767266, 0.99780249,
#         0.99790243, 0.95297587, 1.        , 0.98404594, 0.96976475,
#         0.97598836, 0.97048562, 1.        , 1.        , 0.99059338,
#         0.99870219, 0.99960035, 0.99660065, 1.        , 0.99549792,
#         1.        , 0.96097156, 1.        , 0.96068602, 1.        ,
#         1.        , 0.98626655, 0.99860265, 0.97518111, 0.9809313 ,
#         0.99930041, 0.97515659, 1.        , 1.        , 0.97922126,
#         0.99179326, 1.        , 1.        , 0.99910105, 1.        ,
#         1.        , 0.98346632, 1.        , 1.        , 1.        ,
#         0.98153406, 1.        , 0.97122496, 0.97264771, 0.99950072,
#         1.        , 0.98918854, 1.        , 0.99930082, 0.99690122,
#         1.        , 0.99168517, 1.        , 1.        , 1.        ,
#         1.        , 0.9992011 , 1.        , 0.96927952, 0.9653888 ,
#         0.95407085, 0.98535099, 0.95857926, 0.99950072, 0.99410556,
#         0.96988178, 1.        , 0.98295013, 0.99740272, 0.99630723,
#         0.99770195, 1.        , 0.99800284, 1.        , 0.9820347 ,
#         1.        , 0.9974997 , 0.9999001 , 1.        , 0.9999001 ]),
#  'split1_train_score': array([1.        , 0.96727713, 1.        , 0.95327049, 0.94128688,
#         0.94793481, 0.99987424, 0.93524775, 0.98881751, 0.97253028,
#         1.        , 0.99748629, 0.99773932, 0.93693489, 1.        ,
#         0.99899505, 0.96649205, 1.        , 0.98831339, 0.99773901,
#         0.99799196, 0.94296775, 1.        , 0.98707343, 0.96552918,
#         0.97812705, 0.97041721, 1.        , 1.        , 0.99160024,
#         0.99949744, 0.99987424, 0.99723561, 1.        , 0.99510214,
#         1.        , 0.95531101, 1.        , 0.95189201, 1.        ,
#         1.        , 0.98793719, 0.99886914, 0.9772809 , 0.98430398,
#         0.99974874, 0.97589277, 1.        , 1.        , 0.98241164,
#         0.99258597, 1.        , 1.        , 0.99937153, 1.        ,
#         1.        , 0.98668049, 1.        , 1.        , 1.        ,
#         0.98404596, 1.        , 0.97109548, 0.97317088, 0.99987424,
#         1.        , 0.99034534, 1.        , 0.99987424, 0.99736073,
#         1.        , 0.99220422, 1.        , 1.        , 1.        ,
#         1.        , 0.99987424, 1.        , 0.96754015, 0.96331693,
#         0.94297088, 0.98630839, 0.94877021, 0.99987424, 0.99321652,
#         0.96807839, 1.        , 0.98518259, 0.99824018, 0.99598219,
#         0.99899505, 1.        , 0.99861745, 1.        , 0.98366301,
#         1.        , 0.99849212, 0.99987424, 1.        , 1.        ]),
#  'split2_train_score': array([1.        , 0.95662402, 1.        , 0.94237542, 0.93213159,
#         0.93749104, 1.        , 0.92668371, 0.98205184, 0.96658514,
#         1.        , 0.9961209 , 0.9962239 , 0.92628612, 1.        ,
#         0.999353  , 0.95763635, 1.        , 0.98237549, 0.99697926,
#         0.99719845, 0.93354485, 1.        , 0.98032958, 0.95688699,
#         0.97119866, 0.96155056, 1.        , 1.        , 0.98770801,
#         0.99956861, 1.        , 0.99579147, 1.        , 0.99406553,
#         1.        , 0.94417873, 1.        , 0.94111828, 1.        ,
#         1.        , 0.98269139, 0.99870534, 0.96757417, 0.97684225,
#         0.99989207, 0.96791884, 1.        , 1.        , 0.97554962,
#         0.98908142, 1.        , 1.        , 0.99935272, 1.        ,
#         1.        , 0.97880162, 1.        , 1.        , 1.        ,
#         0.97823672, 1.        , 0.96159487, 0.96229088, 0.99989206,
#         1.        , 0.98542236, 1.        , 0.99978419, 0.99621882,
#         1.        , 0.98963826, 1.        , 1.        , 1.        ,
#         1.        , 0.99978432, 1.        , 0.95840678, 0.95163615,
#         0.93296725, 0.9799668 , 0.93950926, 0.99989206, 0.99202946,
#         0.9574558 , 1.        , 0.97772111, 0.99708638, 0.99493123,
#         0.99838179, 1.        , 0.9977354 , 1.        , 0.97683657,
#         1.        , 0.9990291 , 1.        , 1.        , 1.        ]),
#  'mean_train_score': array([0.9999667 , 0.96446158, 1.        , 0.95213391, 0.94178949,
#         0.94741767, 0.99969198, 0.93707449, 0.9857775 , 0.97048268,
#         1.        , 0.99693596, 0.99695523, 0.93759592, 1.        ,
#         0.99924954, 0.96399255, 1.        , 0.98612051, 0.99750692,
#         0.99769761, 0.94316282, 1.        , 0.98381631, 0.9640603 ,
#         0.97510469, 0.96748446, 1.        , 1.        , 0.98996721,
#         0.99925608, 0.99982487, 0.99654258, 1.        , 0.99488853,
#         1.        , 0.9534871 , 1.        , 0.9512321 , 1.        ,
#         1.        , 0.98563171, 0.99872571, 0.97334539, 0.98069251,
#         0.99964708, 0.9729894 , 1.        , 1.        , 0.97906084,
#         0.99115355, 1.        , 1.        , 0.9992751 , 1.        ,
#         1.        , 0.98298281, 1.        , 1.        , 1.        ,
#         0.98127224, 1.        , 0.96797177, 0.96936982, 0.99975567,
#         1.        , 0.98831875, 1.        , 0.99965308, 0.99682693,
#         1.        , 0.99117588, 1.        , 1.        , 1.        ,
#         1.        , 0.99961989, 1.        , 0.96507548, 0.96011396,
#         0.94333633, 0.9838754 , 0.94895291, 0.99975567, 0.99311718,
#         0.96513866, 1.        , 0.98195128, 0.99757643, 0.99574022,
#         0.9983596 , 1.        , 0.99811856, 1.        , 0.98084476,
#         1.        , 0.99834031, 0.99992478, 1.        , 0.9999667 ]),
#  'std_train_score': array([4.70923512e-05, 5.61472534e-03, 0.00000000e+00, 7.54667626e-03,
#         8.09862850e-03, 7.90239902e-03, 3.50469677e-04, 9.31974136e-03,
#         2.80430217e-03, 2.75715954e-03, 0.00000000e+00, 5.88010735e-04,
#         6.19790508e-04, 9.51575897e-03, 0.00000000e+00, 1.81002523e-04,
#         4.52853682e-03, 0.00000000e+00, 2.66101720e-03, 3.74009134e-04,
#         3.54849059e-04, 7.93387712e-03, 0.00000000e+00, 2.75795087e-03,
#         5.35894028e-03, 2.89670026e-03, 4.19599525e-03, 0.00000000e+00,
#         0.00000000e+00, 1.64953203e-03, 3.92736165e-04, 1.66849574e-04,
#         5.90993993e-04, 0.00000000e+00, 6.03965807e-04, 0.00000000e+00,
#         6.97590008e-03, 0.00000000e+00, 8.00211159e-03, 0.00000000e+00,
#         0.00000000e+00, 2.18813079e-03, 1.09746800e-04, 4.16993662e-03,
#         3.05091340e-03, 2.52013687e-04, 3.59800090e-03, 0.00000000e+00,
#         0.00000000e+00, 2.80370361e-03, 1.50052999e-03, 0.00000000e+00,
#         0.00000000e+00, 1.23314069e-04, 0.00000000e+00, 0.00000000e+00,
#         3.23465162e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.37882529e-03, 0.00000000e+00, 4.50946081e-03, 5.01012418e-03,
#         1.80427997e-04, 0.00000000e+00, 2.10180055e-03, 0.00000000e+00,
#         2.51786593e-04, 4.69135969e-04, 0.00000000e+00, 1.10771837e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         2.98394580e-04, 0.00000000e+00, 4.76864974e-03, 6.05409507e-03,
#         8.61938401e-03, 2.79129478e-03, 7.78636634e-03, 1.80427997e-04,
#         8.50468713e-04, 5.48226073e-03, 0.00000000e+00, 3.12694886e-03,
#         4.86787794e-04, 5.87228005e-04, 5.28135923e-04, 0.00000000e+00,
#         3.69277852e-04, 0.00000000e+00, 2.91113309e-03, 0.00000000e+00,
#         6.33534701e-04, 5.42248127e-05, 0.00000000e+00, 4.70923512e-05])}

# %% [markdown]
# x = [s.['c1'] for s in rs.cv_results__]
# _y = [s.params['c2'] for s in rs.cv_results_]
# _c = [s.mean_validation_score for s in rs.cv_results_]
#
# fig = plt.figure()
# fig.set_size_inches(12, 12)
# ax = plt.gca()
# ax.set_yscale('log')
# ax.set_xscale('log')
# ax.set_xlabel('C1')
# ax.set_ylabel('C2')
# ax.set_title("Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".format(
#     min(_c), max(_c)
# ))
#
# ax.scatter(_x, _y, c=_c, s=60, alpha=0.9, edgecolors=[0,0,0])
#
# print("Dark blue => {:0.4}, dark red => {:0.4}".format(min(_c), max(_c)))

# %% [markdown]
# ### Prediction and Evaluation after parameter tuning

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#               precision    recall  f1-score   support
#
#         DATE      0.991     0.991     0.991       112
#        ECLIP      0.990     0.944     0.967       306
#         GEOM      0.988     0.970     0.979      1995
#         TIME      0.875     0.946     0.909        37
#          ANG      0.809     0.783     0.796       244
#        COORD      0.883     0.903     0.893       485
#          NUM      0.992     0.989     0.991      1407
#
#    micro avg      0.968     0.957     0.963      4586
#    macro avg      0.933     0.932     0.932      4586
# weighted avg      0.968     0.957     0.963      4586

# %%
y_test_flatten = sum(y_test, [])
y_pred_flatten = sum(y_pred, [])

# %%
cm_tuned=nltk.ConfusionMatrix(y_test_flatten,y_pred_flatten)
print(cm_tuned)
# Out:
#       |           C           E                         |
#       |           O     D     C     G           N     T |
#       |     A     O     A     L     E     N     o     I |
#       |     N     R     T     I     O     U     n     M |
#       |     G     D     E     P     M     M     e     E |
# ------+-------------------------------------------------+
#   ANG |  <191>   51     .     .     .     2     .     . |
# COORD |    37  <438>    .     .     .     2     8     . |
#  DATE |     .     1  <111>    .     .     .     .     . |
# ECLIP |     7     4     .  <289>    .     6     .     . |
#  GEOM |     .     .     .     . <1935>    .    60     . |
#   NUM |     1     .     .     2     . <1392>    7     5 |
#  None |     .     2     1     .    23     .<60005>    . |
#  TIME |     .     .     .     1     .     1     .   <35>|
# ------+-------------------------------------------------+
# (row = reference; col = test)

# %%
dfAstroNova.text.iloc[201]
# Out:
# 'the elongation of the place opposite the sun from the same node, is made equal to AC (the observed distance of the planet from the node).'

# %%
eli5.show_weights(rs.best_estimator_, top=30)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>ANG</th>
#
#                 <th>COORD</th>
#
#                 <th>DATE</th>
#
#                 <th>ECLIP</th>
#
#                 <th>GEOM</th>
#
#                 <th>NUM</th>
#
#                 <th>None</th>
#
#                 <th>TIME</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>ANG</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.91%)" title="ANG &rArr; ANG">
#                             -0.049
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.25%)" title="ANG &rArr; COORD">
#                             -0.965
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.96%)" title="ANG &rArr; DATE">
#                             -0.568
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 83.74%)" title="ANG &rArr; ECLIP">
#                             -2.338
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 86.84%)" title="ANG &rArr; GEOM">
#                             -1.729
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 85.92%)" title="ANG &rArr; NUM">
#                             1.903
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.83%)" title="ANG &rArr; None">
#                             -0.132
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="ANG &rArr; TIME">
#                             -0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>COORD</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.07%)" title="COORD &rArr; ANG">
#                             -0.692
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.74%)" title="COORD &rArr; COORD">
#                             -0.739
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="COORD &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="COORD &rArr; ECLIP">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="COORD &rArr; GEOM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 96.59%)" title="COORD &rArr; NUM">
#                             0.251
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.27%)" title="COORD &rArr; None">
#                             -0.285
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="COORD &rArr; TIME">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>DATE</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.87%)" title="DATE &rArr; ANG">
#                             -0.223
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; COORD">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; ECLIP">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.03%)" title="DATE &rArr; GEOM">
#                             -0.43
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; NUM">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 99.46%)" title="DATE &rArr; None">
#                             0.018
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="DATE &rArr; TIME">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>ECLIP</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.64%)" title="ECLIP &rArr; ANG">
#                             -0.479
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 85.59%)" title="ECLIP &rArr; COORD">
#                             -1.968
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="ECLIP &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 80.00%)" title="ECLIP &rArr; ECLIP">
#                             3.143
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.64%)" title="ECLIP &rArr; GEOM">
#                             -0.356
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.51%)" title="ECLIP &rArr; NUM">
#                             -0.372
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.63%)" title="ECLIP &rArr; None">
#                             -0.15
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="ECLIP &rArr; TIME">
#                             0.0
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>GEOM</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 85.97%)" title="GEOM &rArr; ANG">
#                             -1.894
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 89.80%)" title="GEOM &rArr; COORD">
#                             1.201
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="GEOM &rArr; DATE">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 92.62%)" title="GEOM &rArr; ECLIP">
#                             0.757
#                         </td>

# %%
eli5.show_weights(rs.best_estimator_, top=10, targets=['GEOM', 'NUM', 'ANG'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>GEOM</th>
#
#                 <th>NUM</th>
#
#                 <th>ANG</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>GEOM</th>
#
#                         <td style="background-color: hsl(120, 100.00%, 88.27%)" title="GEOM &rArr; GEOM">
#                             1.306
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 90.96%)" title="GEOM &rArr; NUM">
#                             -0.9
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 84.78%)" title="GEOM &rArr; ANG">
#                             -1.894
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>NUM</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 93.57%)" title="NUM &rArr; GEOM">
#                             -0.553
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 80.00%)" title="NUM &rArr; NUM">
#                             -2.799
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 94.06%)" title="NUM &rArr; ANG">
#                             0.494
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>ANG</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 85.73%)" title="ANG &rArr; GEOM">
#                             -1.729
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 84.73%)" title="ANG &rArr; NUM">
#                             1.903
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.82%)" title="ANG &rArr; ANG">
#                             -0.049
#                         </td>
#
#                 </tr>
#
#
#     </tbody>
# </table>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=GEOM
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=NUM
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=ANG
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.310
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         postag:NNP
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.837
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:βδ
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.501
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:αε
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.62%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.319
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:βα
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.256
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:δζ
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.156
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:αθ
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.062
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:γζ
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.917
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:αδ
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.900
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         word[-2:]:αζ
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 88.31%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 1253 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 93 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.557

# %% [markdown]
# ### Let's check what classifier learned

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# ECLIP  -> ECLIP   3.142696
# None   -> None    2.643471
# ANG    -> NUM     1.903495
# NUM    -> COORD   1.574189
# GEOM   -> GEOM    1.305645
# GEOM   -> COORD   1.200722
# TIME   -> NUM     1.028966
# GEOM   -> ECLIP   0.756929
# TIME   -> GEOM    0.653263
# NUM    -> ANG     0.493646
# COORD  -> NUM     0.251070
# NUM    -> None    0.174796
# NUM    -> TIME    0.147537
# None   -> ANG     0.067199
# None   -> TIME    0.057953
# DATE   -> None    0.018268
# GEOM   -> None    0.009266
# ANG    -> TIME    -0.000022
# ANG    -> ANG     -0.049181
# ANG    -> None    -0.131541
#
# Top unlikely transitions:
# ECLIP  -> GEOM    -0.356349
# ECLIP  -> NUM     -0.372038
# DATE   -> GEOM    -0.429718
# None   -> NUM     -0.453703
# TIME   -> None    -0.470243
# ECLIP  -> ANG     -0.478697
# NUM    -> GEOM    -0.553384
# TIME   -> COORD   -0.554750
# ANG    -> DATE    -0.567712
# None   -> COORD   -0.603801
# COORD  -> ANG     -0.692070
# COORD  -> COORD   -0.738859
# GEOM   -> NUM     -0.899904
# ANG    -> COORD   -0.964655
# NUM    -> ECLIP   -1.560647
# ANG    -> GEOM    -1.728780
# GEOM   -> ANG     -1.894295
# ECLIP  -> COORD   -1.967915
# ANG    -> ECLIP   -2.337725
# NUM    -> NUM     -2.799362

# %% [markdown]
#  Check the state features:

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))    

print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
# 10.371512 NUM      word.isdigit()
# 7.979126 COORD    word[-2:]:0'
# 7.728360 COORD    word[-2:]:2'
# 7.725321 COORD    word[-2:]:6'
# 7.688046 ANG      word[-2:]:0°
# 7.585716 ANG      word[-2:]:5°
# 7.498884 COORD    word[-2:]:4'
# 7.413887 COORD    word[-2:]:5'
# 7.382821 DATE     word[-2:]:3
# 7.332347 COORD    word[-2:]:8'
# 7.323168 COORD    word[-2:]:9'
# 7.232795 None     word[-2:]:er
# 7.093053 DATE     word[-2:]:9
# 7.080598 COORD    word[-2:]:3'
# 6.913781 ANG      word[-2:]:1°
# 6.904348 COORD    word[-2:]:7'
# 6.885529 None     word[-2:]:le
# 6.857414 DATE     word[-2:]:1
# 6.802992 ANG      word[-2:]:2°
# 6.793481 TIME     word[-2:]:0m
# 6.783135 None     word[-2:]:ne
# 6.722620 DATE     word[-2:]:0
# 6.704888 ANG      word[-2:]:4°
# 6.700219 COORD    word[-2:]:1'
# 6.638983 ANG      word[-2:]:6°
# 6.634014 DATE     word[-2:]:8
# 6.601872 ANG      word[-2:]:9°
# 6.502404 None     word[-2:]:nt
# 6.499947 ANG      word.lower():43' 46"
# 6.499473 COORD    word[-2:]:0"
#
# Top negative:
# -1.429465 None     -1:word.lower():eccentric
# -1.473330 None     -1:word.lower():arc
# -1.494824 None     -1:word.lower():side
# -1.679942 COORD    +1:word.lower():that
# -1.682669 None     -1:word.lower():ecliptic
# -1.686873 DATE     bias
# -1.756093 None     -1:word.lower():triangles
# -1.762901 COORD    +1:word.lower():of
# -1.771923 ANG      +1:word.lower():as
# -1.792277 None     -1:word.lower():angle
# -1.828813 COORD    postag[:2]:NN
# -1.838356 COORD    BOS
# -1.838842 TIME     word.istitle()
# -1.872266 COORD    -1:postag:VBG
# -1.975767 COORD    +1:word.lower():at
# -2.047312 NUM      word.istitle()
# -2.136006 None     -1:word.lower():triangle
# -2.159900 GEOM     -1:word.lower():s
# -2.300576 None     -1:word.lower():radius
# -2.331004 COORD    -1:word.lower():mars
# -2.338439 GEOM     -1:word.lower():at
# -2.454984 ECLIP    word.istitle()
# -2.694538 DATE     EOS
# -3.003285 GEOM     postag:NNS
# -3.970447 None     postag:CD
# -3.970447 None     postag[:2]:CD
# -4.182706 COORD    word.isupper()
# -4.466992 ECLIP    word.isdigit()
# -4.831834 DATE     word.isupper()
# -10.557279 GEOM     word.istitle()
