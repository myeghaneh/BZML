# %% [markdown]
# # Print Annotation's result based on trained spaCy model (ALL Labels*)

# %% [markdown]
# <fig size= 4>
# This notebook provides a colorfull print of  labeld data. The data first is annotated label by label using regex and then corrected by annotator* using prodigy interface. We also made a  SpaCy model for Named Entity Recognition for each labels. Furtheremore, in each step of merging we made a  customized model of spacy regarding to each step of merging. Finally  You can see the result of annotation as colorfull print in the end of notebook </p>
# *Here we runned the model only on the annotated data by regex with out correcting by annotator
# </fig size= 4>

# %%
import spacy 
from spacy import displacy

# %% [markdown]
# ## Read the Data

# %%
import pandas as pd
importVersion = '013'

# %%
path= '../data/01_df_v{0}.pickle'.format(importVersion)# Put the path of the data in your local machine here, consider the letter "r" before the path
dfAstroNova = pd.read_pickle(path)

# %%
type(dfAstroNova)
# Out:
# pandas.core.frame.DataFrame

# %%
dfAstroNova.head(5)
# Out:
#                                                 html  \
# 0                                  <p>Appendix B</p>
# 1  <p><span class="anchor" id="bookmark0"></span>...
# 2  <p>by Yaakov Zik <span style="font-variant: sm...
# 3  <p><span class="anchor" id="bookmark1"></span>...
# 4                              <p>General notes:</p>
#
#                                                 text links italic     chapter  \
# 0                                         Appendix B    []     []  appendix b
# 1          On the Table of Oppositions in Chapter 15    []     []  appendix b
# 2                             by Yaakov Zik Table i:    []     []  appendix b
# 3  Initial positions of Mars in Chapter 15 comput...    []     []  appendix b
# 4                                     General notes:    []     []  appendix b
#
#   graphic table marginal                                          sentences  \
# 0      []    []       []                                       [Appendix B]
# ...

# %%
texts=[]
for sen in dfAstroNova.sentences:
    texts +=sen

# %%
texts=texts[1000:2000]

# %%
str1 = ''.join(texts)

# %%
type(texts)
# Out:
# list

# %%
pwd
# Out:
# 'C:\\Users\\moha\\Documents\\vorlesung2019\\notebooks\\yeghaneh\\ml\\notebooks'

# %%
path= '../data/Model_LABEL_01_02'
nlp=spacy.load(path)

# %%
nlp=spacy.load(path)

# %%
doc=nlp(str1)

# %%
displacy.render(doc,style="ent",jupyter="True" )
# Out:
# <div class="entities" style="line-height: 2.5">But let AH be the line of the apogee, or the line of the aphelion in the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Copernican
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ...

# %% [markdown]
# # Result of annotation based on that model on other books
