# %%
import pandas as pd
path= '../data/signor.xlsx'
data = pd.read_excel(path)

# %% [markdown]
# # Protein-Protein Relation Extraction data set Signor

# %%
data.head()
# Out:
#    ENTITYA    TYPEA     IDA DATABASEA ENTITYB    TYPEB     IDB DATABASEB  \
# 0    MAPK1  protein  P28482   UNIPROT   CASP9  protein  P55211   UNIPROT
# 1  RPS6KA1  protein  Q15418   UNIPROT   CREB1  protein  P16220   UNIPROT
# 2      FES  protein  P07332   UNIPROT     BCR  protein  P11274   UNIPROT
# 3     HES1  protein  Q14469   UNIPROT    DTX1  protein  Q86Y01   UNIPROT
# 4     JAK2  protein  O60674   UNIPROT    JAK2  protein  O60674   UNIPROT
#
#                                   EFFECT                   MECHANISM  \
# 0                down-regulates activity             phosphorylation
# 1                  up-regulates activity             phosphorylation
# 2                down-regulates activity             phosphorylation
# 3  down-regulates quantity by repression  transcriptional regulation
# 4                  up-regulates activity             phosphorylation
#
#        ...       MODIFICATIONA MODASEQ  MODIFICATIONB MODBSEQ      PMID  \
# ...

# %%
data.tail()
# Out:
#       ENTITYA    TYPEA     IDA DATABASEA ENTITYB    TYPEB     IDB DATABASEB  \
# 22845  PRKACA  protein  P17612   UNIPROT   STMN1  protein  P16949   UNIPROT
# 22846     SRC  protein  P12931   UNIPROT   PTPN6  protein  P29350   UNIPROT
# 22847     SRC  protein  P12931   UNIPROT   PTPN6  protein  P29350   UNIPROT
# 22848   STK11  protein  Q15831   UNIPROT   MARK3  protein  P27448   UNIPROT
# 22849   STK11  protein  Q15831   UNIPROT   MARK3  protein  P27448   UNIPROT
#
#                       EFFECT        MECHANISM      ...       MODIFICATIONA  \
# 22845         down-regulates  phosphorylation      ...                 NaN
# 22846           up-regulates  phosphorylation      ...                 NaN
# 22847           up-regulates  phosphorylation      ...                 NaN
# 22848  up-regulates activity  phosphorylation      ...                 NaN
# 22849  up-regulates activity  phosphorylation      ...                 NaN
#
# ...
