# %% [markdown]
# # Print Annotation's result based on trained spaCy model (ALL Labels before edition*)

# %% [markdown]
# <fig size= "4">
# This notebook provides a colorfull print of  labeld data. The data first is annotated label by label using regex and then corrected by annotator* using prodigy interface. We also made a  SpaCy model for Named Entity Recognition for each labels. Furtheremore, in each step of merging we made a  customized model of spacy regarding to each step of merging. Finally  You can see the result of annotation as colorfull print in the end of notebook </p>
# </fig size= "4">

# %%
import spacy 
from spacy import displacy

# %% [markdown]
# ## Read the Data

# %%
import pandas as pd
import numpy as np
importVersion = '013'

# %%
path= '../data/01_df_v{0}.pickle'.format(importVersion)# Put the path of the data in your local machine here, consider the letter "r" before the path
dfAstroNova = pd.read_pickle(path)

# %%
# Sort the data based on the chapters of the book 
dfAstroNova['chapter'] = dfAstroNova.chapter.replace("appendix b",np.nan).astype(float)  
dfAstroNova = dfAstroNova.rename_axis('MyIdx').sort_values(by = ['chapter', 'MyIdx'], ascending = [True, True])
dfAstroNova.chapter.fillna('appendix b', inplace=True)

# %%
dfAstroNova.reset_index(inplace=True)
dfAstroNova=dfAstroNova.drop("MyIdx",axis=1,inplace=False)
dfAstroNova=dfAstroNova.drop("html",axis=1)

# %%
type(dfAstroNova)
# Out:
# pandas.core.frame.DataFrame

# %%
dfAstroNova.head(5)
# Out:
#                                                 text links   italic chapter  \
# 0                                          Chapter 1    []       []       1
# 1  On the distinction between the first motion an...    []       []       1
# 2  The testimony of the ages confirms that the mo...    []       []       1
# 3  It is just this from which astronomy arose amo...    []       []       1
# 4  Before the distinction between the first motio...    []  [(such]       1
#
#         graphic table                                           marginal  \
# 0            []    []                                                 []
# 1            []    []                                                 []
# 2            []    []  [ Terms: 1. The first motion is that of the wh...
# 3  [ ch 1 gr 1]    []                                                 []
# 4            []    []                                               [ 2]
#
#                                            sentences  \
# 0                                        [Chapter 1]
# 1  [On the distinction between the first motion a...
# 2  [The testimony of the ages confirms that the m...
# 3  [It is just this from which astronomy arose am...
# 4  [Before the distinction between the first moti...
#
#                                               tagged
# 0                      [[(Chapter, None), (1, NUM)]]
# 1  [[(On, None), (the, None), (distinction, None)...
# 2  [[(The, None), (testimony, None), (of, None), ...
# 3  [[(It, None), (is, None), (just, None), (this,...
# 4  [[(Before, None), (the, None), (distinction, N...

# %%
texts=[]
for sen in dfAstroNova.sentences:
    texts +=sen

# %%
str1 = ' '.join(texts)

# %%
len(texts)
# Out:
# 6699

# %% [markdown]
# *We resample data to make NER faster*

# %%
texts=texts[0:1000]  #choose part of data

# %%
type(texts)
# Out:
# list

# %% [markdown]
# # Upload customized spaCy model provioded by our training data in prodigy

# %%
path= '../data/Model_06'
nlp=spacy.load(path)

# %%
dfAstroNova['entities'] = dfAstroNova['text'].apply(lambda x: nlp(x).ents)

# %%
dfAstroNova.head(20)
# Out:
#                                                  text  \
# 0                                           Chapter 1
# 1   On the distinction between the first motion an...
# 2   The testimony of the ages confirms that the mo...
# 3   It is just this from which astronomy arose amo...
# 4   Before the distinction between the first motio...
# 5   as here ABCE, FMNG cutting the equator AB in C...
# 6   This first adumbration of astronomy consists, ...
# 7   For it was helpful to astronomers to understan...
# 8   This turned out to be of great profit in astro...
# 9   Now that the first and diurnal motion had thus...
# 10  If one were to bundle all this together, and w...
# 11   This is the accurate depiction of the motions...
# 12  Again, however, it was noticed that these loop...
# 13  From these observations it came to be understo...
# 14  Now the causes and measures of these inequalit...
# 15  But since the sun's mean and apparent motions*...
# 16  But before that, I shall prove in this first p...
# 17                                          Chapter 2
# 18  On the first and simple equivalence, that of t...
# 19  And now, to begin, I take up the equivalence o...
#
#                                                 links  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'#fn1': 'The Greek word hypate actually mean...
# 6   [{'#fn4': 'Francesco Patrizi (1529-1597), prof...
# 7                                                  []
# 8                                                  []
# 9   [{'#fn5': 'Latin, a terris, ad terras. Use of ...
# 10  [{'#fn6': 'The Latin is panis quadragesimalis,...
# 11  [{'#fn7': 'a Here and in the following sentenc...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19  [{'#fn1': 'Kepler uses the late Latin word sal...
#
#                                                italic chapter       graphic  \
# 0                                                  []       1            []
# 1                                                  []       1            []
# 2                                                  []       1            []
# 3                                                  []       1  [ ch 1 gr 1]
# 4                                             [(such]       1            []
# 5   [as here ABCE, FMNG cutting the equator AB in ...       1  [ ch 2 gr 2]
# 6                                                  []       1            []
# 7   [and in its proper motion FG, (such as the moo...       1            []
# 8   [a new one always being added to the end of th...       1            []
# 9                                                  []       1            []
# 10                                                 []       1  [ ch 1 gr 3]
# 11                                           [A,, B.]       1            []
# 12                                                 []       1            []
# 13                                                 []       1            []
# 14                                                 []       1            []
# 15                        [Mysterium cosmographicum,]       1            []
# 16                                                 []       1            []
# 17                                                 []       2            []
# 18  [<strong>On the first and simple equivalence, ...       2            []
# 19                                                 []       2            []
#
#    table                                           marginal  \
# 0     []                                                 []
# 1     []                                                 []
# 2     []  [ Terms: 1. The first motion is that of the wh...
# 3     []                                                 []
# 4     []                                               [ 2]
# 5     []                                                 []
# 6     []                                                 []
# 7     []  [ Term: * "In consequence" means "according to...
# 8     []                                               [ 3]
# 9     []                                                 []
# 10    []                                                 []
# 11    []                                               [ 4]
# 12    []                                                 []
# 13    []  [ The sun has only a single inequality, with r...
# 14    []                                               [ 5]
# 15    []  [ Terms: * The sun's apparent position is that...
# 16    []                                                 []
# 17    []                                                 []
# 18    []                                                 []
# 19    []                                                 []
#
#                                             sentences  \
# 0                                         [Chapter 1]
# 1   [On the distinction between the first motion a...
# 2   [The testimony of the ages confirms that the m...
# 3   [It is just this from which astronomy arose am...
# 4   [Before the distinction between the first moti...
# 5   [as here ABCE, FMNG cutting the equator AB in ...
# 6   [This first adumbration of astronomy consists,...
# 7   [For it was helpful to astronomers to understa...
# 8   [This turned out to be of great profit in astr...
# 9   [Now that the first and diurnal motion had thu...
# 10  [If one were to bundle all this together, and ...
# 11  [This is the accurate depiction of the motions...
# 12  [Again, however, it was noticed that these loo...
# 13  [From these observations it came to be underst...
# 14  [Now the causes and measures of these inequali...
# 15  [But since the sun's mean and apparent motions...
# 16  [But before that, I shall prove in this first ...
# 17                                        [Chapter 2]
# 18  [On the first and simple equivalence, that of ...
# 19  [And now, to begin, I take up the equivalence ...
#
#                                                tagged  \
# 0                       [[(Chapter, None), (1, NUM)]]
# 1   [[(On, None), (the, None), (distinction, None)...
# 2   [[(The, None), (testimony, None), (of, None), ...
# 3   [[(It, None), (is, None), (just, None), (this,...
# 4   [[(Before, None), (the, None), (distinction, N...
# 5   [[(as, None), (here, None), (ABCE, GEOM), (FMN...
# 6   [[(This, None), (first, None), (adumbration, N...
# 7   [[(For, None), (it, None), (was, None), (helpf...
# 8   [[(This, None), (turned, None), (out, None), (...
# 9   [[(Now, None), (that, None), (the, None), (fir...
# 10  [[(If, None), (one, None), (were, None), (to, ...
# 11  [[(This, None), (is, None), (the, None), (accu...
# 12  [[(Again, None), (however, None), (it, None), ...
# 13  [[(From, None), (these, None), (observations, ...
# 14  [[(Now, None), (the, None), (causes, None), (a...
# 15  [[(But, None), (since, None), (the, None), (su...
# 16  [[(But, None), (before, None), (that, None), (...
# 17                      [[(Chapter, None), (2, NUM)]]
# 18  [[(On, None), (the, None), (first, None), (and...
# 19  [[(And, None), (now, None), (to, None), (begin...
#
#                                              entities
# 0                                                  ()
# 1                                                  ()
# 2                                           ((rise),)
# 3                                                  ()
# 4                                        ((diurnal),)
# 5   ((north), (south), (diurnal), (apparent, motio...
# 6                                    ((Patricius,4),)
# 7   ((diurnal), (retrograde), (fixed, star), (fixe...
# 8                             ((Aristarchus), (axis))
# 9   ((diurnal), (diurnal), (observed), (diurnal), ...
# 10                        ((Tycho, Brahe), (diagram))
# 11  ((star), (Mars), (orb), (Mars), (Venus), (Merc...
# 12                                    ((retrograde),)
# 13                                                 ()
# 14  ((rise), (conjunction), (opposition), (conjunc...
# 15                       ((opposition), (Copernicus))
# 16                                ((orbit), (aether))
# 17                                                 ()
# 18                          ((eccentric), (epicycle))
# 19                                    ((Copernicus),)

# %%
dfAstroNova.entities[290]
# Out:
# (1592 January 23,
#  10h 15m,
#  Mars,
#  11° 34’ 30” Aries,
#  latitude,
#  south,
#  altitude,
#  Mars,
#  refraction,
#  parallax,
#  Mars,
#  latitude,
#  Mars,
#  parallax,
#  ecliptic,
#  February 6,
#  latitude)
