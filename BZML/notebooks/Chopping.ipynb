# %%
import pandas as pd
import numpy as np

# %%
options = {"compact": True, "bg": "#09a3d5",
           "color": "white", "font": "Source Sans Pro","collapse_phrases":False}

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# ## Resources

# %% [markdown]
# ### Import resources

# %%
df=pd.read_json('../data/dfObsR01V05A02.json');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6699 entries, 0 to 6698
# Data columns (total 7 columns):
# Chapter      6699 non-null object
# ParaIndex    6699 non-null int64
# SentIndex    6699 non-null int64
# Paragraph    6699 non-null object
# Sentence     6699 non-null object
# Entities     6699 non-null object
# Label        6699 non-null object
# dtypes: int64(2), object(5)
# memory usage: 418.7+ KB

# %%
df.head()
# Out:
#   Chapter  ParaIndex  SentIndex  \
# 0       1          0          0
# 1       1          1          1
# 2       1          2          2
# 3       1          2          3
# 4       1          2          4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Paragraph  \
# ...

# %%
df.tail()
# Out:
#          Chapter  ParaIndex  SentIndex  \
# 6694  appendix b       1603       6694
# 6695  appendix b       1603       6695
# 6696  appendix b       1604       6696
# 6697  appendix b       1604       6697
# 6698  appendix b       1604       6698
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Paragraph  \
# ...

# %%
df['Chapter'] = df.Chapter.replace("appendix b",0)
df.Chapter.fillna('appendix b', inplace=True)
df['Chapter'] = df.Chapter.astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6699 entries, 0 to 6698
# Data columns (total 7 columns):
# Chapter      6699 non-null int64
# ParaIndex    6699 non-null int64
# SentIndex    6699 non-null int64
# Paragraph    6699 non-null object
# Sentence     6699 non-null object
# Entities     6699 non-null object
# Label        6699 non-null object
# dtypes: int64(3), object(4)
# memory usage: 418.7+ KB

# %%
df[df.Chapter==35]
# Out:
#       Chapter  ParaIndex  SentIndex  \
# 3175       35        738       3175
# 3176       35        739       3176
# 3177       35        740       3177
# 3178       35        741       3178
# 3179       35        741       3179
# 3180       35        742       3180
# 3181       35        742       3181
# 3182       35        743       3182
# 3183       35        743       3183
# 3184       35        743       3184
# 3185       35        743       3185
# 3186       35        744       3186
# 3187       35        744       3187
# 3188       35        745       3188
# 3189       35        745       3189
# 3190       35        745       3190
# 3191       35        745       3191
# 3192       35        745       3192
# 3193       35        745       3193
# 3194       35        746       3194
# 3195       35        746       3195
# 3196       35        746       3196
# 3197       35        747       3197
# 3198       35        747       3198
# 3199       35        747       3199
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6699 entries, 0 to 6698
# Data columns (total 7 columns):
# Chapter      6699 non-null int64
# ParaIndex    6699 non-null int64
# SentIndex    6699 non-null int64
# Paragraph    6699 non-null object
# Sentence     6699 non-null object
# Entities     6699 non-null object
# Label        6699 non-null object
# dtypes: int64(3), object(4)
# memory usage: 418.7+ KB

# %%
dfPart1=df[(df["Chapter"] >=1) & (df["Chapter"] <=6 )]
dfPart2=df[(df["Chapter"] >=7) &  (df["Chapter"] <=21)]
dfPart3=df[(df["Chapter"] >=22) &  (df["Chapter"] <=40)]
dfPart4=df[(df["Chapter"] >=41) &  (df["Chapter"] <=60)]
dfPart5=df[(df["Chapter"] >=61) &  (df["Chapter"] <=70)]

# %%
dfPart3=dfPart5.sort_index();
dfPart3=dfPart5.reset_index(drop=True)
dfPart3.head()
# Out:
#    Chapter  ParaIndex  SentIndex  \
# 0       61       1402       5865
# 1       61       1403       5866
# 2       61       1404       5867
# 3       61       1404       5868
# 4       61       1405       5869
#
# ...

# %%
dfPart1.to_json("../data/dfObsR01V05A02P01.json")
dfPart2.to_json("../data/dfObsR01V05A02P02.json")
dfPart3.to_json("../data/dfObsR01V05A02P03.json")
dfPart4.to_json("../data/dfObsR01V05A02P04.json")
dfPart5.to_json("../data/dfObsR01V05A02P05.json")

# %%
dfPart1.to_pickle("../data/dfObsR01V05A02P01.pkl")
dfPart2.to_pickle("../data/dfObsR01V05A02P02.pkl")
dfPart3.to_pickle("../data/dfObsR01V05A02P03.pkl")
dfPart4.to_pickle("../data/dfObsR01V05A02P04.pkl")
dfPart5.to_pickle("../data/dfObsR01V05A02P05.pkl")
