# %%
import pandas as pd
import numpy as np

# %%
options = {"compact": True, "bg": "#09a3d5",
           "color": "white", "font": "Source Sans Pro","collapse_phrases":False}

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# ## Resources

# %% [markdown]
# ### Import resources

# %%
df=pd.read_json('../data/dfObsR01V05A02.json');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6699 entries, 0 to 6698
# Data columns (total 7 columns):
# Chapter      6699 non-null object
# ParaIndex    6699 non-null int64
# SentIndex    6699 non-null int64
# Paragraph    6699 non-null object
# Sentence     6699 non-null object
# Entities     6699 non-null object
# Label        6699 non-null object
# dtypes: int64(2), object(5)
# memory usage: 418.7+ KB

# %%
df.head()
# Out:
#   Chapter  ParaIndex  SentIndex  \
# 0       1          0          0
# 1       1          1          1
# 2       1          2          2
# 3       1          2          3
# 4       1          2          4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Paragraph  \
# ...

# %%
df['Chapter'] = df.chapter.replace("appendix b",0)
df=df.Chapter.astype("int64")
#df.Chapter.fillna('appendix b', inplace=True)
#df['ParaIndex'] = df.ParaIndex.astype(float)

# %%
df[df.Chapter=="1"]
# Out:
# Empty DataFrame
# Columns: [Chapter, ParaIndex, SentIndex, Paragraph, Sentence, Entities, Label]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6699 entries, 0 to 6698
# Data columns (total 9 columns):
# Sentence     6699 non-null object
# SentIndex    6699 non-null int64
# Chapter      6699 non-null float64
# Paragraph    6699 non-null object
# ParaIndex    6699 non-null int64
# ASO          6699 non-null object
# Entities     6699 non-null object
# CNER         6699 non-null object
# Label        6699 non-null int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 523.4+ KB

# %%
dfPart1=df[(df["Chapter"] >=1) & (df["Chapter"] <=6 )]
dfPart2=df[(df["Chapter"] >=7) &  (df["Chapter"] <=21)]
dfPart3=df[(df["Chapter"] >=22) &  (df["Chapter"] <=40)]
dfPart4=df[(df["Chapter"] >=41) &  (df["Chapter"] <=60)]
dfPart5=df[(df["Chapter"] >=61) &  (df["Chapter"] <=70)]

# %%
dfPart5
# Out:
#                                                                                                                                                                                                                                                                                                                                                       Sentence  \
# 5865                                                                                                                                                                                                                                                                                                                                                Chapter 61
# ...

# %%
dfPart1.to_json("../data/dfObsV05A02P01.json")
dfPart2.to_json("../data/dfObsV05A02P02.json")
dfPart3.to_json("../data/dfObsV05A02P03.json")
dfPart4.to_json("../data/dfObsV05A02P04.json")
dfPart5.to_json("../data/dfObsV05A02P05.json")

# %%
dfPart1.to_pickle("../data/dfObsV05A02P01.pkl")
dfPart2.to_pickle("../data/dfObsV05A02P02.pkl")
dfPart3.to_pickle("../data/dfObsV05A02P03.pkl")
dfPart4.to_pickle("../data/dfObsV05A02P04.pkl")
dfPart5.to_pickle("../data/dfObsV05A02P05.pkl")
