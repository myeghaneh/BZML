# %% [markdown]
#  # Regex and Prodigy

# %% [markdown]
# <font size= "3">
# Annotation of entities for sentences based on prodigy's format for different labels for further usage in Machine learning. Prodigy is an annotation tool based on spaCy. Please see here:
#     </p>
#   <a href="https://prodi.gy/ "> Prodigy </a>
# <font 3>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import re
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
import spacy 
import re
from prodigy.util import write_jsonl

# %%
pwd
# Out:
# 'C:\\Projects_28_06\\notebooks\\yeghaneh\\BZML\\notebooks'

# %% [markdown]
# ## Read the Data

# %%
importVersion = '013'

# %%
path= '../data/01_df_v{0}.pickle'.format(importVersion)# Put the path of the data in your local machine here, consider the letter "r" before the path
dfAstroNova = pd.read_pickle(path)

# %% [markdown]
# # Sort based on the Chapter

# %%
# Sort the data based on the chapters of the book 
dfAstroNova['chapter'] = dfAstroNova.chapter.replace("appendix b",np.nan).astype(float)  
dfAstroNova = dfAstroNova.rename_axis('MyIdx').sort_values(by = ['chapter', 'MyIdx'], ascending = [True, True])
dfAstroNova.chapter.fillna('appendix b', inplace=True)

# %%
dfAstroNova.reset_index(inplace=True)
dfAstroNova=dfAstroNova.drop("MyIdx",axis=1,inplace=False)
dfAstroNova=dfAstroNova.drop("html",axis=1)

# %%
type(dfAstroNova)
# Out:
# pandas.core.frame.DataFrame

# %%
dfAstroNova.head(5)
# Out:
#                                                 text links   italic chapter  \
# 0                                          Chapter 1    []       []       1
# 1  On the distinction between the first motion an...    []       []       1
# 2  The testimony of the ages confirms that the mo...    []       []       1
# 3  It is just this from which astronomy arose amo...    []       []       1
# 4  Before the distinction between the first motio...    []  [(such]       1
#
#         graphic table                                           marginal  \
# 0            []    []                                                 []
# 1            []    []                                                 []
# 2            []    []  [ Terms: 1. The first motion is that of the wh...
# 3  [ ch 1 gr 1]    []                                                 []
# 4            []    []                                               [ 2]
#
#                                            sentences  \
# 0                                        [Chapter 1]
# 1  [On the distinction between the first motion a...
# 2  [The testimony of the ages confirms that the m...
# 3  [It is just this from which astronomy arose am...
# 4  [Before the distinction between the first moti...
#
#                                               tagged
# 0                      [[(Chapter, None), (1, NUM)]]
# 1  [[(On, None), (the, None), (distinction, None)...
# 2  [[(The, None), (testimony, None), (of, None), ...
# 3  [[(It, None), (is, None), (just, None), (this,...
# 4  [[(Before, None), (the, None), (distinction, N...

# %%
len(dfAstroNova)
# Out:
# 1605

# %% [markdown]
# ### Read the Sentences

# %%
df=dfAstroNova.sentences

# %%
sents=[]
for para in dfAstroNova.sentences:
    sents +=para

# %%
len(sents)
# Out:
# 6699

# %% [markdown]
# ## Annotation Based on Consistant format with Prodigy

# %% [markdown]
# <fig size= 3>
# Prodigy accept a specific format; a JSONL format (newline-delimited JSON). Entities and other highlighted spans of text can be defined in the "spans" property. A example could look like this dictionary:
# </p>
# text': 'On 1595 October 30 at 8h 20m, they found Mars at 17° 48’ Taurus, with a diurnal motion of 22’ 54” ^15.',
#   'spans': [{'start': 22, 'end': 29, 'label': 'TIME'}]}
# </p>
# which start and end's numbers refer to the position of entitiy  in the sentence. (here PARA)
#
#
# <fig size>

# %%
    label = "COOR"   
texts = sents  

regex_patterns = [
                  re.compile(r"\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+"   #LONG in format 
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\s?[A-Z][a-z.]+"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+")           
]
 
#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)              

#write_jsonl("NER_LONG_05_01.jsonl", examples)

# %%
def print_sents_entities(examples):
    for example in examples:
        if example["spans"]!=[]:
            sent,entity=example['text'], example['text'][example["spans"][0]["start"]:example["spans"][0]["end"]]
            print(sent,[entity])

# %%
print_sents_entities(examples)
# Out:
# Therefore, as 100,000 is to 70,711, so is 7560 to 5346, the sine of the arc of 3° 4' 52", which is CEB. ['3° 4\' 52"']
# Subtracting this from 45° leaves CBE, 41° 55' 8", whose half is 20° 57' 34", the tangent to which arc is 38,304. ['41° 55\' 8"']
# The product, that is, 29,732, is the tangent of the arc 16° 33' 30", which, subtracted from the half of CBE, found above, leaves 4° 24' 4", which is the angle BEA. ['16° 33\' 30"']
# Therefore, the whole, CEA, is 7° 28' 56", in the Ptolemaic form. ['7° 28\' 56"']
# Therefore, as οξ is to ξα, so is the whole sine4 to the tangent of αοξ or οαβ, 76,852, giving an angle of 37° 32' 37", which differs from the arc 45° by 7° 27' 23". ['37° 32\' 37"']
# Therefore, since ECB is right, and EB is 100,000, BC will be the sine of the angle CEB, or 4° 20' 8". ['4° 20\' 8"']
# Therefore, EBC is 85° 39' 52", and EC is 99,713. ['85° 39\' 52"']
# Hence, the equation, CEA, is 11° 25' 48". ['11° 25\' 48"']
# Therefore, ηαδ is 11° 23' 53". ['11° 23\' 53"']
# Now, from these three given quantities, γα, Mars’s new eccentricity, will also be given, and will be 27,971, while the angle δγα is 5° 27’ 47”. ['5° 27’ 47”']
# On the supposition that the old apogee of Mars δγ is positioned at 23° 32' 16" Leo, Mars’s new apogee αγ will fall at 29° 0’ 16” Leo. ['23° 32\' 16" Leo']
# Again, after a certain amount of time, whose measure shall be ιγζ or εγκ, whose vertical angle is δγα, just found to be 5° 27’ 47”, let a common moment be taken, represented by γκζ. ['5° 27’ 47”']
# This will be revealed by the triangle βγχ, in which βχ is parallel to θγ, the angle at χ is right, and γβχ is equal to θγβ (5° 27’ 47”) and βγ is 6763. ['5° 27’ 47”']
# These come out to be 78° 51’ 54” and 78° 47’ 30”. ['78° 51’ 54”']
# Now we said above12 that in δλρ, δλ is 741113 where λρ is 100,000, and ρλβ is 47° 59’ 16”. ['47° 59’ 16”']
# This gives ρδλ a value of 44° 59’ 10”, and δρ 105,123. ['44° 59’ 10”']
# Therefore, in εδμ, since εδλ is 44° 59’ 10”, and λδμ earlier came out to be 5° 27’ 47”, the whole εδμ is 50° 26’ 57”, and δμ above was 6763 where με is 100,000. ['44° 59’ 10”']
# Therefore, in εδμ, with three magnitudes  given the rest are given: εμκ is 53° 26’ 17”, and through this, δε is 104,170. ['53° 26’ 17”']
# In triangle δβι, the angle at ι is right, and βδι is 44° 59’ 10”, and βδ was found to be 19,763, above. ['44° 59’ 10”']
# Therefore, αβψ is 7° 30’ 10”. ['7° 30’ 10”']
# But above, αβ or ρδ were inclined to ρλ or βκ by 3° 0’ 6”, which latter lies at 5½˚ Cancer. ['3° 0’ 6”']
# Therefore, ρι or αβ will be at 8½° Cancer, and ψβ is consequently at 16° Cancer. ['16° Cancer.']
# Therefore (assuming these numbers), when the sun is passing through 16° Cancer while the planet is at 8½° Capricorn in its mean and uniform motion, and in the neighborhood of 27° Scorpio in its apparent motion, ερ appears maximum. ['16° Cancer']
# For since οψ was found to be 25,772, and ορ 476½, οψε will be 1° 3’ 32” But ρνε  (which is what we have been seeking) is equal to οψε, by Euclid III. ['1° 3’ 32” But']
# Now since ΖΩΟ is equal to ΚΣΨ, and ΚΣ is imperceptibly greater than ΨΣ  or ΩΟ (because ΚΨΣ is right, and the angle at Σ is not greater than 2° 3’, so that if ΨΣ is 100,000, ΚΣ is 100,064), ΟΖ is also imperceptibly less than ΚΨ. ['2° 3’']
# The occasion had placed this in his hands, in that they were busy with the observation of the acronychal position or opposition of Mars to the sun in 9° Leo. ['9° Leo.']
# The apogee at the beginning of the year 1585 was placed at 23° 45’ Leo. ['23° 45’ Leo.']
# However, the position of its apogee then fell short of the Prutenic calculation at the same time, by 5° 2’, both being compared with the first star of Aries in the Copernican manner. ['5° 2’']
# Hence, owing to our removal of the vernal equinox westward from that star, which was then 28° 2½’,4 it is concluded that Mars’s apogee was at 23° 25’ Leo. ['23° 25’ Leo.']
# For the first date it was set at 23° 20’ Leo, and for the last, at 23° 45’ Leo. ['23° 20’ Leo']
# This is clear from the following: since the nodes are about 17° Taurus and Scorpio, and the limits about 17° Leo and Aquarius, as will be said below, the additions and subtractions are made chiefly at 17° Cancer, 25° Virgo, 4° Scorpio, 27° Sagittarius, and 13° Pisces, intermediate points, and none at 21° Leo and 18° Scorpio, the nodes and the limit. ['17° Taurus']
# For, in their way of thinking, the difference ought to be greatest at 3° Cancer, because Cancer is closest to the 45th degree,5 where this difference is generally greatest. ['3° Cancer']
# But at 17° Cancer they subtracted 5 minutes, while at 3° Cancer, one minute only. ['17° Cancer']
# All positions are tolerably accurate except 27° Sagittarius. ['27° Sagittarius.']
# First, the sun’s position is 26° 45’ 24” Gemini. ['26° 45’ 24” Gemini.']
# Now the computed position on Mars’s orbit is 26° 24’ 43” Sagittarius. ['26° 24’ 43” Sagittarius.']
# Therefore, the computed position on the ecliptic would be 26° 24’ 13” Sagittarius, a difference from opposition to the sun of 21’ 11”. ['26° 24’ 13” Sagittarius']
# First, the table provides us the following information from the observations: the northern latitude takes its rise from 18° Taurus, at which it was five minutes, reaches its observed maximum at 21° Leo, decreased thereafter and became only 1⅔° at 3° Scorpio, but right away at 27° Sagittarius it was south  and a rather large 4°, and still ['18° Taurus']
# greater at 13° Pisces. ['13° Pisces.']
# From this one concludes roughly that the ascending node is a little before 18° Taurus, and the descending node far beyond 3° Scorpio. ['18° Taurus']
# The nodes will therefore be around 17° Taurus and 17° Scorpio, and the limits around 17° Leo and Aquarius. ['17° Taurus']
# For the angles come out as in the accompanying table,  from which it is clear that in the northern semicircle they suppose an angle of maximum northern latitude of 4° 33’, and in the southern, of 6° 26’ south. ['4° 33’']
# And since, from arguments which I shall present below, it is clear that for the star Mars the angle EAF is not greater than about 1° 50’, the adjustment about 45° from the node (where it is maximum) accordingly does not exceed one minute, for which the table nonetheless has one add 8 or 10 minutes in certain places. ['1° 50’']
# On 1580 November 12 at 10h 50m,1 they set Mars down at 8° 36’ 50” Gemini2 without mentioning the horizontal variations,  by which term I wish the diurnal parallaxes and the refractions to be understood in what follows. ['8° 36’ 50” Gemini']
# For in Maestlin,4 on the twelfth at noon, Mars is put at 8° 20’ Gemini, and on the seventeenth, again at noon, it is at 6° 25’ Gemini. ['8° 20’ Gemini']
# Therefore, the motion over five whole days would be 1° 55’. ['1° 55’']
# In Stadius,5 it is 1° 52’. ['1° 52’']
# Therefore, on the seventeenth at the same hour of 10h 50m, Mars ought to have been seen at either 6° 41’ 50” Gemini, or 6° 44’ 50”. ['6° 41’ 50” Gemini']
# At 9h 40m (which Tycho gives as the moment of opposition), it is 1’ 4” farther forward, at either 6° 42’ 54” or 6° 45’ 54”. ['6° 42’ 54”']
# They put it at 6° 46’ 10” Gemini. ['6° 46’ 10” Gemini.']
# On 1582 December 28 at 11h 30m, they set Mars down at 16° 47’ Cancer by observation ^6. ['16° 47’ Cancer']
# Tycho therefore puts it at 16° 46’ 16” Cancer ^7. ['16° 46’ 16” Cancer']
# On 1585 January 31 at 12h 0m, Mars was placed at 21° 18’ 11” Leo ^8. ['21° 18’ 11” Leo']
# Therefore, at the designated moment, it would have been at 21° 10’ 30” Leo, which is what was accepted. ['21° 10’ 30” Leo']
# On 1587 March 7 at 19h 10m they deduced the position of Mars from the observations, which was 25° 10’ 20” Virgo. ['25° 10’ 20” Virgo.']
# It therefore should have been 25° 8’ 32” Virgo, which also approaches nearer the point opposite the sun. ['25° 8’ 32” Virgo']
# On 1589 April 15 at 12h 5m they established the position of Mars very carefully at 3° 58' 21" Scorpio, and corrected for longitudinal parallax so as to make it 3° 57’ 11” ^10. ['3° 58\' 21" Scorpio']
# There remain 1h 30m until the designated moment of opposition, which, for a diurnal motion of 22', bring the planet back 1’ 22”, so as to be at 3° 55’ 49”. ['3° 55’ 49”']
# They took the value of 3° 58’ 10”. ['3° 58’ 10”']
# On 1591 June 6 at 12h 20m, Mars is placed at 27° 15’ Sagittarius ^11. ['27° 15’ Sagittarius']
# In four days it was found to be moved forward 1° 12’ 47”. ['1° 12’ 47”']
# Consequently, at that moment Mars was at 26° 35’ 31” Sagittarius. ['26° 35’ 31” Sagittarius.']
# The table has 26° 32’ Sagittarius. ['26° 32’ Sagittarius.']
# On 1593 24 August at 10h 30m they report Mars as being at 12° 38’ Pisces12 with an observed diurnal motion of 16’ 45”, and this near the nonagesimal13 where there is no longitudinal parallax. ['12° 38’ Pisces']
# Therefore, the planet falls at 12° 43’ 48” Pisces. ['12° 43’ 48” Pisces.']
# And the table has 12° 43’ 45”. ['12° 43’ 45”']
# On 1595 October 30 at 8h 20m, they found Mars at 17° 48’ Taurus, with a diurnal motion of 22’ 54” ^15. ['17° 48’ Taurus']
# The designated moment preceded by 11h 48m, for which is required a motion of Mars of 11’ 7” eastward, so that it would be at 17° 59’ 7” Taurus. ['17° 59’ 7” Taurus.']
# Therefore, possibly using another observation on the meridian, they put down 17° 56’ 15” Taurus in the table. ['17° 56’ 15” Taurus']
# On 1597 December 10 at 8h 30m, they first placed Mars at 3° 30’ Cancer, and again at 4° 1’ Cancer, the mean being 3° 45½’ Cancer ^16. ['3° 30’ Cancer']
# The moment of opposition came 3 days 5h 5m later, to which, from Magini, corresponds 1° 15’ westward. ['1° 15’']
# In the table, it was put at 2° 28’. ['2° 28’']
# Hence, Mars is at 10° 38’ 46” Leo, at an adjusted time of 11h 40m reduced to the meridian of Uraniborg. ['10° 38’ 46” Leo']
# But on January 24/February 3 at the same time it was at 6° 18’ Leo. ['6° 18’ Leo.']
# This gives a diurnal motion of 23’ 44”, and a position on January 19/29 at 9h 40m of 8° 18’ 45” Leo, just as they put it. ['8° 18’ 45” Leo']
# On the night of 26 December,3 it passed between the second and seventh stars of Gemini,4 its distance (measured with the staff) from the head of the lower of the Twins (the second star) being 2° 25’ or 2° 26’, but from the seventh, ['2° 25’']
# 1° 6’ or 1° 7’, making the latitude about 4° 9’. ['1° 6’']
# Then, at 8h 28m, it was 44° 41’ from ['44° 41’']
# the eye of Taurus,5 whose latitude is 5° 31’ south, longitude 4° 12½’ Gemini, in 1600. ['5° 31’']
# Hence, Mars’s longitude as if the year were 1600 is 17° 53⅓’ Cancer,6 or, at the end of 1582, 17° 38’ Cancer, at an altitude of 40° 50’. ['17° 38’ Cancer']
# Again, at 7h 15m on the morning of December 27, it was 36° 43’ from Cor Leonis,7 whose latitude is 0° 26½’; hence, its longitude at the end of 1582 is 17° 28⅓’ Cancer, altitude 14° 4’, and thus affected by refraction. ['36° 43’']
# On 1583 January 16 at 7h 30m in the evening,11 Mars was 23° 29’ from the bright star in the foot of Erichthonius at an altitude of 51°. ['23° 29’']
# The next morning at 5h 0m, it was 43° 58’ from Cor Leonis at an altitude of 15°. ['43° 58’']
# On January 16 at 10½h it was 23° 27’ from the bright star in the foot of Erichthonius. ['23° 27’']
# Now in order to comply with Brahe’s advice, we must set out the distance between the foot of Erichthonius and Cor Leonis, which is found to be 67° 21’. ['67° 21’']
# Subtracting Mars's distance from the bright star in the foot of Erichthonius, 23° 29’, leaves Mars's distance from Cor Leonis, 43° 52’, at 7½h in the evening, which at 5h in the morning was 43° 58’, 6 minutes greater. ['23° 29’']
# On January 17 at 5h 20m in the evening,13 Mars was 23° 16’ from the foot of Erichthonius. ['23° 16’']
# On the following day, the 18th, at 3h 0m in the morning, this distance was 23° 9’, and at 5h 5m in the evening it was 23° 1½’. ['23° 9’']
# Likewise, at 7h 34m its distance from the seventh star of Gemini14 was 7° 51’. ['7° 51’']
# At 4h 52m in the morning, it was 7° 59’ from the same star. ['7° 59’']
# On January 18 at 8h 52m in the evening15 there was 44° 22’ between Mars and Cor Leonis. ['44° 22’']
# On the night between Thursday and Friday, which was February 17/27, while Corvus was on the meridian, there was 9° 44’ between Mars and Spica, and between it and the Northern Pan,23 17° 41’; and between Mars and Arcturus, 29° 13’. ['9° 44’']
# Also, to test the sextant, we measured the interval between Arcturus and Spica as 32° 57’, which should have been 33° 1’ 45”, as is clear if you calculate it using the right ascensions and declinations, or latitudes and longitudes, which Tycho assigned to these stars in Book I of the Progymnasmata ^24. ['32° 57’']
# I applied this correction to the distances of Mars from the fixed stars, so as to make it 9° 48’ 45” from Spica, 17° 45’ 45” from the Pan, and 29° 17’ 45” from Arcturus ^25. ['9° 48’ 45”']
# I then used the quadrant to obtain the meridian altitude of Mars, 32° 4’, and of Spica, 30° 50’. ['32° 4’']
# Since the latter has a declination of 9° 2’, Mars is left with a declination of 7° 48”. ['9° 2’']
# For the altitude of the equator, at my location, is 39° 54’. ['39° 54’']
# Accordingly, the meridian altitude of Spica is 30° 52’, and of Mars, 32° 6’. ['30° 52’']
# But from this right ascension, I first select,  from Tycho’s table of right ascensions, the degree of the right sphere that was riding at the same time, 28° 1’ 0” Libra,27 whose declination, from another of that author’s tables,28 is 10° 48’ 30” [South]. ['28° 1’ 0” Libra']
# But that of Mars is 7° 48’ [South]. ['7° 48’']
# Therefore, Mars is distant from the ecliptic, the oblique path, by 3° 0’ 30” on the circle of declination. ['3° 0’ 30”']
# But the angle which the circle of declination makes with the ecliptic is 68° 59’ from the appropriate table. ['68° 59’']
# Its complement is 21° 1’. ['21° 1’']
# And in my table of parallax,29 under the heading of 60’, I find, opposite 68° 59’, the entry 56’ 1”. ['68° 59’']
# This gives me a latitude of 2° 48’ 31”. ['2° 48’ 31”']
# The same operation opposite 21° 1’ shows me what has to be subtracted from the place rising at the same time, namely, 1° 5’ 4”. ['21° 1’']
# Accordingly, Mars’s position will be 26° 56’ Libra. ['26° 56’ Libra.']
# To test the latitude of Mars, I also consulted the distance from Arcturus, through the star’s latitude and longitude provided from Tycho, and Mars’s longitudinal position just found, and it replied to me that Mars was at a latitude of 2° 47’ 48”. ['2° 47’ 48”']
# Before, it was at 2° 48’ 31”. ['2° 48’ 31”']
# Later, the back of Leo31 culminated at altitude 62° 37’, according to a corrected plumb line. ['62° 37’']
# Thus the altitude of the equator was shown to be 39° 55’: almost correct. ['39° 55’']
# Vindemiatrix32 showed a meridian altitude of 53° 5’, a little greater than it should have had. ['53° 5’']
# But Spica’s 30° 54’ was correct within one minute. ['30° 54’']
# The altitude of Mars at culmination was 32° 6’, the same as it had been two days before, and of Arcturus, a correct 61° 13’. ['32° 6’']
# On February 22 or March 3 we tested the sextant, just as we had done above, and found 26° 2’ between Canis Minor and Orion’s higher shoulder,33 which the calculation shows to be 26° 2’ 15”. ['26° 2’']
# So also, between Canis minor and Palilicium34 was found 46° 22½’, which Tycho, in his Epistolae, indicates is 46° 22’ ^35. ['46° 22’']
# Therefore, when the fifth star of Leo36 culminated, with the arm of the instrument fixed above 29° 13½’ the distance was now more, while no error could be found at 29° 15’. ['29° 15’']
# It became clear again on the morning of March 4, and now, when Antares culminated, with the arm fixed at 29° 19’, both stars were seen evenly [with the sights]. ['29° 19’']
# However, it seemed that something needed to be added, but at 29° 20’ too much had been added. ['29° 20’']
# On the night following February 29 or March 10, the instrument having meanwhile been displaced, this distance was, first, between 29° 9’ and 29° 10’, half an hour before the culmination of the Heart of Hydra ^37. ['29° 9’']
# Later, it appeared to the investigators to be between 29° 12’ and 29° 13’, as it was now higher and free from refraction. ['29° 12’']
# The Tail of Leo, when culminating, had the correct altitude of 56° 44’, within one minute. ['56° 44’']
# Then, between Mars and Spica, there was 9° 26’, and less than 9° 27’. ['9° 26’']
# There was then 18° 25’ between Mars and the Norther Pan [of Libra]. ['18° 25’']
# For the investigation of the sextant, the distance between Spica and the Pan was taken as 27° 39’, although it should have been 27° 34’ ^40. ['27° 39’']
# For unless you diminish Mars’s distance from the fixed stars by 5 minutes, the right ascension measured through Spica and through the Pan will be discrepant by 10 minutes, but if (as required by the examination of the sextant) the five minutes be subtracted, they will coincide exactly, and will be 205° 27’ 10”, with declination 7° 35½’. ['205° 27’ 10”']
# Therefore, the position is 26° 18’ 48” Libra, with latitude 2° 47’ 20”. ['26° 18’ 48” Libra']
# If, from the position of Mars found thus, you find its distance from Arcturus, it will come out to be 29° 9⅙’, while using the faulty instrument it was 29° 14’. ['29° 14’']
# We next tested the sextant again, which showed 44° 45’ between Polaris and the Tail of Cygnus ^43. ['44° 45’']
# But when Saturn had passed the meridian by one degree, the distance could not admit 29° 13½’; nevertheless, it was greater than 29° 12½’, about 29° 13’. ['29° 13’']
# In both, Mars was 29° 18’ from Arcturus, and in both, its meridian altitude was 32° 7’ or 6’. ['29° 18’']
# But on March 3, with the Mouth of Leo44 culminating, the distance was 29° 15’, and with the Heart of Scorpius45 culminating, 29° 19’ plus. ['29° 15’']
# I am not unaware that 29° 19’ is hardly different from 29° 18’, and that by analogy with the previous day the latter ought to be the distance at about the same time if Mars is standing still. ['29° 19’']
# The meridian distance ought to have been 29° 9½’ with an accurate instrument, and consequently 29° 14’ with the faulty one. ['29° 14’']
# When its altitude was 9 degrees (when Hydra was culminating), the distance was 29° 9’ with a faulty instrument, and still subject to refraction. ['29° 9’']
# Later, at an altitude of 25° and near the meridian, it was again 29° 9’, measured twice at different moments. ['29° 9’']
# 9, let A be the position of the node, E the planet’s position on the ecliptic in 1595, C the observed sidereal position of the planet, 17° 56’ 5” Taurus, EC the observed latitude, 0° 5’ 15” north. ['17° 56’ 5” Taurus']
# On 1590 March 4 at 7h 10m in the evening, Mars's declination was 9° 26’ ['9° 26’']
# N, and the right ascension was 22° 35’ 10” ^2. ['22° 35’ 10”']
# Hence, its position comes out as 24° 22’ 56” Aries, and its latitude as 3’ 12” south. ['24° 22’ 56” Aries']
# On 1592 January 23 at 10h 15m in the evening, Mars was at 11° 34’ 30” Aries with latitude 0° 2’ south ^3. ['11° 34’ 30” Aries']
# For after correction of the horizontal variations it retained no more than 0° 0’ 45” north latitude ^7. ['0° 0’ 45”']
# On 1595 October 27 at 12h 20m, Mars's true latitude after the removal of parallax was 0° 2’ 20” south ^8. ['0° 2’ 20”']
# On the 28th, when the parallax had similarly been removed, the latitude was 0° 0’ 25” north ^9. ['0° 0’ 25”']
# I. On the morning of 1595 January 4, when Mars was observed at 7h 10m at altitude 8°, with reference to Spica Virginis and Cor Scorpii,10 it was observed at latitude 0° 3’ 46” N, and it was itself at 13° 36’ 40” Sagittarius ^11. ['0° 3’ 46”']
# On the night of 1589 April 15 Mars's observed latitude was 1° 7’ north ^14. ['1° 7’']
# Whether you do this with the help of the Prutenic or Tychonic tables, taking into account the true precession of the equinox, you will find that on the morning of 1594 December 30, the mean position of Mars is 27° 14½’ Scorpio, and on the morning of 1595 October 28 it was at 5° 31’ Taurus. ['5° 31’ Taurus.']
# For from 5° 31’ Taurus to 27° 14½’ Scorpio is more than from the latter to the former. ['5° 31’ Taurus']
# If, on the other hand, you make use of the Tychonic equations, 11° 17’ must be added to the latter figure and 11° 30’ subtracted from the former. ['11° 17’']
# Accordingly, the one comes out to be 15° 44½’ Scorpio, and the other, 16° 48’ Taurus, which are Mars’s equated eccentric positions ^17. ['16° 48’ Taurus']
# Now it is apparent from what has just been said that it will be most directly helpful to us if we find an observation of the star Mars at that moment at which Mars is reported to be equidistant from the sun and the earth and on the line drawn from the sun to 16° or 17° Leo or Aquarius (the positions of the limits). ['17° Leo']
# In the Ptolemaic form, this is where the center of the epicycle is at 16° or 17° Leo or Aquarius and Mars is as far from the earth as is the center of the epicycle. ['17° Leo']
# At 16° or 17° Leo, this is about 5:3, and at 16° or 17° Aquarius, about 11:8. ['17° Leo']
# So the triangle ACB is isosceles with sides AC, CB equal, and (with AB=1000), BC is 1666⅔ when directed toward 17° Leo. ['17° Leo.']
# Looking this up in a table of secants, we find the angles CAD and CBD to be 72° 33’. ['72° 33’']
# So also, at 16° or 17° Aquarius, with AB=1000, AC is 1375, so if AD=1000, AC is 2750, showing 68° 40’ in the table of secants. ['17° Aquarius']
# Therefore, with BC directed towards 16° or 17° Leo or thereabouts, the apparent position of Mars, AC, ought to be 72½° from the apparent position of the sun AB. ['17° Leo']
# And with BC at 16° or 17° Aquarius, these ought to be 68⅔ from one another. ['17° Aquarius']
# And since the sum of the two (CAB, CBA) at 17° Leo is 145°, ACB will be 35° at 17° Leo. ['17° Leo']
# Wherefore, Mars, which lies on the line AC, ought to be seen at 22° Virgo (the sun being on AB at 5° Sagittarius), or at 12° Cancer (the sun being at 30° Aries). ['22° Virgo']
# Similarly, at 17° Aquarius, since the sum (CAB, CBA) is 137⅓, ACB will be 42⅔°, wherefore Mars, lying on the line AC, ought to be seen at 24⅓˚ Sagittarius3 (the sun being on AB at 16° Libra) or at 0° Aries (the sun being at 9° Gemini). ['17° Aquarius']
# Accordingly, on 1588 November 10 at 6h 30m in the morning the planet Mars was seen at 25° 31’ Virgo, with a latitude of 1° 36’ 45” north, the sun being at 21 Scorpio ^4. ['25° 31’ Virgo']
# On December 5 following, at 6h in the morning, Mars was seen at 9° 19⅖’ Libra, with a latitude of 1° 53½’ N., the sun being at 23° Sagittarius ^5. ['23° Sagittarius']
# And since these two effects cancel one another, the maximum inclination of the planes will be about 1° 50’. ['1° 50’']
# Similarly, on 1586 October 22 at 6h in the morning, about dawn, there was about 6° 9’ eastward between Mars and Cor Leonis ^6. ['6° 9’']
# The declination of Mars from the equator was 13° 0’ 40” north. ['13° 0’ 40”']
# Hence, its apparent longitude is found to be 0° 7’ Virgo,7 latitude 1° 36’ 6” N ^8. ['0° 7’ Virgo']
# The sun stood at 8° Scorpio, 68° from Mars. ['8° Scorpio']
# But on November 2 at 4⅔h in the morning, with the sun at 19⅖° Scorpio, Mars was seen at 5° 52’ Virgo, with latitude 1° 47’ N ^9. ['5° 52’ Virgo']
# But Mars was a few degrees before its northern limit which is at about 16° 17’. ['16° 17’']
# Therefore the latitude at this position appeared about right, although exactly at the limit it is reckoned to be greater than 1° 47’, namely, about 1° 50’. ['1° 47’']
# Hence is found its longitude, 20° 4’ 30” Virgo, and latitude, 2° 16’ 30”, with the sun at 18° Sagittarius, which is 88° from Mars. ['20° 4’ 30” Virgo']
# Indeed, it was much less, but not thereby much greater than 1° 47’. ['1° 47’']
# So here the magnitude of the maximum inclination is indirectly confirmed to be 1° 50’. ['1° 50’']
# On the other hand, on 1583 April 22, at 9¾h in the night, an interval of 20° 58’ was observed between Mars and the Dog12 and 22° 47½’ between Mars and Cor Leonis ^13. ['20° 58’']
# Hence, the position of Mars is found to be 1° 17’ Leo, with latitude 1° 50⅔’ north. ['1° 17’ Leo']
# The sun was at 11° Taurus, 80° distant from Mars. ['11° Taurus']
# Therefore, the opposite causes again cancel one another, and the maximum inclination is 1° 50’. ['1° 50’']
# Likewise, at 8h in the evening on 1596 March 9, it was observed at 15° 49’ Gemini, with latitude 1° 49⅔’ north ^14. ['15° 49’ Gemini']
# The sun was at 30° Pisces, 76 degrees from Mars. ['30° Pisces']
# So once again, indirect support is provided for a maximum digression of about 1° 50’ at the limit. ['1° 50’']
# Now, at the other limit, at 17° Aquarius, although observations are rarer,  there is one available. ['17° Aquarius']
# The sun was at 2° Libra, 74⅓° distant from Mars. ['2° Libra']
# On November 1 following, at 6⅙h, it was seen at 20° 59¼ Capricorn, with latitude 1° 36’ south, the sun being at 19° Scorpio ^16. ['1° 36’']
# Therefore, the maximum inclination is much greater than 1° 36’, and by all indications is about as great as the apparent latitude on September 15, namely, 1° 50’, approximately. ['1° 36’']
# You will therefore note that if ever there is a perfect quadrature of the sun and Mars, with the line BA, that is, the sun, at 16° or 17° Taurus or 16° or 17° Scorpio—where between the line BA from earth to sun (which in this instance is also the line of intersection of the planes), and the line BF from earth to Mars, there is 90° or one quadrant intervening—then, whatever the apparent latitude of Mars FBD will be there, that will also be the maximum inclination of the planes EAC, although at that place F, Mars is not as far from the ecliptic as at E. ['17° Taurus']
# However, on November 12 following, at 1½h in the night, when the sun had already fallen about 14° or 15° below the diameter of intersection, the earth having risen that much (for Copernicus), or the diameter of intersection having fallen that much toward the earth (for Tycho), Mars was seen at 23° 14’ Leo with latitude 2° 12⅖’ north, while the sun was at 1° Sagittarius ^17. ['23° 14’ Leo']
# Therefore, the inclination is much less than 2° 12’, namely, 1° 50’. ['2° 12’']
# On 1585 April 26 at 9h 42m, Mars was seen at 21° 26’ Leo with latitude 1° 49¾’ north ^18. ['21° 26’ Leo']
# The sun was at 16° Taurus, right near the node. ['16° Taurus']
# Mars’s line of vision was a little inclined, since Mars was beyond 16° Leo. ['16° Leo.']
# Therefore, the angle of maximum inclination of the planes was only a little greater than 1° 49¾’; that is, 1° 50’ or a little greater. ['1° 50’']
# Fourteen days later, when the sun was at the node, if it were again to have decreased 28 minutes (the amount of decrease in the previous 14 days), there would remain 1° 45’. ['1° 45’']
# Therefore nothing can be adduced here against a maximum inclination of 1° 50’. ['1° 50’']
# Let BA be a line drawn from the earth through the body of the sun at the place of the node, 17° Scorpio or Taurus, and let the planet be observed at any point whatever on the zodiac. ['17° Scorpio']
# For example, in the observation of 1585 April 26, the sun was at 16° Taurus, and Mars was observed at 21° 26’ Leo, with latitude 1° 49¾’. ['16° Taurus']
# Therefore, the inclination at the eccentric motion of 21° 26’ Leo is 1° 49¾’. ['21° 26’ Leo']
# And since 21° 26’ Leo is 5° from the limit, and the sine of 85° is 1/250 less than the whole sine,21 the maximum inclination here will be greater by 1/250 of it, that is, about 1° 50½‘. ['21° 26’ Leo']
# Let A be the earth, AB the line through the sun and the point opposite, at 17° Taurus or Scorpio, AD Mars’s line of vision, D Mars, and BAD a right angle. ['17° Taurus']
# AD will accordingly be at 17° Leo or Aquarius. ['17° Leo']
# Therefore, since AC will not be at 17° Leo or Aquarius, it will not be so far from the ecliptic as the northern limit E. D will likewise not stand so far from the ecliptic as E, because CD and all the points of the epicycle are equally distant from the ecliptic, since the plane of the epicycle, in order to make the hypothesis equivalent, is supposed always to remain parallel to the plane of the ecliptic. ['17° Leo']
# Also, they will be concurrent, since the sides (AD, AE) are drawn in the plane of the ecliptic through the same point A, and are directed toward the same point of longitude, 17° Leo or Aquarius. ['17° Leo']
# In Tycho’s table of oppositions, the apparent latitude at 21° 16’ Leo was 4° 32⅙’22 ['21° 16’ Leo']
# And since Mars is at 21° Leo, near the limit, the angle EAC is near its maximum. ['21° Leo']
# Therefore, as AC is to EBC, so is BA to BCA, 2° 43’ 27“ ^23. ['2° 43’ 27“']
# This, subtracted from EBC, leaves the required angle BAC, 1° 48’ 43“; hence, right at the limit, it would be about 1° 49’ and is somewhat altered if the ratio BA to AC is altered (more on this below). ['1° 48’ 43“']
# For example, on 1593 August 24, the apparent latitude at opposition to the sun comes out to be 6° 3’ south ^24. ['6° 3’']
# As CA is to the sine of CBE, BA is to the sine of BCA, 4° 21’ 10“. ['4° 21’ 10“']
# Subtracting from CBE, this leaves the required angle BAC, 1° 41’ 50“. ['1° 41’ 50“']
# So, as the sine of 64° is to this digression from the ecliptic of 1° 42’, so is the whole sine to the maximum inclination of the planes, which comes out to be 1° 53’. ['1° 42’']
# But when the sun was at all three places, Mars exhibited one and the same maximum inclination (1° 50’, about), northwards, at the same place on its eccentric, and the same amount southwards at the opposite position. ['1° 50’']
# Suppose, however, that on 1580 November 12 at 10h 50m Mars was observed at 8° 37’ Gemini,3 and the motion over five days was 1° 55’. ['8° 37’ Gemini']
# Since at the given time the sun stood at 0° 45’ 36“ Sagittarius, and its motion over five days is 5° 5’, the sum of the two motions will come to 7° 0’. ['0° 45’ 36“ Sagittarius']
# But the sun is 7° 51’ 24“ removed from opposition to Mars. ['7° 51’ 24“']
# Its position was 6° 28’ Gemini on the ecliptic. ['6° 28’ Gemini']
# I want to know how much longer this makes the arc on the orbit extended from the node to the arc of  latitude through 6° 28’ Gemini. ['6° 28’ Gemini.']
# From Lansberge, then, the tangent of the 20° side multiplied by the secant of the angle of inclination, 1° 50’, the last five digits being dropped,5 gives an increase of only 18½ of the smallest units, to which corresponds about 35 seconds. ['1° 50’']
# Mars therefore, standing opposite 6° 28’ Gemini, is 35“ further along on its orbit. ['6° 28’ Gemini']
# It should therefore be placed at 6° 28’ 35“ Gemini, a tiny and quite unnecessary correction. ['6° 28’ 35“ Gemini']
# The latitude is 1° 40’ north. ['1° 40’']
# On the night following 1582 December 28, at 11h 30m, Mars was observed at 16° 47’ Cancer,6 while the true position of the sun was 17° 13’ 45“ Capricorn. ['16° 47’ Cancer']
# Therefore, as 1° 25’ 18“ is to 24 hours, so is 26’ 45“ to 7 hours 32 minutes. ['1° 25’ 18“']
# Its position on the ecliptic was 16° 54’ 32“ Cancer, and by reduction to the orbit (a 50“ correction), 16° 55½’ Cancer. ['16° 54’ 32“ Cancer']
# The latitude was 4° 6’ north, as given by Brahe’s table of oppositions. ['4° 6’']
# For among the observations I find various latitudes: on the night following December 26, 4° 6’ or 4° 2’, while on the night following December 29, 4° 8’ or 4° 6½’. ['4° 6’']
# On 1585 January 31 at 12h 0m, Mars was observed at 21° 18’ 11“ Leo ^7. ['21° 18’ 11“ Leo']
# The sun was at 22° 21’ 31“Aquarius. ['22° 21’ 31“Aquarius.']
# The distance was 1° 3’ 20“. ['1° 3’ 20“']
# Now as 1° 25’ 31“ is to 24 hours, so is 1° 3’ 20“ to 17 hours 46 minutes, to which correspond about 18’ of Mars’s motion. ['1° 25’ 31“']
# Therefore the time was January 30 at 19h 14m, and Mars’s ecliptic position was 21° 36’ 10“ Leo. ['21° 36’ 10“ Leo.']
# The latitude, on the authority of the Tychonic table, was 4° 32’ 10“ north. ['4° 32’ 10“']
# For the observation on January 31 at 12h gave 4° 31’. ['4° 31’']
# On the night following 1587 March 4, at 1h 16m past midnight, the position of Mars was found to be 26° 26’ 17“ Virgo,8 from Cor Leonis9 and Spica Virginis, with an observed latitude of 3° 38’ 16“ north. ['26° 26’ 17“ Virgo']
# But because Mars was elevated 37½° above the horizon, diurnal parallax comes into the reckoning, and subtracts some small quantity from the longitude, thus making it 26° 26’ Virgo, with a slightly greater latitude. ['26° 26’ Virgo']
# Now when 9° Sagittarius is rising, the nonagesimal10 is 55° from the zenith. ['9° Sagittarius']
# Therefore, the latitude observed from the center of the earth would be 3° 42’ 22“ north. ['3° 42’ 22“']
# The sun’s true position was 23° 59’ 11“ Pisces. ['23° 59’ 11“ Pisces.']
# The stars were 2° 26’ 49“ apart. ['2° 26’ 49“']
# The sun’s diurnal motion was 59’ 35“, that of Mars 24’, and their sum 1° 23’ 35“. ['1° 23’ 35“']
# As this is to 24 hours, so is 2° 26’ 49“ to 1 day 18 hours 7 minutes, to which corresponds 42’ 7“ of Mars’s motion. ['2° 26’ 49“']
# Mars’s position on the ecliptic was 25° 43’ 53“ Virgo. ['25° 43’ 53“ Virgo.']
# Therefore, on the orbit it was at 25° 43’ Virgo. ['25° 43’ Virgo.']
# It was therefore somewhat less than 3° 38’ N., or 3° 42’ corrected for parallax. ['3° 38’ N.']
# On the night following 1589 April 15 at 12h 5m, the planet was found at 3° 58’ 20“ Scorpio,13 with latitude 1° 4’ 20“ north, decreasing. ['3° 58’ 20“ Scorpio']
# The degree rising was 24° Sagittarius. ['24° Sagittarius.']
# For there, the northern latitude, free from diurnal parallax (and if there is no refraction), would come out to be 1° 9’ 45“ north. ['1° 9’ 45“']
# But Mars is 40° from the nonagesimal, counting from 4° Scorpio to 24° Virgo, which, under the column  headed 2’ 38“ shows a true longitudinal parallax of 1’ 42“. ['4° Scorpio']
# Still, let there be no refraction at all, and let Mars be placed at 3° 57’ Scorpio. ['3° 57’ Scorpio.']
# At that moment the sun was at 5° 36’ 20“ Taurus. ['5° 36’ 20“ Taurus.']
# At this time, therefore, Mars was 1° 39’ 20“ past opposition to the sun. ['1° 39’ 20“']
# Mars’s diurnal motion, as is clear from comparison with April 13, is 22’ 8“; the sun’s, 58’ 10“; the sum, 1° 20’ 18“. ['1° 20’ 18“']
# As this is to 24 hours, so is 1° 39’ 20“ to 1 day 5 hours 42 minutes. ['1° 39’ 20“']
# Its position was 4° 24’ 30“ Scorpio, or a little past, if refraction were applied or if the previously assumed value for the diurnal parallax was too great. ['4° 24’ 30“ Scorpio']
# This would be about 24 seconds, which are of no importance, and Mars would be at 4° 24’ Scorpio, with latitude three minutes greater than before. ['4° 24’ Scorpio']
# On the night following 1591 June 6 at 12h 20m, Mars was found at 27° 14’ 42“ Sagittarius,16 with latitude 3° 55½’ south. ['27° 14’ 42“ Sagittarius']
# The sun was at 24° 58’ 10“ Gemini. ['24° 58’ 10“ Gemini.']
# The difference in position between the stars was 2° 16’ 10“. ['2° 16’ 10“']
# The sun’s diurnal motion was 57’ 8“, and Mars’s (for four days) was 1° 12’ 24“, since on June 10 at 11h 50m it was at 26° 2’ 18“ Sagittarius. ['1° 12’ 24“']
# The sum of the diurnal motions is 1° 15’ 20“. ['1° 15’ 20“']
# Mars’s position was 26° 41’ 48“ Sagittarius, to which are added 52“ for reduction to the orbit, so as to make it about 26° 43’ Sagittarius. ['26° 41’ 48“ Sagittarius']
# On 1593 August 24 at 10h 30m, the ecliptic position of Mars was found  to be 12° 38’ Pisces,18 with latitude 6° 5’ 30“ south. ['12° 38’ Pisces']
# On the August 29th following, at 10h 20m, Mars was observed at 11° 15’ 24“ Pisces, with latitude 5° 52’ 15“ south. ['11° 15’ 24“ Pisces']
# The motion for the five days was 1° 22’ 36“, and for one day, 16’ 31“. ['1° 22’ 36“']
# The sun’s position on August 24 at 10½h was 11° 2’ 31“ Virgo. ['11° 2’ 31“ Virgo.']
# The stars were 1° 35’ 30“ apart. ['1° 35’ 30“']
# The sum of the diurnal motions was 1° 14’ 51“. ['1° 14’ 51“']
# Mars’s position was 12° 16’ Pisces. ['12° 16’ Pisces.']
# Its latitude was 6° 2’ south, approximately, if the horizontal variations do indeed cancel. ['6° 2’']
# On 1595 October 30 at 8h 20m, the planet was found at 17° 47’ 15“ Taurus,19 not far from the nonagesimal. ['17° 47’ 15“ Taurus']
# The latitude was 0° 5’ 10“ north. ['0° 5’ 10“']
# The sun’s position was 16° 50’ 30“ Scorpio. ['16° 50’ 30“ Scorpio.']
# The sun’s diurnal motion was 1° 0’ 35“; that of Mars, 22’ 54“, as appears by comparing the nearby observations. ['1° 0’ 35“']
# The sum of the diurnal motions was 1° 23’ 29“. ['1° 23’ 29“']
# Mars’s position was 17° 31’ 40“ Taurus. ['17° 31’ 40“ Taurus.']
# The latitude was about 0° 8’ north. ['0° 8’']
# The sun’s position was 29° 4’ 53“ Sagittarius. ['29° 4’ 53“ Sagittarius.']
# The distance between the stars was 4° 40’ 37“. ['4° 40’ 37“']
# The sun’s diurnal motion was 61’ 20“, that of Mars 23’ 40“ (for in 1580 the diurnal motion in Gemini was 23’, and in 1582, at 17° Cancer, it was 24’). ['17° Cancer']
# Therefore, the sum of the diurnal motions was 1° 25’ 0“. ['1° 25’ 0“']
# Therefore, the corrected position was 2° 28’ Cancer. ['2° 28’ Cancer.']
# The latitude, from the table, was 3° 33’ north. ['3° 33’']
# On the same night, the one following December 10, at 12⅙h, Fabricius in East Frisia found Mars’s position to be 3° 40¼’ Cancer with latitude 3° 23’ N. In this observation the longitude comes out nearly the same. ['3° 23’ N.']
# For the motion over 3h 40m is 3½’, so that in the Brahean observation too, at 12⅙h Mars could have been at 3° 42’ Cancer—two minutes beyond the Fabrician position. ['3° 42’ Cancer']
# X. On 1600 January 13/23 at 11h 40m, the time being adjusted to Uraniborg time, the planet was observed at 10° 38’ 46“ Leo ^21. ['10° 38’ 46“ Leo']
# The sun’s position was 3° 26’ 30“ Aquarius. ['3° 26’ 30“ Aquarius.']
# The stars were 7° 12’ 16“ apart. ['7° 12’ 16“']
# The sun’s diurnal motion for the next few days was 1° 1’ 3“; that of Mars, 23’ 44“. ['1° 1’ 3“']
# The sum: 1° 24’ 47“. ['1° 24’ 47“']
# Mars was at 8° 38’ Leo. ['8° 38’ Leo.']
# The latitude, from the table, was 4° 30’ 50“ N.
# XI. ['4° 30’ 50“ N.']
# 18/28 at 10h 30m, using the Tychonic  instruments (with the help of the learned Matthias Seiffard,22 bequeathed us by Tycho), I took the distance of Mars from the middle star of the tail of Ursa Major 23 to be 52° 22’. ['52° 22’']
# And since the distance between Cor Leonis and Procyon was 37° 22’ 20“, which should have been 37° 19’ 50“,24 we know that the sextant reads 2½ minutes high. ['37° 22’ 20“']
# And since the latitude of the fixed star is 56° 22’, the remainder, by subtraction, is 4° 2½’—supposing that Mars was at precisely the same longitude as the fixed star. ['56° 22’']
# For let AB be 3° 43’ 30“ on a parallel close to the ecliptic, B Mars, C the fixed star, and BC 52° 19’ 30“. ['3° 43’ 30“']
# Dividing the secant of BC by the secant of AB gives the  secant of CA, 52° 14’, which, subtracted from 56° 22’ (the latitude of the fixed star) leaves 4° 8’ north as Mars’s observed latitude. ['52° 14’']
# At the same time, we found 19° 23’ between Mars and Cor Leonis (19° 20½ corrected), and 21° 20’ between Mars and the bright star in the wing of Virgo25 (21° 17½’ corrected). ['19° 23’']
# From these two distances (using the latitudes of the stars and Mars), Mars’s longitude is found to be 13° 19’ 6“ Virgo, by consensus of all measurements. ['13° 19’ 6“ Virgo']
# Alternatively, the meridian altitude of Mars was found at 12h 40m, using two quadrants, to be 50° 19’, while the tail of Leo26 was 56° 45’. ['50° 19’']
# Therefore, from the declinations and right ascensions of the fixed stars and our distances, Mars’s position is determined as 13° 19’ 30“ Virgo, latitude 4° 7’ 55“ ^27. ['13° 19’ 30“ Virgo']
# At Prague, 5° Scorpio was rising ^28. ['5° Scorpio']
# But since Mars was 38° from the nonagesimal, the longitudinal parallax corresponding to this position is 2’ 36“, and if this be eliminated, Mars would be placed at about 13° 18’ Virgo ^29. ['13° 18’ Virgo']
# At that moment, the sun’s position was 10° 16’ 42“ Pisces. ['10° 16’ 42“ Pisces.']
# The distance between the bodies was 3° 1’ 18“. ['3° 1’ 18“']
# The sun’s diurnal motion was 1° 0’ 4“, and that of Mars, 24’ 5“ (for it was 24’ 18“ at 21° Leo in 1585, and 24’ at 26 Virgo in 1587). ['1° 0’ 4“']
# The sum of the diurnal motions was 1° 24’ 9“. ['1° 24’ 9“']
# The true opposition therefore followed 2 days 3 hours 43 minutes later, on 21 February/3 March before dawn at 2h 13m, Mars being at 12° 27’ 35“ Virgo. ['12° 27’ 35“ Virgo.']
# Forty seconds must be subtracted to reduce the position to the orbit, putting Mars at 12° 27’ Virgo, with slightly less latitude than before, since the latitude was then decreasing. ['12° 27’ Virgo']
# It was therefore about 4° 10’, or 4° 7⅓’ if the parallax be neglected. ['4° 10’']
# First, the star in the wing of Virgo, adjusted to our time, is at 4° 36’ 30“ Libra with latitude 2° 50’ north. ['4° 36’ 30“ Libra']
# Fabricius found that Mars is 20° 18’ westward from it on the zodiac, which puts Mars at about 14° 18’ 30“ Virgo. ['20° 18’']
# Now the tail of Leo31 is at 16° 4’ Virgo, with latitude 12° 18’ North, and Mars was found to be 8° 17’ distant from the Tail. ['16° 4’ Virgo']
# What is sought is the distance of its parallel from the Tail, since the difference in longitude is 1° 45’. ['1° 45’']
# Dividing the secant of 8° 17’ by the secant of 1° 45’ gives the secant of 8° 6’, the arc sought. ['8° 17’']
# This subtracted from the fixed star’s northern latitude of 12° 18’ leaves Mars’s latitude, 4° 12’ north. ['12° 18’']
# From the Wing of Virgo, I find Mars’s longitude to be 14° 19’ Virgo; from the Neck of Leo, 14° 23’ 36“. ['14° 19’ Virgo']
# The mean of these two is 14° 21’ 18“ Virgo. ['14° 21’ 18“ Virgo.']
# And since the sextant gave distances larger than the truth, the latitude would come out at 4° 14’ north. ['4° 14’']
# It was found to be 9° 24’ from the Tail of Leo, and hence, its latitude comes out at 4° 6’ ^32. ['9° 24’']
# And now, through this and the latitudes of the fixed stars, together with their distances (17° 26’ from Regulus, 17° 51’ from the Neck of Leo, 37° 28’ from Spica, 44° 15’ from Arcturus), Mars’s position comes out at 11° 21’ 23“ Virgo (from Regulus), 11° 20’ 52“ Virgo (from the Neck of Leo), and 11° 17’ 40“ (from Spica). ['17° 26’']
# The mean (ignoring Arcturus), 11° 19’ 20“ Virgo, is very nearly true. ['11° 19’ 20“ Virgo']
# Also, the latitude is greater, namely, 4° 7’ 40“ north. ['4° 7’ 40“']
# Now from February 15 at 17h to 23 February at 12h, a period of 7 days 19 hours, Mars moved 3° 0’: 180 minutes in 187 hours. ['3° 0’']
# Because the last observation follows the time of observation found by me by 2 days 21 hours 47 min., add the motion corresponding to this time, 1° 7’: the position will come out 12° 26’ Virgo. ['1° 7’']
# As for the latitude, on the 16th it was 4° 12’, and on the 23rd it was 4° 7⅔’. ['4° 12’']
# It is therefore fitting to set it at 4° 9’ on the 21st, which comes between the other two dates. ['4° 9’']
# And I, too, was putting it at a little less than 4° 10⅔’, or 4° 10’. ['4° 10’']
# At that time, with the help of Johann Schuler and using Hofmann’s sextant, I found 33° 4’ between Arcturus and Spica, which ought to have been 33° 1½’. ['33° 4’']
# Immediately after, between Arcturus and Mars there was 29° 43½’; therefore, correctly, 29° 41’. ['29° 41’']
# This should, however, have been 54° 2’. ['54° 2’']
# But let us suppose that, as before, the excess was 2½’, making the distance between Mars and Cor Leonis 54° 6’. ['54° 6’']
# Hence, Mars’s latitude comes out to 2° 21½’, longitude 18° 25’ Libra. ['18° 25’ Libra.']
# The hour is known since, at the time of observation, the Back of Leo was culminating, whose right ascension is 163° 13’. ['163° 13’']
# Now the sun’s position at noon is 18° 56’ 24“ Aries, whose right ascension is 17° 27’ 55“. ['18° 56’ 24“ Aries']
# Hence the difference in ascensions is 145° 45’, which resolves into 9 hours 43 min. ['145° 45’']
# Therefore the latitude without parallax was 2° 25’ (whether this correction was rightly made, we shall consider below). ['2° 25’']
# At our chosen moment, the sun’s position is 19° 20’ 8“ Aries. ['19° 20’ 8“ Aries.']
# (For in 1587 in Virgo it is 24’, and in 1589 at 4° Scorpio it is 22’ 8“). ['4° Scorpio']
# The sum of the diurnal motions is 1° 21’ 14“. ['1° 21’ 14“']
# Mars’s position was 18° 37’ 50“ Libra. ['18° 37’ 50“ Libra.']
# For reduction to the orbit, subtract about 39 sec., making Mars’s position 18° 37’ 10“ Libra. ['18° 37’ 10“ Libra.']
# The latitude was slightly greater than 2° 25’, but, when parallax is ignored, it is 2° 22’ north. ['2° 25’']
# As, although from 2⅔° Cancer through Leo to 26¾° Sagittarius is less than a semicircle, and from 26° Sagittarius through Aquarius to Cancer is more than a semicircle, nonetheless the planet is found to spend longer on the former than on the latter, although a law of uniformity2 would require the contrary. ['26° Sagittarius']
# For from a mean longitude of 2s 23° 18’ to 9s 5° 44’ is 6s 12° 26’, more than a  semicircle, that is, more than half of the planet’s periodic time ^3. ['23° 18’']
# So from 12° 16’ Pisces through Leo to 12° 27’ Virgo is about a semicircle and 11 minutes. ['12° 16’ Pisces']
# But if the mean longitude of the former position (11s 9° 55’) be subtracted from the longitude of the latter (5s 14° 59’), the difference is seen to be 6s 5° 5’, which is 5° 5’ more than half. ['9° 55’']
# Now let each point be connected with each of the others, and let AF be at 25° 43’ Virgo, AG at 26° 43’ Sagittarius, AD at 12° 16’ Pisces, and AE at 17° 31⅔’ Taurus. ['25° 43’ Virgo']
# Hence, the four angles about A are given: FAG is 91° 0’, GAD is 75° 33’, DAE is 65° 15⅔’, and EAF is 128° 11⅓’. ['91° 0’']
# Here, the apparent longitude was 25° 43’ Virgo, the mean longitude 6s 0° 47’ 40“, and the annual motion of the fixed stars is 51 seconds, as Brahe has demonstrated in the Progymnasmata. ['25° 43’ Virgo']
# Therefore, we must set the apparent position in 1591 at 26° 39’ 23“ Sagittarius, and the mean longitude at 9s 5° 40’ 18“. ['26° 39’ 23“ Sagittarius']
# And so Mars is to be placed at 12° 10’ 30“ Pisces, with mean longitude 11s 9° 49’ 34“. ['12° 10’ 30“ Pisces']
# And so Mars is to be placed at 17° 24’ 22“ Taurus, with mean longitude 1s 7° 6’ 51“. ['17° 24’ 22“ Taurus']
# Now first, we shall assume that the apogee or aphelion in 1587 is at 28° 44’ 0“ Leo, and second, we shall assume that the mean longitudes should be increased by 3’ 16“,17 so that the mean longitudes are 6s 0° 50’ 56“, 9s 5° 43’ 34“, 11s 9° 52’ 50“, and 1s 7° 10’ 7“. ['28° 44’ 0“ Leo']
# Before, when we had erred in defect by 29’ 15“, the sum of the differences at F and D was 12° 1’ 44“. ['12° 1’ 44“']
# Now, when we have erred in excess by 1’ 48“, this sum comes out to be 12° 19’ 46“. ['12° 19’ 46“']
# And so, since 31’ will produce 18’ in the sum of the differences, therefore, 1⅘’ produces about 1’, so that the exact sum is 12° 18’ 44“, whose half, 6° 9’ 22“, is the sum at either F or D.
# For the Triangles GFE, GBE. ['12° 18’ 44“']
# HCF is 32° 2' 6"; GCI 53° 8' 32"; DCI 11° 0' 44"; and ECI 68° 18' 1". ['32° 2\' 6"']
# So, since it was at 28° 49' 8" Leo, it will now be at 28° 48' 30" Leo. ['28° 49\' 8" Leo']
# And from the sum of 70° 22' 29" established above, subtract the difference of 6° 2’ 20" just found. ['70° 22\' 29"']
# Therefore, the total addition to Tycho's longitude is 3' 55",23 and the aphelion is placed at 28° 48’ 55" Leo. ['28° 48’ 55" Leo.']
# BC will be the sine of the angle BGC, 4° 8' 51". ['4° 8\' 51"']
# And GBC will be 85° 51' 9". ['85° 51\' 9"']
# And in the tangents, this shows 10° 32' 38" as the common angle of the equation at 90° of anomaly. ['10° 32\' 38"']
# Therefore, since two sides and the included angle are given, the angle CBA is given as 123° 27'. ["123° 27'"]
# And because BA is directed towards 5½° Sagittarius, the direction of BC (by subtraction of the angle 123° 27’) will be about 2° 3' Leo, for Ptolemy's time. ['123° 27’']
# At that time, Cor Leonis was at 2° 30' Leo. ["2° 30' Leo."]
# In our times, in 1587, Tycho Brahe found this star at 24° 5' Leo. ["24° 5' Leo."]
# Since the aphelion progressed to 28° 49' Leo, it was 4° 44' east of Cor Leonis. ["28° 49' Leo"]
# If you add the above mentioned 27' to this, the sum (5° 11') is the motion over the 1447 years between 140 and 1587. ["5° 11'"]
# And today it is at about 16° 20' Leo, about 7° 45' before Cor Leonis. ["16° 20' Leo"]
# ...
# On 1589 April 5 at 11h 33m Mars was observed at 7° 31' 10" Scorpio with latitude 1° 28' 13" N ^15. ['7° 31\' 10" Scorpio']
# The mean longitude is concluded to be 7s 9° 46' 8". ['9° 46\' 8"']
# aphelion is at 4s 28° 51' 8". ['28° 51\' 8"']
# Therefore, the mean anomaly is 70° 55' 0", to which corresponds an equated anomaly of 61° 17' 35", by the vicarious hypothesis. ['70° 55\' 0"']
# And so the eccentric position is 0° 8' 43" Scorpio; the sun's position, 25° 52' 43" Aries; its distance from earth 100,560; the angle at the earth 11° 38' 27"; at the planet 7° 22' 27". ['0° 8\' 43" Scorpio']
# 19, when, at 5½h am Mars was observed to be 28° 11' from the southern pan of Libra17 (which in that year was at 9° 23½' Scorpio), with a latitude of 0° 26' North ^18. ["28° 11'"]
# But since that eccentric position has a declination from the equator of 21° 39' 10", [while] the observed declination of Mars was 20° 50' 30", its latitude was therefore 48' 40". ['21° 39\' 10"']
# But the mean longitude is 7s 8° 21' 47", to which corresponds an equated 59° 57' 38", and an eccentric position of 28° 51' Libra. ['8° 21\' 47"']
# Therefore, the angle at the planet is 38° 43' 20"; the sun's position 10° 14' 25" Pisces; therefore, the angle at the earth, 87° 20' 0"; and the distance of the sun from the earth, 99,210. ['38° 43\' 20"']
# Thus the distance of Mars from the sun comes out here to be 158,428, longer than before, because here we are also nearer to aphelion by 1° 26' 30" ^20. ['1° 26\' 30"']
# Whence it is proved that these two eccentric positions, treated by the method given above, will show exactly the same eccentric position as our vicarious hypothesis, except that on account of our nearness to 17° Scorpio we run the risk of being in error by one or two minutes. ['17° Scorpio']
# Moreover, in the latter of these, the distance from Aquila comes out to 54° 12', which is not within 12' of agreeing with the other observed data, and consequently this observation is not perfectly certain. ["54° 12'"]
# A suitable observation at a similar longitude on the other semicircle occurred on 1582 November 12 at 6¾h am, when the sun's position was 29° 35' 17" Scorpio ^21. ['29° 35\' 17" Scorpio']
# Its distance was 98,503, mean longitude of Mars 2s 15° 10' 20", aphelion 4s 28° 44' 20". ['15° 10\' 20"']
# Hence, the full-circle complement of the mean  anomaly was 73° 34', and of the equated anomaly, 63° 45' 18". ["73° 34'"]
# Hence, the eccentric position was 24° 59' 2" Gemini. ['24° 59\' 2" Gemini.']
# Then, I say, the planet was observed at 26° 35' 30" Cancer, making the angle of vision, the one at the earth, 57° 0' 13", and at the planet, 31° 36' 28". ['26° 35\' 30" Cancer']
# And because the anomaly was previously 70° 55', and is now 73° 34', we are therefore lower by 2° 39'. ["70° 55'"]
# On 1596 March 9 at 7h 40m pm, when the sun's position was 29° 31' 24" ['29° 31\' 24"']
# Pisces, the distance from earth 99,764, Mars's mean longitude 3s 15° 35' 0", aphelion 4s 28° 58' 31", the full-circle complement of the mean anomaly 43° 23' 31", equated anomaly 36° 40' 2", eccentric position from the vicarious hypothesis 22° 18' 29" Cancer—the planet was observed at 15° 49' 12" Gemini, latitude 1° 47' 40" N ^22. ['15° 35\' 0"']
# Therefore, the angle at the earth was 76° 17' 48", at the planet 36° 29' 17". ['76° 17\' 48"']
# 25 at 10h 20m, when the sun was at 14° 0' 3" Sagittarius, distance from earth 98,318. ['14° 0\' 3" Sagittarius']
# Therefore, the eccentric position is the same, 22° 8' 44" Cancer, if you subtract the precession of 9' 45". ['22° 8\' 44" Cancer']
# 12 at 13h 26m at 23° 14' 15" Leo,23 with latitude 2° 12' 24" N. On the 20th of Nov. ['23° 14\' 15" Leo']
# following, at 18h 30m astronomically,24 it appeared at 26° 0' 30" Leo ^25. ['26° 0\' 30" Leo']
# Thus in 8 days 5 hours it was moved forward 2° 46' 25". ['2° 46\' 25"']
# In Magini, this is 2° 48'. ["2° 48'"]
# Therefore, since our time follows by 4 days 15h 49m, to which corresponds 1° 28' of motion from Magini,26 we shall add 1° 27' according to the above ratio. ["1° 28'"]
# So Mars could have been observed at 27° 27' 30" Leo, approximately. ['27° 27\' 30" Leo']
# Therefore, the angle at the earth was 73° 27' 27", at the planet 35° 18' 46". ['73° 27\' 27"']
# 1227 at 5h 13m am, the mean longitude was 6s 12° 38' 44",28 aphelion 4s 28° 50' 57"; and consequently, the mean anomaly was 43° 47' 48", lower than our previous one by 24 minutes. ['12° 38\' 44"']
# So the distance which was less than 163,13729 at an anomaly of  43° 48' will again be increased at anomaly 43° 24' according to this ratio, so as to make it almost exactly 163,100 in this semicircle. ["43° 48'"]
# Second, in Chapter 18 above, the acronychal observation of 1589, at 5° Scorpio, gave the same testimony, namely, that our vicarious hypothesis needs to be diminished by 2⅕’. ['5° Scorpio']
# And in 1591, at 26° Sagittarius, there still was one minute to be subtracted. ['26° Sagittarius']
# Third, in this very chapter, about 16° Scorpio, the observations of 1589 and 1594 required 3½ minutes to be subtracted from the eccentric position computed from our vicarious hypothesis. ['16° Scorpio']
# And likewise, near aphelion, we shall again take up the observations of  Chapter 28, where at a mean anomaly of 11° 37' a distance of 166,180 or 166,208 was found (without correction for latitude). ["11° 37'"]
# On 1585 January 24 at 9h, when the position of the sun was 15° 9' 5" Aquarius, its distance from earth 98,590, the mean longitude of Mars 4s 16° 50' 10", the aphelion 4s 28° 46' 41", the remainder of the mean anomaly to complete the full circle 11° 56' 31", and the consequent eccentric position from the vicarious hypothesis 18° 49' 0" Leo: the planet was observed at 24° 9' 30" Leo, latitude 4° 31' 0" N ^30. ['15° 9\' 5" Aquarius']
# The angle at earth was therefore 9° 0' 25", and at the planet 5° 20' 30". ['9° 0\' 25"']
# 18 in the computation of the acronychal opposition, the angle at the planet will be 5° 19', and the distance of Mars from the sun 166,580. ["5° 19'"]
# On 1586 December 16 at 6½h am, when the sun was at 4° 16' 51" Capricorn, 98,200 distant from earth, mean longitude of Mars 4s 18' 39' 9", remainder of mean anomaly 10° 9' 41", eccentric position from the vicarious hypothesis 20° 20' 30" Leo: the declination of Mars was found to be 3° 54', right ascension from Arcturus and Spica 177° 27' ^31. ['4° 16\' 51" Capricorn']
# Thus its longitude was 26° 6' 24" Virgo, latitude 2° 35'. ['26° 6\' 24" Virgo']
# Hence, the angle at earth was 81° 49' 33", at the planet 35° 45' 54". ['81° 49\' 33"']
# And at the previous distance from aphelion, 11° 37', it would be about 70 units less. ["11° 37'"]
# 6 at 6h 50m am, when the sun's position was 24° 3' 43" Scorpio, 98,630 distant from earth, mean longitude of Mars 4s 20° 47' 35", remainder of the anomaly 8° 2' 51", eccentric position from the vicarious hypothesis 22° 7' 48" Leo: Mars was observed at 23° 16' Virgo, lat. ['24° 3\' 43" Scorpio']
# 1° 37',32 {marginal: ["1° 37'"]
# 254} Hence, the angle at earth was 60° 47' 43", at the planet 31° 8' 12". ['60° 47\' 43"']
# And by this analogy, at the greater distance from aphelion of 11° 37', where it is less by about 110, it is either 166,401 or 166,286. ["11° 37'"]
# In 1591 on the night following May 13, at 1 hour 40m past midnight, when the sun was at 2° 8' 43" Gemini, distant from earth 101,487, while the mean longitude of Mars was 8s 22° 18' 4", anomaly 113° 24' 4", equated 103° 15' 48", consequent eccentric position from the vicarious hypothesis 12° 9' 48” Sagittarius (or, by analogy with 26 Sagittarius nearby, just now mentioned, 12° 8¾’ ['2° 8\' 43" Gemini']
# Sagittarius): Mars was observed at 2° 24½' Capricorn, latitude 2° 15' S ^33. ["2° 15'"]
# Therefore, the angle at the earth was 30° 15' 44", and at the planet either 20° 14' 39" or 20° 15' 42". ['30° 15\' 44"']
# But since 12° 10' Sagittarius is about 26½’ from the node, the secant of the inclination at this place exceeds the radius by about 11 units, or 15 or 16 in our dimensions, so as to make the distance of Mars from the sun almost exactly 147,820 or 147,700. ["12° 10' Sagittarius"]
# And at one of the times noted therein, namely, 1590 March 4 at 7⅕h, the [mean] longitude of Mars was 1s 4° 11' 20". ['4° 11\' 20"']
# Hence, the full-circle complement of the mean anomaly was 114° 41'. ["114° 41'"]
# Therefore, the distance of 113° 24' on the ascending semicircle  would be 147,743 or 148,000 or 148,050 (extrapolating from the observations of Ch. ["113° 24'"]
# 3 at 5h 39m, when the sun's position was 21° 44' 56"  Sagittarius, and its distance from earth was 98,248, and the mean longitude of Mars was 11s 16° 27' 53", full-circle complement of the anomaly 162° 24' 11", and the equated eccentric position 20° 4' 32" Pisces: Mars was observed at 15° 25' 33" Aquarius, lat. ['21° 44\' 56"']
# 1° 11' 47" S ^34. ['1° 11\' 47"']
# 16 at 6h 28m, when the sun was at 2° 39' 15" Scorpio, 99,142 distant from earth, Mars's mean longitude 11s 13° 53' 57", full-circle complement of the anomaly 165° 0' 9", eccentric position from the vicarious hypothesis 16° 59' 14" Pisces: Mars was observed at 1° 27' 18" Aquarius, lat. ['2° 39\' 15" Scorpio']
# 2° 10' 52" S. ['2° 10\' 52" S.']
# 8 at 10h 38m, when the sun was at 25° 41' 0" Virgo, 100,266 distant from earth, Mars's mean longitude 11s 17° 10' 17", full-circle complement of the anomaly 161° 45' 28", and eccentric position from the vicarious hypothesis 20° 53' 54" Pisces: the planet was found at 8° 53' 51" Pisces with latitude 5° 14' 30" south ^36. ['25° 41\' 0" Virgo']
# Finally, on 1595 July 22 at 2h 40m am, when the sun was at 7° 59' 52" Leo, 101,487 distant from earth, Mars's mean longitude 11s 14° 9' 5", and anomaly 164° 48' 55", and consequent eccentric position from the vicarious hypothesis 17° 16' 36" Pisces: the apparent position of Mars, from the most select observations, was 4° 11' 10" Taurus, lat. ['7° 59\' 52" Leo']
# 2° 30' S ^37. ["2° 30'"]
# So now, given the angles GKA, 45° 35' 13", and EKA, 46° 51' 16", the other angles G, E, and the lines EA, GA remaining the same, AK comes out to be 138,765, and 138,787, differing from our assumed value by 258 units. ['45° 35\' 13"']
# So if we also subtract that much from the other two AKs, so as to make them 138,954 and 139,000, the resulting angles are DKA 34° 43' 47" and AK 20° 9' 40" [Pisces]; while FKA is 12° 1' 24" and AK 20° 55' 15" [Pisces]. ['34° 43\' 47"']
# But since I previously added 6' 46" at G and subtracted the same amount at E, I have therefore repositioned the eccentric positions at 17° 2' 31" Pisces at G, and 17° 19' 54" Pisces at E, increasing the position given by the vicarious hypothesis by 3' 17". ['17° 2\' 31" Pisces']
# For on the night following June 29 in 1593, at 1h 30m after midnight, when the sun was at 17° 25' 42" Cancer, 101,760 distant from earth, the longitude of Mars 10s 10° 1' 29", anomaly 161° 5' 29", and the consequent position of Mars 6° 10' 5" Aquarius, it was observed at 13° 37' 22" Pisces, with latitude 4° 37' S ^38. ['17° 25\' 42" Cancer']
# Hence, the supplement of the angle at earth was 56° 11' 46", at the planet, or the parallax of the annual orb, 37° 27' 23". ['56° 11\' 46"']
# But above, at an anomaly of 161° 45' 28", where Mars was 40 minutes farther from aphelion than here, the distance was found and established as 139,000. ['161° 45\' 28"']
# equal intervals from 29° Leo in either semicircle be at equal distances from the sun, and at unequal distances from the point that stands for the sun, which for Brahe is the center of the sun's epicycle. ['29° Leo']
# When this is proved, it will follow in addition that the parts around 24° Leo are neither the most distant from the sun's body, nor from the Copernican center of the world, which for Brahe is the center of the sun's epicycle, and also the center to which the planetary circle is attached; and the parts at an equal arc's removal from 24° Leo in either semicircle are at unequal distances from the sun and from the point that stands for it. ['24° Leo']
# This, taken as a sine, shows the angle ναθ to be 22° 15’, and greater, if instead of ξθ you take οθ. ['22° 15’']
# And αθ will be at 16° 5' Cancer, and αη at 17° 55' Cancer ^11. ["16° 5' Cancer"]
# So by an operation conducted as before, the more nearly correct values resulting are: αθ 158,792, and αη 164,364, placing αθ at 0° 41' 0" Cancer, and αη at 0° 8' 30" Leo. ['0° 41\' 0" Cancer']
# Therefore, αθ falls at 18° 48' 47" Leo, and αη at 23° 34' 48" Leo. ['18° 48\' 47" Leo']
# The mean motion at the same time is 10s 7° 14’ 34" ^16. ['7° 14’ 34"']
# And in Chapter 28, at a mean anomaly of 11° 37', which, after the correction of Chapter 53 preceding, becomes 11° 52',2 the distance of the point on the ecliptic to which a perpendicular dropped from the body of Mars descends, was found to be 166,180, or 166,208. ["11° 37'"]
# And therefore, since this position is 23° from the northern limit, the inclination will be about 1° 43', and excess of the secant will be 45 units, which will be about 70 in our dimensions. ["1° 43'"]
# In 1586, with 10° 9' 41" of mean anomaly remaining, or 9° 54' 41" after correction, we found 166,311. ['10° 9\' 41"']
# Thus in 1588, when the remaining [mean] anomaly was 8° 2' 51", or 7° 47' 51" corrected, by a subtraction of 1½’ from the position given by the vicarious hypothesis we found the distance to be 166,396. ['8° 2\' 51"']
# Thus, a position 4° 4' lower will be shorter by about 102, making it 166,294. ["4° 4'"]
# Let it thus be [taken as] certain that at a mean anomaly of 11° 52' the distance is 166,260. ["11° 52'"]
# While anxiously turning this thought over in my mind, reflecting that absolutely nothing was articulated by Chapter 45, and consequently my triumph over Mars was futile, quite by chance I hit upon the secant of the angle 5° 18', which is the measure of the greatest optical equation. ["5° 18'"]
# Let us conclude that the body of the planet, like a magnet, approaches and recedes according to the law of the lever along an imaginary diameter of the epicycle tending towards the sun, and that the body's diameter of power, its true diameter DA, tends towards the middle elongations, so that for this time BD tends toward 29° Taurus BA towards 29° Scorpio. ['29° Taurus']
# This, with HV, gives the angle VHF, 44° 52' 34", which differs from 45° 0' 0" by only 7’ 26". ['44° 52\' 34"']
# And because as HN is to this root, so is the whole to LH, LH will therefore be 84,084, which is the sine of KE, 57° 14', the complement of the eccentric anomaly AK, 32° 46'. ["57° 14'"]
# On 1593 December 10, at 7h 0m in the evening, Mars was observed at 4° 44' Aries, with latitude 0° 1' 15" south, parallax not accounted for ^1. ["4° 44' Aries"]
# After the 687 days of one complete revolution of Mars, on 1595 October 28 at 11h 30m pm Mars was found at an altitude of 51° in 18° 35' Taurus, with latitude 4½’ south, parallax not accounted for ^2. ["18° 35' Taurus"]
# For since on 1589 May 6 Mars had 6⅔‘ of northern latitude,7 it traversed this in 2⅓ days, according to the proportion of the latitudinal motion of the preceding days, [arriving at the node on] May 8 at 20h at which time its eccentric position is found to be 16° 42' Scorpio. ["16° 42' Scorpio."]
# In 1595, this would be 16° 47' Scorpio, the position of the ascending node, while previously we found the ascending node to be at 16° 45⅖’ Taurus. ["16° 47' Scorpio"]
# On 1593 August 25 at 17h 27m, Mars was observed at opposition to the sun at 12° 16' Pisces ^1. ["12° 16' Pisces"]
# On the 23rd its latitude was 6° 7' 30". ['6° 7\' 30"']
# On the 24th it was 6° 5' 30". ['6° 5\' 30"']
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def print_entities(examples):
    entities = []
    for example in examples:
        if example["spans"] != []:
            entities += [example['text'][example["spans"][0]["start"]:example["spans"][0]["end"]]]
            len(entities)
    print("There is {} entities with this detail\n{}".format(len(entities),entities))

# %%
print_entities(examples)
# Out:
# There is 903 entities with this detail
# ['3° 4\' 52"', '41° 55\' 8"', '16° 33\' 30"', '7° 28\' 56"', '37° 32\' 37"', '4° 20\' 8"', '85° 39\' 52"', '11° 25\' 48"', '11° 23\' 53"', '5° 27’ 47”', '23° 32\' 16" Leo', '5° 27’ 47”', '5° 27’ 47”', '78° 51’ 54”', '47° 59’ 16”', '44° 59’ 10”', '44° 59’ 10”', '53° 26’ 17”', '44° 59’ 10”', '7° 30’ 10”', '3° 0’ 6”', '16° Cancer.', '16° Cancer', '1° 3’ 32” But', '2° 3’', '9° Leo.', '23° 45’ Leo.', '5° 2’', '23° 25’ Leo.', '23° 20’ Leo', '17° Taurus', '3° Cancer', '17° Cancer', '27° Sagittarius.', '26° 45’ 24” Gemini.', '26° 24’ 43” Sagittarius.', '26° 24’ 13” Sagittarius', '18° Taurus', '13° Pisces.', '18° Taurus', '17° Taurus', '4° 33’', '1° 50’', '8° 36’ 50” Gemini', '8° 20’ Gemini', '1° 55’', '1° 52’', '6° 41’ 50” Gemini', '6° 42’ 54”', '6° 46’ 10” Gemini.', '16° 47’ Cancer', '16° 46’ 16” Cancer', '21° 18’ 11” Leo', '21° 10’ 30” Leo', '25° 10’ 20” Virgo.', '25° 8’ 32” Virgo', '3° 58\' 21" Scorpio', '3° 55’ 49”', '3° 58’ 10”', '27° 15’ Sagittarius', '1° 12’ 47”', '26° 35’ 31” Sagittarius.', '26° 32’ Sagittarius.', '12° 38’ Pisces', '12° 43’ 48” Pisces.', '12° 43’ 45”', '17° 48’ Taurus', '17° 59’ 7” Taurus.', '17° 56’ 15” Taurus', '3° 30’ Cancer', '1° 15’', '2° 28’', '10° 38’ 46” Leo', '6° 18’ Leo.', '8° 18’ 45” Leo', '2° 25’', '1° 6’', '44° 41’', '5° 31’', '17° 38’ Cancer', '36° 43’', '23° 29’', '43° 58’', '23° 27’', '67° 21’', '23° 29’', '23° 16’', '23° 9’', '7° 51’', '7° 59’', '44° 22’', '9° 44’', '32° 57’', '9° 48’ 45”', '32° 4’', '9° 2’', '39° 54’', '30° 52’', '28° 1’ 0” Libra', '7° 48’', '3° 0’ 30”', '68° 59’', '21° 1’', '68° 59’', '2° 48’ 31”', '21° 1’', '26° 56’ Libra.', '2° 47’ 48”', '2° 48’ 31”', '62° 37’', '39° 55’', '53° 5’', '30° 54’', '32° 6’', '26° 2’', '46° 22’', '29° 15’', '29° 19’', '29° 20’', '29° 9’', '29° 12’', '56° 44’', '9° 26’', '18° 25’', '27° 39’', '205° 27’ 10”', '26° 18’ 48” Libra', '29° 14’', '44° 45’', '29° 13’', '29° 18’', '29° 15’', '29° 19’', '29° 14’', '29° 9’', '29° 9’', '17° 56’ 5” Taurus', '9° 26’', '22° 35’ 10”', '24° 22’ 56” Aries', '11° 34’ 30” Aries', '0° 0’ 45”', '0° 2’ 20”', '0° 0’ 25”', '0° 3’ 46”', '1° 7’', '5° 31’ Taurus.', '5° 31’ Taurus', '11° 17’', '16° 48’ Taurus', '17° Leo', '17° Leo', '17° Leo', '17° Leo.', '72° 33’', '17° Aquarius', '17° Leo', '17° Aquarius', '17° Leo', '22° Virgo', '17° Aquarius', '25° 31’ Virgo', '23° Sagittarius', '1° 50’', '6° 9’', '13° 0’ 40”', '0° 7’ Virgo', '8° Scorpio', '5° 52’ Virgo', '16° 17’', '1° 47’', '20° 4’ 30” Virgo', '1° 47’', '1° 50’', '20° 58’', '1° 17’ Leo', '11° Taurus', '1° 50’', '15° 49’ Gemini', '30° Pisces', '1° 50’', '17° Aquarius', '2° Libra', '1° 36’', '1° 36’', '17° Taurus', '23° 14’ Leo', '2° 12’', '21° 26’ Leo', '16° Taurus', '16° Leo.', '1° 50’', '1° 45’', '1° 50’', '17° Scorpio', '16° Taurus', '21° 26’ Leo', '21° 26’ Leo', '17° Taurus', '17° Leo', '17° Leo', '17° Leo', '21° 16’ Leo', '21° Leo', '2° 43’ 27“', '1° 48’ 43“', '6° 3’', '4° 21’ 10“', '1° 41’ 50“', '1° 42’', '1° 50’', '8° 37’ Gemini', '0° 45’ 36“ Sagittarius', '7° 51’ 24“', '6° 28’ Gemini', '6° 28’ Gemini.', '1° 50’', '6° 28’ Gemini', '6° 28’ 35“ Gemini', '1° 40’', '16° 47’ Cancer', '1° 25’ 18“', '16° 54’ 32“ Cancer', '4° 6’', '4° 6’', '21° 18’ 11“ Leo', '22° 21’ 31“Aquarius.', '1° 3’ 20“', '1° 25’ 31“', '21° 36’ 10“ Leo.', '4° 32’ 10“', '4° 31’', '26° 26’ 17“ Virgo', '26° 26’ Virgo', '9° Sagittarius', '3° 42’ 22“', '23° 59’ 11“ Pisces.', '2° 26’ 49“', '1° 23’ 35“', '2° 26’ 49“', '25° 43’ 53“ Virgo.', '25° 43’ Virgo.', '3° 38’ N.', '3° 58’ 20“ Scorpio', '24° Sagittarius.', '1° 9’ 45“', '4° Scorpio', '3° 57’ Scorpio.', '5° 36’ 20“ Taurus.', '1° 39’ 20“', '1° 20’ 18“', '1° 39’ 20“', '4° 24’ 30“ Scorpio', '4° 24’ Scorpio', '27° 14’ 42“ Sagittarius', '24° 58’ 10“ Gemini.', '2° 16’ 10“', '1° 12’ 24“', '1° 15’ 20“', '26° 41’ 48“ Sagittarius', '12° 38’ Pisces', '11° 15’ 24“ Pisces', '1° 22’ 36“', '11° 2’ 31“ Virgo.', '1° 35’ 30“', '1° 14’ 51“', '12° 16’ Pisces.', '6° 2’', '17° 47’ 15“ Taurus', '0° 5’ 10“', '16° 50’ 30“ Scorpio.', '1° 0’ 35“', '1° 23’ 29“', '17° 31’ 40“ Taur ...

# %% [markdown]
# ## See Misaligned Tokens

# %% [markdown]
# <fig size= 3>
# This step is very important, since if Pordigy faces with Misaligned tokens, we can see that before and try to adjust regex accordingly
# <fig size>

# %%
def misaligned_token(examples):
    counter=0
    nlp = spacy.load("en_core_web_sm")  
    for example in examples:  
        doc = nlp(example["text"])
        for span in example["spans"]:
            char_span = doc.char_span(span["start"], span["end"])
            if char_span is None:  
                counter+=1
                print("{}- Misaligned tokens-->".format(counter), example["text"], span)

# %%
misaligned_token(examples)
# Out:
# 1- Misaligned tokens--> On 1580 November 12 at 10h 50m,1 they set Mars down at 8° 36’ 50” Gemini2 without mentioning the horizontal variations,  by which term I wish the diurnal parallaxes and the refractions to be understood in what follows. {'start': 55, 'end': 72, 'label': 'LONG'}
# 2- Misaligned tokens--> On 1593 24 August at 10h 30m they report Mars as being at 12° 38’ Pisces12 with an observed diurnal motion of 16’ 45”, and this near the nonagesimal13 where there is no longitudinal parallax. {'start': 58, 'end': 72, 'label': 'LONG'}
# 3- Misaligned tokens--> But from this right ascension, I first select,  from Tycho’s table of right ascensions, the degree of the right sphere that was riding at the same time, 28° 1’ 0” Libra,27 whose declination, from another of that author’s tables,28 is 10° 48’ 30” [South]. {'start': 153, 'end': 168, 'label': 'LONG'}
# 4- Misaligned tokens--> Hence, its apparent longitude is found to be 0° 7’ Virgo,7 latitude 1° 36’ 6” N ^8. {'start': 45, 'end': 56, 'label': 'LONG'}
# 5- Misaligned tokens--> Suppose, however, that on 1580 November 12 at 10h 50m Mars was observed at 8° 37’ Gemini,3 and the motion over five days was 1° 55’. {'start': 75, 'end': 88, 'label': 'LONG'}
# 6- Misaligned tokens--> On the night following 1582 December 28, at 11h 30m, Mars was observed at 16° 47’ Cancer,6 while the true position of the sun was 17° 13’ 45“ Capricorn. {'start': 74, 'end': 88, 'label': 'LONG'}
# 7- Misaligned tokens--> On the night following 1587 March 4, at 1h 16m past midnight, the position of Mars was found to be 26° 26’ 17“ Virgo,8 from Cor Leonis9 and Spica Virginis, with an observed latitude of 3° 38’ 16“ north. {'start': 99, 'end': 116, 'label': 'LONG'}
# 8- Misaligned tokens--> On the night following 1589 April 15 at 12h 5m, the planet was found at 3° 58’ 20“ Scorpio,13 with latitude 1° 4’ 20“ north, decreasing. {'start': 72, 'end': 90, 'label': 'LONG'}
# 9- Misaligned tokens--> On the night following 1591 June 6 at 12h 20m, Mars was found at 27° 14’ 42“ Sagittarius,16 with latitude 3° 55½’ south. {'start': 65, 'end': 88, 'label': 'LONG'}
# 10- Misaligned tokens--> On 1593 August 24 at 10h 30m, the ecliptic position of Mars was found  to be 12° 38’ Pisces,18 with latitude 6° 5’ 30“ south. {'start': 77, 'end': 91, 'label': 'LONG'}
# 11- Misaligned tokens--> On 1595 October 30 at 8h 20m, the planet was found at 17° 47’ 15“ Taurus,19 not far from the nonagesimal. {'start': 54, 'end': 72, 'label': 'LONG'}
# 12- Misaligned tokens--> And since the distance between Cor Leonis and Procyon was 37° 22’ 20“, which should have been 37° 19’ 50“,24 we know that the sextant reads 2½ minutes high. {'start': 94, 'end': 105, 'label': 'LONG'}
# 13- Misaligned tokens--> Magini puts it at 1° 5' Virgo,7 14' or 15' too much. {'start': 18, 'end': 29, 'label': 'LONG'}
# 14- Misaligned tokens--> And δηζ will be 43° 26' 18", and δγζ 86° 52' 36", γδζ 46° 33' 42", and γδα 1° 7' 5"- a different angle from different beginnings. {'start': 75, 'end': 83, 'label': 'LONG'}
# 15- Misaligned tokens--> At 7¼h on the morning of that day, Mars's mean longitude is calculated to be 7s 26° 13' 39",2 a few minutes beyond the other. {'start': 80, 'end': 91, 'label': 'LONG'}
# 16- Misaligned tokens--> Therefore, 306° 57' on the equator was rising, and along with it 29° Sagittarius,4 at which the angle between the ecliptic and the horizon is 26°, its complement 64°. {'start': 65, 'end': 80, 'label': 'LONG'}
# 17- Misaligned tokens--> And for the first time the mean anomaly is 87° 9' 24", and 87° 16' 30"8 for the second. {'start': 59, 'end': 70, 'label': 'LONG'}
# 18- Misaligned tokens--> 12 at 13h 26m at 23° 14' 15" Leo,23 with latitude 2° 12' 24" N. On the 20th of Nov. {'start': 17, 'end': 32, 'label': 'LONG'}
# 19- Misaligned tokens--> 1227 at 5h 13m am, the mean longitude was 6s 12° 38' 44",28 aphelion 4s 28° 50' 57"; and consequently, the mean anomaly was 43° 47' 48", lower than our previous one by 24 minutes. {'start': 45, 'end': 56, 'label': 'LONG'}
# 20- Misaligned tokens--> 1° 37',32 {marginal: {'start': 0, 'end': 6, 'label': 'LONG'}
# 21- Misaligned tokens--> And in Chapter 28, at a mean anomaly of 11° 37', which, after the correction of Chapter 53 preceding, becomes 11° 52',2 the distance of the point on the ecliptic to which a perpendicular dropped from the body of Mars descends, was found to be 166,180, or 166,208. {'start': 110, 'end': 117, 'label': 'LONG'}
# 22- Misaligned tokens--> And since the node is at 16° 43' Taurus,2 I subtract from this 12° 16' Pisces. {'start': 25, 'end': 39, 'label': 'LONG'}
# 23- Misaligned tokens--> And this is the amount of the inclination of the point K as it would appear from A. And since Mars is at 20° 1½' Aquarius, and the node is at 16° 43' Taurus,7 and thus the elongation of Mars from the node is 86° 42', therefore, as the sine of this elongation is to the whole sine, so is the sine of 1° 49' 37" to the sine of the maximum inclination, 3200 ^8. {'start': 142, 'end': 156, 'label': 'LONG'}
# 24- Misaligned tokens--> And since the [full-circle] complement of Mars's equated anomaly was 7° 6' 23",11 its distance from the sun was 166,334, and the sun's distance from the earth, 98,724. {'start': 69, 'end': 78, 'label': 'LONG'}
# 25- Misaligned tokens--> Hence it is concluded that the maximum southern latitude will be about 6° 52' 20",4 and at conjunction it appears as 2° 4' 20" ^5. {'start': 71, 'end': 81, 'label': 'LONG'}
# 26- Misaligned tokens--> And since 2° 40’ 48" Pisces, the position on the orbit, is distant from 16° 43' Taurus10 by 74° 2', the inclination will therefore be 1° 46' 10". {'start': 72, 'end': 86, 'label': 'LONG'}
# 27- Misaligned tokens--> But when 36' are subtracted from Mars's aphelion, placing it at 0° 3' Leo26 for the last time, and when its mean motion is so adjusted that for the middle time the [mean] anomaly is 34° 58½’ with longitude from the equinoctial of 5s 5° 0' 50", the following observations result:27 {'start': 64, 'end': 73, 'label': 'LONG'}
# 28- Misaligned tokens--> Therefore, [the position of] its mean motion is 11° 4’ Sagittarius,37 which, in the first case, was 11° 18½’ Sagittarius. {'start': 48, 'end': 66, 'label': 'LONG'}
# 29- Misaligned tokens--> If the sun had been at 3° 5' Pisces,41 where Ptolemy placed it using his eccentricity, the moon could not have appeared 92° 8' from it, the measure that is just and computed from the hypothesis, for the reason that the setting sun reaches the eye by refraction, and appears higher than it actually is (and thus 30’ farther to the east). {'start': 23, 'end': 35, 'label': 'LONG'}
# 30- Misaligned tokens--> The apparent magnitude of this arc, using the Ptolemaic distance of the sun and earth, 102,100, will be 3° 45' 45",4 so the planet will fall at 1° 43' Sagittarius. {'start': 104, 'end': 114, 'label': 'LONG'}
# 31- Misaligned tokens--> Then the sun's elongation from Cor Leonis is 5s 27° 33' 20",8 differing from Mars's eccentric longitude of 1s 26° 35' 7" by 4s 0° 58' 13". {'start': 48, 'end': 59, 'label': 'LONG'}

# %% [markdown]
# # Edge Cases

# %% [markdown]
# As it is clear from above , After using regular expression we faced with some specific format like these words:
# - 12° 38’ Pisces12
# - 0° 7’ Virgo,7
# - 8° 37’ Gemini,3
# - 16° 47’ Cancer,6
# - 12° 38’ Pisces,18
# - 16° 43' Taurus,2
# - 29° Sagittarius,4
# - 11° 52',2
# - 1° 37',32
# - 11° 52',2
# - 16° 43' Taurus,2
# - 16° 43' Taurus10
# - 0° 3' Leo26
# - 11° 4’ Sagittarius,37
# - 3° 5' Pisces,41
# - 8° 36’ 50” Gemini2
# - 28° 1’ 0” Libra,27
# - 26° 26’ 17“ Virgo,8
# - 3° 58’ 20“ Scorpio,13
# - 27° 14’ 42“ Sagittarius,16
# - 17° 47’ 15“ Taurus,19
# - 37° 19’ 50“,24
# - 1° 7' 5"-
# - 26° 13' 39",2
# - 7° 6' 23",11
# - 6° 52' 20",4
# - 3° 45' 45",4
# - 7° 33' 20",8
#
# We consider these words as edge cases which means tokens are not consistant with the tokens assigned by the model’s tokenizer.

# %% [markdown]
# ## Solution

# %% [markdown]
# We can modify our annotation rules based on the above examples

# %%
label = "COOR"   
texts = sents  

regex_patterns = [
                  re.compile(r"\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"   #LONG in different format 
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\s?[A-Z][a-z.]+(,\d{1,2})"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“](,\d{1,2})"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’](,\d{1,2})"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+(,\d{1,2})")           
]
 
#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)

# %%
misaligned_token(examples)
# Out:
# 1- Misaligned tokens--> On 1580 November 12 at 10h 50m,1 they set Mars down at 8° 36’ 50” Gemini2 without mentioning the horizontal variations,  by which term I wish the diurnal parallaxes and the refractions to be understood in what follows. {'start': 55, 'end': 72, 'label': 'LONG'}

# %% [markdown]
# # Refined Edge Cases

# %% [markdown]
# - 8° 36’ 50” Gemini2

# %% [markdown]
# ### One Possible Solution

# %%
label = "COOR"   
texts = sents  

regex_patterns = [
                  re.compile(r"8° 36’ 50” Gemini2"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|]\s?\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“](,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+(,\d{1,2})?")           
]

#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)         
#write_jsonl("NER_LONG_V05.jsonl", examples)

# %%
print_entities(examples)
# Out:
# There is 1002 entities with this detail
# ['3° 4\' 52"', '41° 55\' 8"', '16° 33\' 30"', '7° 28\' 56"', '37° 32\' 37"', '1\' 33"', '4° 20\' 8"', '85° 39\' 52"', '11° 25\' 48"', '11° 23\' 53"', '1’ 55”', '5° 27’ 47”', '23° 32\' 16" Leo', '5° 27’ 47”', '5° 27’ 47”', '78° 51’ 54”', '4’ 24”', '4’ 24”', '47° 59’ 16”', '44° 59’ 10”', '44° 59’ 10”', '53° 26’ 17”', '44° 59’ 10”', '7° 30’ 10”', '3° 0’ 6”', '16° Cancer.', '16° Cancer', '1° 3’ 32” But', '2° 3’', '9° Leo.', '23° 45’', '5° 2’', '23° 25’', '23° 20’', '17° Taurus', '3° Cancer', '17° Cancer', '27° Sagittarius.', '26° 45’ 24” Gemini.', '26° 24’ 43” Sagittarius.', '10’ 20”', '26° 24’ 13” Sagittarius', '18° Taurus', '13° Pisces.', '18° Taurus', '17° Taurus', '4° 33’', '1° 50’', '8° 36’ 50” Gemini2', '8° 20’', '1° 55’', '1° 52’', '6° 41’ 50” Gemini', '1’ 4”', '6° 46’ 10” Gemini.', '16° 47’', '16° 46’ 16” Cancer', '21° 18’ 11” Leo', '24’ 15”', '7’ 41”', '21° 10’ 30” Leo', '25° 10’ 20” Virgo.', '1’ 48”', '25° 8’ 32” Virgo', '3° 58\' 21" Scorpio', '1’ 22”', '3° 58’ 10”', '27° 15’', '1° 12’ 47”', '39’ 29”', '26° 35’ 31” Sagittarius.', '26° 32’', '12° 38’', '5’ 48”', '12° 43’ 48” Pisces.', '12° 43’ 45”', '17° 48’', '11’ 7”', '17° 56’ 15” Taurus', '3° 30’', '1° 15’', '2° 28’', '10° 38’ 46” Leo', '6° 18’', '23’ 44”', '2° 25’', '1° 6’', '44° 41’', '5° 31’', '17° 38’', '36° 43’', '23° 29’', '43° 58’', '23° 27’', '67° 21’', '23° 29’', '23° 16’', '23° 9’', '7° 51’', '7° 59’', '44° 22’', '9° 44’', '32° 57’', '9° 48’ 45”', '32° 4’', '9° 2’', '39° 54’', '30° 52’', '28° 1’ 0” Libra,27', '7° 48’', '3° 0’ 30”', '68° 59’', '21° 1’', '68° 59’', '2° 48’ 31”', '21° 1’', '26° 56’', '2° 47’ 48”', '2° 48’ 31”', '62° 37’', '39° 55’', '53° 5’', '30° 54’', '32° 6’', '26° 2’', '46° 22’', '29° 15’', '29° 19’', '29° 20’', '29° 9’', '29° 12’', '56° 44’', '9° 26’', '18° 25’', '27° 39’', '205° 27’ 10”', '26° 18’ 48” Libra', '29° 14’', '44° 45’', '29° 13’', '29° 18’', '29° 15’', '29° 19’', '4’ 24”', '3’ 0”', '4’ 20”', '8’ 45”', '4’ 36”', '2’ 25”', '29° 14’', '29° 9’', '29° 9’', '17° 56’ 5” Taurus', '9° 26’', '22° 35’ 10”', '24° 22’ 56” Aries', '11° 34’ 30” Aries', '0° 0’ 45”', '0° 2’ 20”', '0° 0’ 25”', '0° 3’ 46”', '6’ 45”', '1° 7’', '5° 31’', '5° 31’', '11° 17’', '16° 48’', '17° Leo', '17° Leo', '17° Leo', '17° Leo.', '72° 33’', '17° Aquarius', '17° Leo', '17° Aquarius', '17° Leo', '22° Virgo', '17° Aquarius', '25° 31’', '23° Sagittarius', '1° 50’', '6° 9’', '13° 0’ 40”', '0° 7’', '8° Scorpio', '5° 52’', '16° 17’', '1° 47’', '20° 4’ 30” Virgo', '1° 47’', '1° 50’', '20° 58’', '1° 17’', '11° Taurus', '1° 50’', '15° 49’', '30° Pisces', '1° 50’', '17° Aquarius', '2° Libra', '1° 36’', '1° 36’', '17° Taurus', '23° 14’', '2° 12’', '21° 26’', '16° Taurus', '16° Leo.', '1° 50’', '1° 45’', '1° 50’', '17° Scorpio', '16° Taurus', '21° 26’', '21° 26’', '17° Taurus', '17° Leo', '17° Leo', '17° Leo', '21° 16’', '21° Leo', '2° 43’ 27“', '1° 48’ 43“', '6° 3’', '4° 21’ 10“', '1° 41’ 50“', '1° 42’', '1° 50’', '8° 37’', '0° 45’ 36“ Sagittarius', '7° 51’ 24“', '51’ 24“', '6° 28’', '6° 28’', '1° 50’', '6° 28’', '6° 28’ 35“ Gemini', '1° 40’', '16° 47’', '61’ 18“', '26’ 45“', '1° 25’ 18“', '16° 54’ 32“ Cancer', '4° 6’', '4° 6’', '21° 18’ 11“ Leo', '22° 21’ 31“Aquarius.', '1° 3’ 20“', '61’ 16“', '1° 25’ 31“', '21° 36’ 10“ Leo.', '4° 32’ 10“', '4° 31’', '26° 26’ 17“ Virgo,8', '26° 26’', '9° Sagittarius', '3° 42’ 22“', '23° 59’ 11“ Pisces.', '2° 26’ 49“', '59’ 35“', '2° 26’ 49“', '25° 43’ 53“ Virgo.', '25° 43’', '3° 38’', '3° 58’ 20“ Scorpio,13', '24° Sagittarius.', '5’ 24“', '1° 9’ 45“', '2’ 38“', '4° Scorpio', '3° 57’', '5° 36’ 20“ Taurus.', '1° 39’ 20“', '22’ 8“', '1° 39’ 20“', '4° 24’ 30“ Scorpio', '4° 24’', '27° 14’ 42“ Sagittarius,16', '24° 58’ 10“ Gemini.', '2° 16’ 10“', '57’ 8“', '18’ 12“', '1° 15’ 20“', '26° 41’ 48“ Sagittarius', '12° 38’', '11° 15’ 24“ Pisces', '1° 22’ 36“', '11° 2’ 31“ Virgo.', '1° 35’ 30“', '58’ 20“', '1° 14’ 51“', '12° 16’', '6° 2’', '17° 47’ 15“ Taurus,19', '0° 5’ 10“', '16° 50’ 30“ Scorpio.', '56’ 45“', '1° 0’ 35“', '1° 23’ 29“', '40’ 47“', '17° 31’ ...

# %%
misaligned_token(examples)
# Out:
# 1- Misaligned tokens--> And δηζ will be 43° 26' 18", and δγζ 86° 52' 36", γδζ 46° 33' 42", and γδα 1° 7' 5"- a different angle from different beginnings. {'start': 75, 'end': 83, 'label': 'LONG'}
# 2- Misaligned tokens--> And for the first time the mean anomaly is 87° 9' 24", and 87° 16' 30"8 for the second. {'start': 59, 'end': 70, 'label': 'LONG'}
# 3- Misaligned tokens--> And in Chapter 28, at a mean anomaly of 11° 37', which, after the correction of Chapter 53 preceding, becomes 11° 52',2 the distance of the point on the ecliptic to which a perpendicular dropped from the body of Mars descends, was found to be 166,180, or 166,208. {'start': 110, 'end': 117, 'label': 'LONG'}
# 4- Misaligned tokens--> And since 2° 40’ 48" Pisces, the position on the orbit, is distant from 16° 43' Taurus10 by 74° 2', the inclination will therefore be 1° 46' 10". {'start': 72, 'end': 86, 'label': 'LONG'}
# 5- Misaligned tokens--> But when 36' are subtracted from Mars's aphelion, placing it at 0° 3' Leo26 for the last time, and when its mean motion is so adjusted that for the middle time the [mean] anomaly is 34° 58½’ with longitude from the equinoctial of 5s 5° 0' 50", the following observations result:27 {'start': 64, 'end': 73, 'label': 'LONG'}

# %%
label = "LONG"   
texts = sents  


regex_patterns = [
                  re.compile(r"8° 36’ 50” Gemini2|87° 16\' 30\"8|16° 43\' Taurus10|0° 3\' Leo26|11° 52\',2"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|]\s?\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]-?(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+(,\d{1,2})?")           
]        


#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)         
#write_jsonl("NER_LONG_V06.jsonl", examples)

# %%
label = "LONG"   
texts = sents  


regex_patterns = [
                  re.compile(r"8° 36’ 50” Gemini2|87° 16\' 30\"8|16° 43\' Taurus10|0° 3\' Leo26|11° 52\',2"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“]\s?\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]-?(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+(,\d{1,2})?")           
]        


#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)         
#write_jsonl("NER_LONG_V07.jsonl", examples)

# %%
misaligned_token(examples)
# Out:
# 1- Misaligned tokens--> On 1593 24 August at 10h 30m they report Mars as being at 12° 38’ Pisces12 with an observed diurnal motion of 16’ 45”, and this near the nonagesimal13 where there is no longitudinal parallax. {'start': 58, 'end': 72, 'label': 'LONG'}

# %%
label = "LONG"   
texts = sents  


regex_patterns = [
                  re.compile(r"8° 36’ 50” Gemini2|87° 16\' 30\"8|16° 43\' Taurus10|0° 3\' Leo26|11° 52\',2|12° 38’ Pisces12"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“]\s?\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]-?(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+(,\d{1,2})?")           
]        


#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)         
#write_jsonl("NER_LONG_V07.jsonl", examples)

# %%
a_07=print_entities(examples)
# Out:
# There is 1002 entities with this detail
# ['3° 4\' 52"', '41° 55\' 8"', '16° 33\' 30"', '7° 28\' 56"', '37° 32\' 37"', '1\' 33"', '4° 20\' 8"', '85° 39\' 52"', '11° 25\' 48"', '11° 23\' 53"', '1’ 55”', '5° 27’ 47”', '23° 32\' 16" Leo', '5° 27’ 47”', '5° 27’ 47”', '78° 51’ 54”', '4’ 24”', '4’ 24”', '47° 59’ 16”', '44° 59’ 10”', '44° 59’ 10”', '53° 26’ 17”', '44° 59’ 10”', '7° 30’ 10”', '3° 0’ 6”', '16° Cancer.', '16° Cancer', '1° 3’ 32” But', '2° 3’', '9° Leo.', '23° 45’ Leo.', '5° 2’', '23° 25’ Leo.', '23° 20’ Leo', '17° Taurus', '3° Cancer', '17° Cancer', '27° Sagittarius.', '26° 45’ 24” Gemini.', '26° 24’ 43” Sagittarius.', '10’ 20”', '26° 24’ 13” Sagittarius', '18° Taurus', '13° Pisces.', '18° Taurus', '17° Taurus', '4° 33’', '1° 50’', '8° 36’ 50” Gemini2', '8° 20’ Gemini', '1° 55’', '1° 52’', '6° 41’ 50” Gemini', '1’ 4”', '6° 46’ 10” Gemini.', '16° 47’ Cancer', '16° 46’ 16” Cancer', '21° 18’ 11” Leo', '24’ 15”', '7’ 41”', '21° 10’ 30” Leo', '25° 10’ 20” Virgo.', '1’ 48”', '25° 8’ 32” Virgo', '3° 58\' 21" Scorpio', '1’ 22”', '3° 58’ 10”', '27° 15’ Sagittarius', '1° 12’ 47”', '39’ 29”', '26° 35’ 31” Sagittarius.', '26° 32’ Sagittarius.', '12° 38’ Pisces12', '5’ 48”', '12° 43’ 48” Pisces.', '12° 43’ 45”', '17° 48’ Taurus', '11’ 7”', '17° 56’ 15” Taurus', '3° 30’ Cancer', '1° 15’', '2° 28’', '10° 38’ 46” Leo', '6° 18’ Leo.', '23’ 44”', '2° 25’', '1° 6’', '44° 41’', '5° 31’', '17° 38’ Cancer', '36° 43’', '23° 29’', '43° 58’', '23° 27’', '67° 21’', '23° 29’', '23° 16’', '23° 9’', '7° 51’', '7° 59’', '44° 22’', '9° 44’', '32° 57’', '9° 48’ 45”', '32° 4’', '9° 2’', '39° 54’', '30° 52’', '28° 1’ 0” Libra,27', '7° 48’', '3° 0’ 30”', '68° 59’', '21° 1’', '68° 59’', '2° 48’ 31”', '21° 1’', '26° 56’ Libra.', '2° 47’ 48”', '2° 48’ 31”', '62° 37’', '39° 55’', '53° 5’', '30° 54’', '32° 6’', '26° 2’', '46° 22’', '29° 15’', '29° 19’', '29° 20’', '29° 9’', '29° 12’', '56° 44’', '9° 26’', '18° 25’', '27° 39’', '205° 27’ 10”', '26° 18’ 48” Libra', '29° 14’', '44° 45’', '29° 13’', '29° 18’', '29° 15’', '29° 19’', '4’ 24”', '3’ 0”', '4’ 20”', '8’ 45”', '4’ 36”', '2’ 25”', '29° 14’', '29° 9’', '29° 9’', '17° 56’ 5” Taurus', '9° 26’', '22° 35’ 10”', '24° 22’ 56” Aries', '11° 34’ 30” Aries', '0° 0’ 45”', '0° 2’ 20”', '0° 0’ 25”', '0° 3’ 46”', '6’ 45”', '1° 7’', '5° 31’ Taurus.', '5° 31’ Taurus', '11° 17’', '16° 48’ Taurus', '17° Leo', '17° Leo', '17° Leo', '17° Leo.', '72° 33’', '17° Aquarius', '17° Leo', '17° Aquarius', '17° Leo', '22° Virgo', '17° Aquarius', '25° 31’ Virgo', '23° Sagittarius', '1° 50’', '6° 9’', '13° 0’ 40”', '0° 7’ Virgo,7', '8° Scorpio', '5° 52’ Virgo', '16° 17’', '1° 47’', '20° 4’ 30” Virgo', '1° 47’', '1° 50’', '20° 58’', '1° 17’ Leo', '11° Taurus', '1° 50’', '15° 49’ Gemini', '30° Pisces', '1° 50’', '17° Aquarius', '2° Libra', '1° 36’', '1° 36’', '17° Taurus', '23° 14’ Leo', '2° 12’', '21° 26’ Leo', '16° Taurus', '16° Leo.', '1° 50’', '1° 45’', '1° 50’', '17° Scorpio', '16° Taurus', '21° 26’ Leo', '21° 26’ Leo', '17° Taurus', '17° Leo', '17° Leo', '17° Leo', '21° 16’ Leo', '21° Leo', '2° 43’ 27“', '1° 48’ 43“', '6° 3’', '4° 21’ 10“', '1° 41’ 50“', '1° 42’', '1° 50’', '8° 37’ Gemini,3', '0° 45’ 36“ Sagittarius', '7° 51’ 24“', '51’ 24“', '6° 28’ Gemini', '6° 28’ Gemini.', '1° 50’', '6° 28’ Gemini', '6° 28’ 35“ Gemini', '1° 40’', '16° 47’ Cancer,6', '61’ 18“', '26’ 45“', '1° 25’ 18“', '16° 54’ 32“ Cancer', '4° 6’', '4° 6’', '21° 18’ 11“ Leo', '22° 21’ 31“Aquarius.', '1° 3’ 20“', '61’ 16“', '1° 25’ 31“', '21° 36’ 10“ Leo.', '4° 32’ 10“', '4° 31’', '26° 26’ 17“ Virgo,8', '26° 26’ Virgo', '9° Sagittarius', '3° 42’ 22“', '23° 59’ 11“ Pisces.', '2° 26’ 49“', '59’ 35“', '2° 26’ 49“', '25° 43’ 53“ Virgo.', '25° 43’ Virgo.', '3° 38’ N.', '3° 58’ 20“ Scorpio,13', '24° Sagittarius.', '5’ 24“', '1° 9’ 45“', '2’ 38“', '4° Scorpio', '3° 57’ Scorpio.', '5° 36’ 20“ Taurus.', '1° 39’ 20“', '22’ 8“', '1° 39’ 20“', '4° 24’ 30“ Scorpio', '4° 24’ Scorpio', '27° 14’ 42“ Sagittarius,16', '24° 58’ 10“ Gemini.', '2° 16’ 10“', '57’ 8“', '18’ 12“', '1° 15’ 20“', '26° 41’ 48“ Sagittarius', '12°  ...

# %%
len(spans)
# Out:
# 0

# %%
misaligned_token(examples)

# %%
label = "LONG"   
texts = sents  

      
regex_patterns = [
                  re.compile(r"8° 36’ 50” Gemini2|87° 16\' 30\"8|16° 43\' Taurus10|0° 3\' Leo26|11° 52\',2|12° 38’ Pisces12"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“]\s?\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]-?(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+(,\d{1,2})?")           
]  

regex_patterns = [
                  re.compile(r"8° 36’ 50” Gemini2|87° 16\' 30\"8|16° 43\' Taurus10|0° 3\' Leo26|11° 52\',2|12° 38’ Pisces12"
                              "|\d{1,3}\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]-?(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\u00BC-\u00BE\u2150-\u215E]?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?[\u00BC-\u00BE\u2150-\u215E]?°\s?[A-Z][a-z.]+(,\d{1,2})?")
]
 
#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)              

#write_jsonl("NER_LONG_V08.jsonl", examples)

# %%
a_08=print_entities(examples)
# Out:
# There is 1096 entities with this detail
# ['3° 4\' 52"', '41° 55\' 8"', '16° 33\' 30"', '7° 28\' 56"', '37° 32\' 37"', '1\' 33"', '4° 20\' 8"', '85° 39\' 52"', '11° 25\' 48"', '11° 23\' 53"', '1’ 55”', '47° 59¼’', '5° 27’ 47”', '23° 32\' 16"', '5° 27’ 47”', '5° 27’ 47”', '78° 51’ 54”', '4’ 24”', '4’ 24”', '47° 59’ 16”', '44° 59’ 10”', '44° 59’ 10”', '53° 26’ 17”', '44° 59’ 10”', '7° 30’ 10”', '3° 0’ 6”', '8½° Cancer', '16° Cancer', '1° 3’ 32”', '2° 3’', '9° Leo.', '23° 45’', '5° 2’', '28° 2½’', '23° 20’', '17° Taurus', '3° Cancer', '17° Cancer', '27° Sagittarius.', '26° 45’ 24”', '26° 24’ 43”', '10’ 20”', '26° 24’ 13”', '18° Taurus', '13° Pisces.', '18° Taurus', '17° Taurus', '4° 33’', '1° 50’', '8° 36’ 50” Gemini2', '8° 20’', '1° 55’', '1° 52’', '6° 41’ 50”', '1’ 4”', '6° 46’ 10”', '16° 47’', '16° 46’ 16”', '21° 18’ 11”', '24’ 15”', '7’ 41”', '21° 10’ 30”', '25° 10’ 20”', '1’ 48”', '25° 8’ 32”', '3° 58\' 21"', '1’ 22”', '3° 58’ 10”', '27° 15’', '1° 12’ 47”', '39’ 29”', '26° 35’ 31”', '26° 32’', '12° 38’ Pisces12', '5’ 48”', '12° 43’ 48”', '12° 43’ 45”', '17° 48’', '11’ 7”', '17° 56’ 15”', '3° 30’', '1° 15’', '2° 30½’', '2° 28’', '10° 38’ 46”', '6° 18’', '23’ 44”', '2° 25’', '1° 6’', '44° 41’', '5° 31’', '17° 53⅓’', '36° 43’', '29° 38½’', '23° 29’', '43° 58’', '23° 27’', '23° 12½’', '67° 21’', '23° 29’', '23° 16’', '23° 9’', '7° 51’', '7° 59’', '44° 22’', '44° 27⅓’', '44° 32½’', '9° 44’', '32° 57’', '9° 48’ 45”', '32° 4’', '9° 2’', '39° 54’', '30° 52’', '28° 1’ 0”', '7° 48’', '3° 0’ 30”', '68° 59’', '21° 1’', '68° 59’', '2° 48’ 31”', '21° 1’', '26° 56’', '2° 47’ 48”', '2° 48’ 31”', '62° 37’', '39° 55’', '53° 5’', '30° 54’', '32° 6’', '29° 18⅓’', '26° 2’', '46° 22½’', '29° 13½’', '29° 19’', '29° 20’', '29° 9’', '29° 12’', '29° 9½’', '56° 44’', '29° 9½’', '29° 10¼’', '9° 26’', '32° 19½’', '18° 25’', '27° 39’', '39° 32½’', '205° 27’ 10”', '26° 18’ 48”', '29° 9⅙’', '29° 13½’', '44° 45’', '44° 39½’', '29° 13½’', '29° 18’', '29° 15’', '29° 19’', '4’ 24”', '3’ 0”', '12½° Mars', '4’ 20”', '8’ 45”', '4’ 36”', '2’ 25”', '29° 9½’', '29° 13½’', '29° 12½’', '29° 9’', '29° 9’', '17° 56’ 5”', '4° 34½’', '9° 26’', '22° 35’ 10”', '24° 22’ 56”', '11° 34’ 30”', '0° 0’ 45”', '0° 2’ 20”', '0° 0’ 25”', '0° 3’ 46”', '6’ 45”', '1° 7’', '27° 14½’', '5° 31’', '11° 17’', '15° 44½’', '17° Leo', '17° Leo', '17° Leo', '17° Leo.', '72° 33’', '17° Aquarius', '17° Leo', '17° Aquarius', '17° Leo', '22° Virgo', '17° Aquarius', '25° 31’', '9° 19⅖’', '1° 53½’', '1° 50’', '6° 9’', '13° 0’ 40”', '0° 7’', '8° Scorpio', '19⅖° Scorpio', '16° 17’', '1° 47’', '25° 12¼’', '20° 4’ 30”', '2° 16½’', '1° 47’', '1° 50’', '20° 58’', '1° 17’', '11° Taurus', '1° 50’', '15° 49’', '30° Pisces', '1° 50’', '17° Aquarius', '16° 47⅓’', '16° 45⅔’', '2° Libra', '1° 36’', '1° 36’', '17° Taurus', '1° 50⅔’', '23° 14’', '2° 12’', '21° 26’', '16° Taurus', '16° Leo.', '1° 49¾’', '1° 27⅓’', '2° 18⅔’,20', '2½° Scorpio', '1° 45’', '1° 50’', '17° Scorpio', '16° Taurus', '21° 26’', '21° 26’', '17° Taurus', '17° Leo', '17° Leo', '17° Leo', '21° 16’', '21° Leo', '4° 32⅙’', '2° 43’ 27“', '1° 48’ 43“', '6° 3’', '12½° Pisces.', '4° 21’ 10“', '1° 41’ 50“', '1° 42’', '1° 50’', '8° 37’', '0° 45’ 36“', '7° 51’ 24“', '51’ 24“', '6° 28’', '16½° Taurus.', '6° 28’', '1° 50’', '6° 28’', '6° 28’ 35“', '1° 40’', '16° 47’', '61’ 18“', '26’ 45“', '1° 25’ 18“', '16° 54’ 32“', '4° 6’', '4° 6’', '21° 18’ 11“', '22° 21’ 31“Aquarius', '1° 3’ 20“', '61’ 16“', '1° 25’ 31“', '21° 36’ 10“', '4° 32’ 10“', '4° 31’', '26° 26’ 17“', '26° 26’', '9° Sagittarius', '3° 42’ 22“', '23° 59’ 11“', '2° 26’ 49“', '59’ 35“', '2° 26’ 49“', '25° 43’ 53“', '25° 43’', '3° 38’', '3° 58’ 20“', '24° Sagittarius.', '5’ 24“', '1° 9’ 45“', '2’ 38“', '4° Scorpio', '3° 57’', '5° 36’ 20“', '1° 39’ 20“', '22’ 8“', '1° 39’ 20“', '4° 24’ 30“', '4° 24’', '27° 14’ 42“', '24° 58’ 10“', '2° 16’ 10“', '57’ 8“', '18’ 12“', '1° 15’ 20“', '26° 41’ 48“', '4° 1½’', '12° 38’', '11° 15’ 24“', '1° 22’ 36“', '11° 2’ 31“', '1° 35’ 30“', '58’ 20“', '1° 14’ 51“', '12° 16’', '6° 2’', '17° 47’ 15“', '0° 5’ 10“', ' ...

# %%
misaligned_token(examples)
# Out:
# 1- Misaligned tokens--> Hence, owing to our removal of the vernal equinox westward from that star, which was then 28° 2½’,4 it is concluded that Mars’s apogee was at 23° 25’ Leo. {'start': 90, 'end': 97, 'label': 'LONG'}
# 2- Misaligned tokens--> In Tycho’s table of oppositions, the apparent latitude at 21° 16’ Leo was 4° 32⅙’22 {'start': 74, 'end': 81, 'label': 'LONG'}
# 3- Misaligned tokens--> The sun was at 22° 21’ 31“Aquarius. {'start': 15, 'end': 26, 'label': 'LONG'}
# 4- Misaligned tokens--> And since the latitude of the fixed star is 56° 22’, the remainder, by subtraction, is 4° 2½’—supposing that Mars was at precisely the same longitude as the fixed star. {'start': 87, 'end': 93, 'label': 'LONG'}
# 5- Misaligned tokens--> And on midnight of July 30 the position of Mars disagrees with Magini's midday position by 3° 25½’, and on August 10 by 3° 59½’,so that the difference is increased, but gradually less so. {'start': 120, 'end': 127, 'label': 'LONG'}

# %%
# add fractional part after the second number

# %%
label = "LONG"   
texts = sents  

regex_patterns = [
                  re.compile(r"8° 36’ 50” Gemini2|87° 16\' 30\"8|16° 43\' Taurus10|0° 3\' Leo26|11° 52\',2|12° 38’ Pisces12"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“]\s?\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]-?(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?°\s?[A-Z][a-z.]+(,\d{1,2})?")           
]     


regex_patterns = [
                  re.compile(r"28° 2½’,4|4° 32⅙’22|4° 32⅙’22|4° 2½’—supposing|3° 59½’,so|22° 21’ 31“Aquarius|8° 36’ 50” Gemini2|87° 16\' 30\"8|16° 43\' Taurus10|0° 3\' Leo26|11° 52\',2|12° 38’ Pisces12"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\u00BC-\u00BE\u2150-\u215E]?[\'|’|\"|”|“]\s?\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]\s?[A-Z][a-z.]+(,\d{1,2})?"
                              "|\d{1,3}\s?°\s?\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”|“]-?(,\d{1,2})?"
                              "|\d{1,3}\s?[\'|’|°]\s?\d{1,2}\s?[\u00BC-\u00BE\u2150-\u215E]?[\'|’|\"|”|“](,\d{2})?"
                              "|\d{1,3}\s?[\u00BC-\u00BE\u2150-\u215E]?°\s?[A-Z][a-z.]+(,\d{1,2})?")
]
 
#(5° 20\' 2\"  Libra,|21° 44\' 56\"  Sagittarius,|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”]\s[A-Z][a-z]+(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s\d{1,2}\s?[\'|’]\s?\d{1,2}\s?[\"|”].?(?!\S?\S)|(?<!\S)\d{1,2}\s?°\s?\d{1,2}\s?[\'|’]\s?[A-Z][a-z]+(?!\S?\S))[,:/.]?
examples = []
for text in texts:
    for expression in regex_patterns:
        spans = []
    for match in re.finditer(expression, text):
        start, end = match.span()
        span = {"start": start, "end": end, "label": label}
        spans.append(span)
    task = {"text": text, "spans": spans}
    examples.append(task)              

write_jsonl("NER_COOR_V04.jsonl", examples)

# %%
a_10=print_entities(examples)
# Out:
# There is 1096 entities with this detail
# ['3° 4\' 52"', '41° 55\' 8"', '16° 33\' 30"', '7° 28\' 56"', '37° 32\' 37"', '1\' 33"', '4° 20\' 8"', '85° 39\' 52"', '11° 25\' 48"', '11° 23\' 53"', '1’ 55”', '47° 59¼’', '5° 27’ 47”', '23° 32\' 16" Leo', '5° 27’ 47”', '5° 27’ 47”', '78° 51’ 54”', '4’ 24”', '4’ 24”', '47° 59’ 16”', '44° 59’ 10”', '44° 59’ 10”', '53° 26’ 17”', '44° 59’ 10”', '7° 30’ 10”', '3° 0’ 6”', '8½° Cancer', '16° Cancer', '1° 3’ 32” But', '2° 3’', '9° Leo.', '23° 45’ Leo.', '5° 2’', '28° 2½’,4', '23° 20’ Leo', '17° Taurus', '3° Cancer', '17° Cancer', '27° Sagittarius.', '26° 45’ 24” Gemini.', '26° 24’ 43” Sagittarius.', '10’ 20”', '26° 24’ 13” Sagittarius', '18° Taurus', '13° Pisces.', '18° Taurus', '17° Taurus', '4° 33’', '1° 50’', '8° 36’ 50” Gemini2', '8° 20’ Gemini', '1° 55’', '1° 52’', '6° 41’ 50” Gemini', '1’ 4”', '6° 46’ 10” Gemini.', '16° 47’ Cancer', '16° 46’ 16” Cancer', '21° 18’ 11” Leo', '24’ 15”', '7’ 41”', '21° 10’ 30” Leo', '25° 10’ 20” Virgo.', '1’ 48”', '25° 8’ 32” Virgo', '3° 58\' 21" Scorpio', '1’ 22”', '3° 58’ 10”', '27° 15’ Sagittarius', '1° 12’ 47”', '39’ 29”', '26° 35’ 31” Sagittarius.', '26° 32’ Sagittarius.', '12° 38’ Pisces12', '5’ 48”', '12° 43’ 48” Pisces.', '12° 43’ 45”', '17° 48’ Taurus', '11’ 7”', '17° 56’ 15” Taurus', '3° 30’ Cancer', '1° 15’', '2° 30½’ Cancer.', '2° 28’', '10° 38’ 46” Leo', '6° 18’ Leo.', '23’ 44”', '2° 25’', '1° 6’', '44° 41’', '5° 31’', '17° 53⅓’ Cancer,6', '36° 43’', '29° 38½’ But', '23° 29’', '43° 58’', '23° 27’', '23° 12½’', '67° 21’', '23° 29’', '23° 16’', '23° 9’', '7° 51’', '7° 59’', '44° 22’', '44° 27⅓’', '44° 32½’', '9° 44’', '32° 57’', '9° 48’ 45”', '32° 4’', '9° 2’', '39° 54’', '30° 52’', '28° 1’ 0” Libra,27', '7° 48’', '3° 0’ 30”', '68° 59’', '21° 1’', '68° 59’', '2° 48’ 31”', '21° 1’', '26° 56’ Libra.', '2° 47’ 48”', '2° 48’ 31”', '62° 37’', '39° 55’', '53° 5’', '30° 54’', '32° 6’', '29° 18⅓’', '26° 2’', '46° 22½’', '29° 13½’', '29° 19’', '29° 20’', '29° 9’', '29° 12’', '29° 9½’', '56° 44’', '29° 9½’', '29° 10¼’', '9° 26’', '32° 19½’', '18° 25’', '27° 39’', '39° 32½’', '205° 27’ 10”', '26° 18’ 48” Libra', '29° 9⅙’', '29° 13½’', '44° 45’', '44° 39½’', '29° 13½’', '29° 18’', '29° 15’', '29° 19’', '4’ 24”', '3’ 0”', '12½° Mars', '4’ 20”', '8’ 45”', '4’ 36”', '2’ 25”', '29° 9½’', '29° 13½’', '29° 12½’', '29° 9’', '29° 9’', '17° 56’ 5” Taurus', '4° 34½’', '9° 26’', '22° 35’ 10”', '24° 22’ 56” Aries', '11° 34’ 30” Aries', '0° 0’ 45”', '0° 2’ 20”', '0° 0’ 25”', '0° 3’ 46”', '6’ 45”', '1° 7’', '27° 14½’ Scorpio', '5° 31’ Taurus', '11° 17’', '15° 44½’ Scorpio', '17° Leo', '17° Leo', '17° Leo', '17° Leo.', '72° 33’', '17° Aquarius', '17° Leo', '17° Aquarius', '17° Leo', '22° Virgo', '17° Aquarius', '25° 31’ Virgo', '9° 19⅖’ Libra', '1° 53½’', '1° 50’', '6° 9’', '13° 0’ 40”', '0° 7’ Virgo,7', '8° Scorpio', '19⅖° Scorpio', '16° 17’', '1° 47’', '25° 12¼’', '20° 4’ 30” Virgo', '2° 16½’', '1° 47’', '1° 50’', '20° 58’', '1° 17’ Leo', '11° Taurus', '1° 50’', '15° 49’ Gemini', '30° Pisces', '1° 50’', '17° Aquarius', '16° 47⅓’ Sagittarius', '16° 45⅔’', '2° Libra', '1° 36’', '1° 36’', '17° Taurus', '1° 50⅔’', '23° 14’ Leo', '2° 12’', '21° 26’ Leo', '16° Taurus', '16° Leo.', '1° 49¾’', '1° 27⅓’ Aquarius', '2° 18⅔’,20', '2½° Scorpio', '1° 45’', '1° 50’', '17° Scorpio', '16° Taurus', '21° 26’ Leo', '21° 26’ Leo', '17° Taurus', '17° Leo', '17° Leo', '17° Leo', '21° 16’ Leo', '21° Leo', '4° 32⅙’', '2° 43’ 27“', '1° 48’ 43“', '6° 3’', '12½° Pisces.', '4° 21’ 10“', '1° 41’ 50“', '1° 42’', '1° 50’', '8° 37’ Gemini,3', '0° 45’ 36“ Sagittarius', '7° 51’ 24“', '51’ 24“', '6° 28’ Gemini', '16½° Taurus.', '6° 28’ Gemini.', '1° 50’', '6° 28’ Gemini', '6° 28’ 35“ Gemini', '1° 40’', '16° 47’ Cancer,6', '61’ 18“', '26’ 45“', '1° 25’ 18“', '16° 54’ 32“ Cancer', '4° 6’', '4° 6’', '21° 18’ 11“ Leo', '22° 21’ 31“Aquarius', '1° 3’ 20“', '61’ 16“', '1° 25’ 31“', '21° 36’ 10“ Leo.', '4° 32’ 10“', '4° 31’', '26° 26’ 17“ Virgo,8', '26° 26’ Virgo', '9° Sagittarius', '3° 42’ 22“', '23° 59’ 11“ Pisces.', '2° 26’ 49“', '59’ 35“', '2° 26’ 49 ...

# %%
misaligned_token(examples)

# %%
a_09=print_entities(examples)
# Out:
# There is 1096 entities with this detail
# ['3° 4\' 52"', '41° 55\' 8"', '16° 33\' 30"', '7° 28\' 56"', '37° 32\' 37"', '1\' 33"', '4° 20\' 8"', '85° 39\' 52"', '11° 25\' 48"', '11° 23\' 53"', '1’ 55”', '47° 59¼’', '5° 27’ 47”', '23° 32\' 16" Leo', '5° 27’ 47”', '5° 27’ 47”', '78° 51’ 54”', '4’ 24”', '4’ 24”', '47° 59’ 16”', '44° 59’ 10”', '44° 59’ 10”', '53° 26’ 17”', '44° 59’ 10”', '7° 30’ 10”', '3° 0’ 6”', '8½° Cancer', '16° Cancer', '1° 3’ 32” But', '2° 3’', '9° Leo.', '23° 45’ Leo.', '5° 2’', '28° 2½’,4', '23° 20’ Leo', '17° Taurus', '3° Cancer', '17° Cancer', '27° Sagittarius.', '26° 45’ 24” Gemini.', '26° 24’ 43” Sagittarius.', '10’ 20”', '26° 24’ 13” Sagittarius', '18° Taurus', '13° Pisces.', '18° Taurus', '17° Taurus', '4° 33’', '1° 50’', '8° 36’ 50” Gemini2', '8° 20’ Gemini', '1° 55’', '1° 52’', '6° 41’ 50” Gemini', '1’ 4”', '6° 46’ 10” Gemini.', '16° 47’ Cancer', '16° 46’ 16” Cancer', '21° 18’ 11” Leo', '24’ 15”', '7’ 41”', '21° 10’ 30” Leo', '25° 10’ 20” Virgo.', '1’ 48”', '25° 8’ 32” Virgo', '3° 58\' 21" Scorpio', '1’ 22”', '3° 58’ 10”', '27° 15’ Sagittarius', '1° 12’ 47”', '39’ 29”', '26° 35’ 31” Sagittarius.', '26° 32’ Sagittarius.', '12° 38’ Pisces12', '5’ 48”', '12° 43’ 48” Pisces.', '12° 43’ 45”', '17° 48’ Taurus', '11’ 7”', '17° 56’ 15” Taurus', '3° 30’ Cancer', '1° 15’', '2° 30½’', '2° 28’', '10° 38’ 46” Leo', '6° 18’ Leo.', '23’ 44”', '2° 25’', '1° 6’', '44° 41’', '5° 31’', '17° 53⅓’', '36° 43’', '29° 38½’', '23° 29’', '43° 58’', '23° 27’', '23° 12½’', '67° 21’', '23° 29’', '23° 16’', '23° 9’', '7° 51’', '7° 59’', '44° 22’', '44° 27⅓’', '44° 32½’', '9° 44’', '32° 57’', '9° 48’ 45”', '32° 4’', '9° 2’', '39° 54’', '30° 52’', '28° 1’ 0” Libra,27', '7° 48’', '3° 0’ 30”', '68° 59’', '21° 1’', '68° 59’', '2° 48’ 31”', '21° 1’', '26° 56’ Libra.', '2° 47’ 48”', '2° 48’ 31”', '62° 37’', '39° 55’', '53° 5’', '30° 54’', '32° 6’', '29° 18⅓’', '26° 2’', '46° 22½’', '29° 13½’', '29° 19’', '29° 20’', '29° 9’', '29° 12’', '29° 9½’', '56° 44’', '29° 9½’', '29° 10¼’', '9° 26’', '32° 19½’', '18° 25’', '27° 39’', '39° 32½’', '205° 27’ 10”', '26° 18’ 48” Libra', '29° 9⅙’', '29° 13½’', '44° 45’', '44° 39½’', '29° 13½’', '29° 18’', '29° 15’', '29° 19’', '4’ 24”', '3’ 0”', '12½° Mars', '4’ 20”', '8’ 45”', '4’ 36”', '2’ 25”', '29° 9½’', '29° 13½’', '29° 12½’', '29° 9’', '29° 9’', '17° 56’ 5” Taurus', '4° 34½’', '9° 26’', '22° 35’ 10”', '24° 22’ 56” Aries', '11° 34’ 30” Aries', '0° 0’ 45”', '0° 2’ 20”', '0° 0’ 25”', '0° 3’ 46”', '6’ 45”', '1° 7’', '27° 14½’', '5° 31’ Taurus', '11° 17’', '15° 44½’', '17° Leo', '17° Leo', '17° Leo', '17° Leo.', '72° 33’', '17° Aquarius', '17° Leo', '17° Aquarius', '17° Leo', '22° Virgo', '17° Aquarius', '25° 31’ Virgo', '9° 19⅖’', '1° 53½’', '1° 50’', '6° 9’', '13° 0’ 40”', '0° 7’ Virgo,7', '8° Scorpio', '19⅖° Scorpio', '16° 17’', '1° 47’', '25° 12¼’', '20° 4’ 30” Virgo', '2° 16½’', '1° 47’', '1° 50’', '20° 58’', '1° 17’ Leo', '11° Taurus', '1° 50’', '15° 49’ Gemini', '30° Pisces', '1° 50’', '17° Aquarius', '16° 47⅓’', '16° 45⅔’', '2° Libra', '1° 36’', '1° 36’', '17° Taurus', '1° 50⅔’', '23° 14’ Leo', '2° 12’', '21° 26’ Leo', '16° Taurus', '16° Leo.', '1° 49¾’', '1° 27⅓’', '2° 18⅔’,20', '2½° Scorpio', '1° 45’', '1° 50’', '17° Scorpio', '16° Taurus', '21° 26’ Leo', '21° 26’ Leo', '17° Taurus', '17° Leo', '17° Leo', '17° Leo', '21° 16’ Leo', '21° Leo', '4° 32⅙’', '2° 43’ 27“', '1° 48’ 43“', '6° 3’', '12½° Pisces.', '4° 21’ 10“', '1° 41’ 50“', '1° 42’', '1° 50’', '8° 37’ Gemini,3', '0° 45’ 36“ Sagittarius', '7° 51’ 24“', '51’ 24“', '6° 28’ Gemini', '16½° Taurus.', '6° 28’ Gemini.', '1° 50’', '6° 28’ Gemini', '6° 28’ 35“ Gemini', '1° 40’', '16° 47’ Cancer,6', '61’ 18“', '26’ 45“', '1° 25’ 18“', '16° 54’ 32“ Cancer', '4° 6’', '4° 6’', '21° 18’ 11“ Leo', '22° 21’ 31“Aquarius', '1° 3’ 20“', '61’ 16“', '1° 25’ 31“', '21° 36’ 10“ Leo.', '4° 32’ 10“', '4° 31’', '26° 26’ 17“ Virgo,8', '26° 26’ Virgo', '9° Sagittarius', '3° 42’ 22“', '23° 59’ 11“ Pisces.', '2° 26’ 49“', '59’ 35“', '2° 26’ 49“', '25° 43’ 53“ Virgo.', '25° 43’ Virgo.', '3° 38’ N.', '3° 58’ ...
